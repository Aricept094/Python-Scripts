# %%
import numpy as np
import pandas as pd
from scipy.signal.windows import hann, hamming, blackman, kaiser
from sklearn.metrics import r2_score

def calculate_metrics(y_true, y_pred, y_mean=None):
    """
    Calculate R² score and RMSE with proper normalization
    """
    if y_mean is None:
        y_mean = np.mean(y_true)
    
    # Calculate RMSE
    rmse = np.sqrt(np.mean((y_true - y_pred)**2))
    
    # Calculate R² manually to ensure proper normalization
    ss_tot = np.sum((y_true - y_mean)**2)
    ss_res = np.sum((y_true - y_pred)**2)
    
    r2 = 1 - (ss_res / ss_tot) if ss_tot != 0 else 0
    
    return rmse, r2

def fourier_components_by_order(theta, radial_idx, order):
    """Generate Fourier components for given order using radial index"""
    if order == 0:
        return np.array([1.0])
    
    # Use radial_idx directly instead of normalized radius
    components = [
        np.cos(order * theta),
        np.sin(order * theta),
        radial_idx * np.cos(order * np.pi * radial_idx/32),  # Assuming 32 is max radial index
        radial_idx * np.sin(order * np.pi * radial_idx/32),
        radial_idx * np.cos(order * theta) * np.cos(order * np.pi * radial_idx/32),
        radial_idx * np.sin(order * theta) * np.sin(order * np.pi * radial_idx/32)
    ]
    
    return np.array(components)

def fit_fourier_model_by_order(theta, radial_idx, k, order, k_mean=None):
    """Fit Fourier model for given order with proper centering"""
    if k_mean is None:
        k_mean = np.mean(k)
    
    # Center the data
    k_centered = k - k_mean if order > 0 else k
    
    X = []
    for i in range(len(theta)):
        X.append(fourier_components_by_order(theta[i], radial_idx[i], order))
    X = np.vstack(X)
    
    coeffs, residuals, rank, s = np.linalg.lstsq(X, k_centered, rcond=None)
    return coeffs

def reconstruct_from_coeffs(theta, radial_idx, coeffs, order, k_mean=0):
    """Reconstruct signal from coefficients"""
    X = []
    for i in range(len(theta)):
        X.append(fourier_components_by_order(theta[i], radial_idx[i], order))
    X = np.vstack(X)
    
    reconstruction = X @ coeffs
    if order > 0:
        reconstruction += k_mean
    
    return reconstruction

def analyze_with_windows(filepath):
    # Load data
    df = pd.read_csv(filepath)
    theta = df['Meridian_Angle_Rad'].values
    radial_idx = df['Radial_Index'].values  # Using Radial_Index instead of normalized radius
    k = df['KR_scaled'].values
    
    # Store original mean for proper normalization
    k_mean = np.mean(k)
    
    windows = ['none', 'kaiser']
    results = {}
    
    for window in windows:
        print(f"\nAnalysis with {window.upper()} window")
        print("-" * 40)
        
        # Apply window if needed
        if window == 'none':
            k_windowed = k
        else:
            k_windowed = k * kaiser(len(k), beta=14)
        
        total_reconstruction = np.zeros_like(k_windowed)
        coeffs_by_order = []
        
        # Analyze each order
        for order in range(3):  # Orders 0, 1, 2
            coeffs = fit_fourier_model_by_order(theta, radial_idx, k_windowed, order, k_mean)
            coeffs_by_order.append(coeffs)
            
            # Reconstruct this order's contribution
            order_reconstruction = reconstruct_from_coeffs(theta, radial_idx, coeffs, order, k_mean)
            total_reconstruction += order_reconstruction if order > 0 else order_reconstruction
            
            # Calculate metrics for this order
            rmse, r2 = calculate_metrics(k_windowed, order_reconstruction, k_mean)
            
            print(f"\nOrder {order}:")
            print(f"RMSE: {rmse:.6f}")
            print(f"R² score: {r2:.6f}")
            
            if order == 0:
                print(f"DC component: {coeffs[0]:.4f}")
            else:
                component_names = [
                    f"cos({order}θ)",
                    f"sin({order}θ)",
                    f"r*cos({order}πr)",
                    f"r*sin({order}πr)",
                    f"r*cos({order}θ)*cos({order}πr)",
                    f"r*sin({order}θ)*sin({order}πr)"
                ]
                for coeff, name in zip(coeffs, component_names):
                    print(f"{name}: {coeff:.4f}")
        
        # Calculate total metrics
        total_rmse, total_r2 = calculate_metrics(k_windowed, total_reconstruction, k_mean)
        
        print(f"\nTotal reconstruction metrics:")
        print(f"RMSE: {total_rmse:.6f}")
        print(f"R² score: {total_r2:.6f}")
        
        results[window] = {
            'rmse': total_rmse,
            'r2': total_r2,
            'coeffs': coeffs_by_order
        }
        
        # Print the full Fourier formula
        print("\nFull Fourier Formula:")
        formula_str = f"K(θ,r) = {coeffs_by_order[0][0]:.4f}"  # DC term
        
        for order in range(1, len(coeffs_by_order)):
            coeffs = coeffs_by_order[order]
            formula_str += (
                f" + {coeffs[0]:.4f}*cos({order}θ)"
                f" + {coeffs[1]:.4f}*sin({order}θ)"
                f" + {coeffs[2]:.4f}*r*cos({order}πr/32)"
                f" + {coeffs[3]:.4f}*r*sin({order}πr/32)"
                f" + {coeffs[4]:.4f}*r*cos({order}θ)*cos({order}πr/32)"
                f" + {coeffs[5]:.4f}*r*sin({order}θ)*sin({order}πr/32)"
            )
        
        print(formula_str)
    
    return results

if __name__ == "__main__":
    filepath = "/home/aricept094/mydata/sheets/conv/transformed/Sheet2_transformed.csv"
    results = analyze_with_windows(filepath)

# %%
import numpy as np
import pandas as pd

# Load the dataset
data_path = "/home/aricept094/mydata/sheets/conv/transformed/Sheet2_transformed.csv"  # Update with your file path
df = pd.read_csv(data_path)

def apply_window(data, window_type, **kwargs):
    """
    Applies a window function to the data.
    """
    if window_type is None:
        return data

    rows, cols = data.shape
    if window_type == 'hann':
        row_window = np.hanning(rows)
        col_window = np.hanning(cols)
    elif window_type == 'kaiser':
        beta = kwargs.get('beta', 8.6)
        row_window = np.kaiser(rows, beta)
        col_window = np.kaiser(cols, beta)
    elif window_type == 'blackman':
        row_window = np.blackman(rows)
        col_window = np.blackman(cols)
    else:
        raise ValueError("Invalid window type specified.")

    window_2d = np.outer(row_window, col_window)
    return data * window_2d

def inverse_window(data, window_type, **kwargs):
    """
    Applies an inverse window function to the data.
    """
    if window_type is None:
        return data

    rows, cols = data.shape
    if window_type == 'hann':
        row_window = np.hanning(rows)
        col_window = np.hanning(cols)
    elif window_type == 'kaiser':
        beta = kwargs.get('beta', 8.6)
        row_window = np.kaiser(rows, beta)
        col_window = np.kaiser(cols, beta)
    elif window_type == 'blackman':
        row_window = np.blackman(rows)
        col_window = np.blackman(cols)
    else:
        raise ValueError("Invalid window type specified.")

    window_2d = np.outer(row_window, col_window)
    epsilon = 1e-10
    window_2d[window_2d < epsilon] = epsilon
    return data / window_2d

def calculate_2d_fourier_coefficients(meridians, radial_indices, keratometry_values, window_type=None, **kwargs):
    """
    Calculates the 2D Fourier coefficients, excluding cross-terms, with optional windowing.
    """
    n_meridians = len(meridians)
    n_radial = len(radial_indices)
    coefficients = {}
    energy = {}

    windowed_data = apply_window(keratometry_values, window_type, **kwargs)
    reconstructed_signal = np.zeros_like(windowed_data)

    # DC component
    coefficients['a0_0'] = np.sum(windowed_data) / (n_meridians * n_radial)
    energy['a0_0'] = coefficients['a0_0'] ** 2
    reconstructed_signal += coefficients['a0_0']

    total_energy = energy['a0_0']

    # Calculate coefficients (increase range of m and r)
    for m in range(1, 5):  # Increased to 4
        meridian_grid = np.tile(meridians, (n_radial, 1))
        cos_term_m = np.cos(2 * np.pi * m * meridian_grid / n_meridians)
        sin_term_m = np.sin(2 * np.pi * m * meridian_grid / n_meridians)

        a_m0 = (2 / (n_meridians * n_radial)) * np.sum(windowed_data * cos_term_m)
        b_m0 = (2 / (n_meridians * n_radial)) * np.sum(windowed_data * sin_term_m)

        coefficients[f'a{m}_0'] = a_m0
        coefficients[f'b{m}_0'] = b_m0
        energy[f'a{m}_0'] = a_m0 ** 2
        energy[f'b{m}_0'] = b_m0 ** 2
        total_energy += a_m0 ** 2 + b_m0 ** 2
        reconstructed_signal += a_m0 * cos_term_m + b_m0 * sin_term_m

    for r in range(1, 5):  # Increased to 4
        radial_grid = np.tile(radial_indices.reshape(-1, 1), (1, n_meridians))
        cos_term_r = np.cos(2 * np.pi * r * radial_grid / n_radial)
        sin_term_r = np.sin(2 * np.pi * r * radial_grid / n_radial)

        a_0r = (2 / (n_meridians * n_radial)) * np.sum(windowed_data * cos_term_r)
        b_0r = (2 / (n_meridians * n_radial)) * np.sum(windowed_data * sin_term_r)

        coefficients[f'a0_{r}'] = a_0r
        coefficients[f'b0_{r}'] = b_0r
        energy[f'a0_{r}'] = a_0r ** 2
        energy[f'b0_{r}'] = b_0r ** 2
        total_energy += a_0r ** 2 + b_0r ** 2
        reconstructed_signal += a_0r * cos_term_r + b_0r * sin_term_r

    variance_explained = {}
    for key, value in energy.items():
        if key == 'a0_0':
            variance_explained[key] = (value / total_energy) * 100
        else:
            variance_explained[key] = (value / total_energy) * 100 * 2

    return coefficients, variance_explained, reconstructed_signal

def calculate_r2(original_signal, reconstructed_signal):
    """
    Calculates the R-squared (coefficient of determination).
    """
    ss_total = np.sum((original_signal - np.mean(original_signal)) ** 2)
    ss_residual = np.sum((original_signal - reconstructed_signal) ** 2)
    r2 = 1 - (ss_residual / ss_total)
    return r2

def perform_2d_fourier_analysis(df, window_type=None, **kwargs):
    """
    Performs the 2D Fourier analysis with different window types.
    """
    unique_meridians = np.sort(df['Meridian_Index'].unique())
    unique_radial_indices = np.sort(df['Radial_Index'].unique())

    keratometry_matrix = np.zeros((len(unique_radial_indices), len(unique_meridians)))
    for i, radial_index in enumerate(unique_radial_indices):
        for j, meridian in enumerate(unique_meridians):
            value = df[(df['Meridian_Index'] == meridian) & (df['Radial_Index'] == radial_index)]['Keratometry_Value'].values
            if value.size > 0:
                keratometry_matrix[i, j] = value[0]

    coefficients, variance_explained, reconstructed_signal = calculate_2d_fourier_coefficients(
        unique_meridians, unique_radial_indices, keratometry_matrix, window_type, **kwargs
    )

    # Calculate R-squared using the inverse window
    reconstructed_signal_unwindowed = inverse_window(reconstructed_signal, window_type, **kwargs)
    r2 = calculate_r2(keratometry_matrix, reconstructed_signal_unwindowed)

    return r2, coefficients, variance_explained

# Example usage with different window functions:
window_types = [None, 'hann', 'kaiser', 'blackman']
results = {}

for window_type in window_types:
    if window_type == 'kaiser':
        r2, coefficients, variance_explained = perform_2d_fourier_analysis(df, window_type, beta=8.6)
    else:
        r2, coefficients, variance_explained = perform_2d_fourier_analysis(df, window_type)

    results[window_type if window_type is not None else "no_window"] = r2
    print(f"Window: {window_type if window_type is not None else 'no_window'}, R2: {r2:.4f}")

# Create a DataFrame and save the results
results_df = pd.DataFrame.from_dict(results, orient='index', columns=['R2'])
output_path = "fourier_analysis_window_comparison_updated.csv"  # Choose a suitable file name
results_df.to_csv(output_path)
print(f"R2 results for different window functions saved to {output_path}")

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score

# Configuration parameters
MAX_MERIDIONAL_COMPONENTS = 5  # Maximum meridional components
MAX_RADIAL_COMPONENTS = 2      # Maximum radial components
DATA_PATH = "/home/aricept094/mydata/sheets/conv/transformed/Sheet2_transformed.csv"

def reconstruct_signal(coefficients, meridians, radial_indices, max_meridional_components, max_radial_components):
    """
    Reconstructs the signal using the Fourier coefficients without cross-terms.
    """
    n_meridians = len(meridians)
    n_radial = len(radial_indices)
    reconstructed = np.zeros((len(radial_indices), len(meridians)))
    
    # Add DC component
    reconstructed += coefficients['a0']
    
    # Create meshgrids for meridional and radial components
    meridian_grid, _ = np.meshgrid(meridians, radial_indices)
    _, radial_grid = np.meshgrid(meridians, radial_indices)
    
    # Add meridional components
    for m in range(1, max_meridional_components + 1):
        cos_term = np.cos(2 * np.pi * m * meridian_grid / n_meridians)
        sin_term = np.sin(2 * np.pi * m * meridian_grid / n_meridians)
        
        am_key = f'am{m}'
        bm_key = f'bm{m}'
        if am_key in coefficients and bm_key in coefficients:
            reconstructed += coefficients[am_key] * cos_term
            reconstructed += coefficients[bm_key] * sin_term
    
    # Add radial components
    for r in range(1, max_radial_components + 1):
        cos_term = np.cos(2 * np.pi * r * radial_grid / n_radial)
        sin_term = np.sin(2 * np.pi * r * radial_grid / n_radial)
        
        ar_key = f'ar{r}'
        br_key = f'br{r}'
        if ar_key in coefficients and br_key in coefficients:
            reconstructed += coefficients[ar_key] * cos_term
            reconstructed += coefficients[br_key] * sin_term
            
    return reconstructed

def calculate_2d_fourier_coefficients(meridians, radial_indices, keratometry_values, max_meridional_components, max_radial_components):
    """
    Calculates the 2D Fourier coefficients without cross-terms.
    """
    n_meridians = len(meridians)
    n_radial = len(radial_indices)
    coefficients = {}
    energy = {}

    # DC component
    coefficients['a0'] = np.mean(keratometry_values)
    energy['a0'] = coefficients['a0']**2

    total_energy = energy['a0']
    
    # Create meshgrids
    meridian_grid, _ = np.meshgrid(meridians, radial_indices)
    _, radial_grid = np.meshgrid(meridians, radial_indices)

    # Calculate meridional components
    for m in range(1, max_meridional_components + 1):
        cos_term = np.cos(2 * np.pi * m * meridian_grid / n_meridians)
        sin_term = np.sin(2 * np.pi * m * meridian_grid / n_meridians)

        am = (2 / (n_meridians * n_radial)) * np.sum(keratometry_values * cos_term)
        bm = (2 / (n_meridians * n_radial)) * np.sum(keratometry_values * sin_term)

        coefficients[f'am{m}'] = am
        coefficients[f'bm{m}'] = bm
        
        energy[f'am{m}'] = am**2
        energy[f'bm{m}'] = bm**2
        
        total_energy += am**2 + bm**2

    # Calculate radial components
    for r in range(1, max_radial_components + 1):
        cos_term = np.cos(2 * np.pi * r * radial_grid / n_radial)
        sin_term = np.sin(2 * np.pi * r * radial_grid / n_radial)

        ar = (2 / (n_meridians * n_radial)) * np.sum(keratometry_values * cos_term)
        br = (2 / (n_meridians * n_radial)) * np.sum(keratometry_values * sin_term)

        coefficients[f'ar{r}'] = ar
        coefficients[f'br{r}'] = br
        
        energy[f'ar{r}'] = ar**2
        energy[f'br{r}'] = br**2
        
        total_energy += ar**2 + br**2

    # Calculate variance explained
    variance_explained = {}
    for key, value in energy.items():
        variance_explained[key] = (value / total_energy) * 100
            
    # Reconstruct signal and calculate R²
    reconstructed_values = reconstruct_signal(coefficients, meridians, radial_indices, 
                                           max_meridional_components, max_radial_components)
    r2 = r2_score(keratometry_values.flatten(), reconstructed_values.flatten())

    return coefficients, variance_explained, r2, reconstructed_values

def perform_2d_fourier_analysis(df, max_meridional_components, max_radial_components):
    """
    Performs 2D Fourier analysis on the input data.
    """
    unique_meridians = np.sort(df['Meridian_Index'].unique())
    unique_radial_indices = np.sort(df['Radial_Index'].unique())

    keratometry_matrix = np.zeros((len(unique_radial_indices), len(unique_meridians)))
    for i, radial_index in enumerate(unique_radial_indices):
        for j, meridian in enumerate(unique_meridians):
            value = df[(df['Meridian_Index'] == meridian) & 
                      (df['Radial_Index'] == radial_index)]['Keratometry_Value'].values
            if value.size > 0:
                keratometry_matrix[i, j] = value[0]

    # Calculate coefficients, variance explained, and R²
    coefficients, variance_explained, r2, reconstructed_values = calculate_2d_fourier_coefficients(
        unique_meridians, unique_radial_indices, keratometry_matrix, 
        max_meridional_components, max_radial_components
    )

    return coefficients, variance_explained, r2, reconstructed_values

def print_coefficients(coefficients, max_meridional_components, max_radial_components):
    """
    Prints the coefficients in a formatted way.
    """
    print("\nCoefficients:")
    print(f"DC Component (a0): {coefficients['a0']:.6f}")
    
    print("\nMeridional Components:")
    for m in range(1, max_meridional_components + 1):
        am_key = f'am{m}'
        bm_key = f'bm{m}'
        print(f"m={m}:")
        print(f"  {am_key}: {coefficients[am_key]:.6f}")
        print(f"  {bm_key}: {coefficients[bm_key]:.6f}")
    
    print("\nRadial Components:")
    for r in range(1, max_radial_components + 1):
        ar_key = f'ar{r}'
        br_key = f'br{r}'
        print(f"r={r}:")
        print(f"  {ar_key}: {coefficients[ar_key]:.6f}")
        print(f"  {br_key}: {coefficients[br_key]:.6f}")

def main():
    # Load the dataset
    df = pd.read_csv(DATA_PATH)

    # Store all coefficients for comparison
    all_coefficients = []
    all_results = []
    
    # Test different combinations of components
    for meridional_components in range(1, MAX_MERIDIONAL_COMPONENTS + 1):
        for radial_components in range(1, MAX_RADIAL_COMPONENTS + 1):
            print(f"\n{'='*50}")
            print(f"Testing with {meridional_components} meridional and {radial_components} radial components...")
            print('='*50)
            
            coefficients, variance_explained, r2, reconstructed_values = perform_2d_fourier_analysis(
                df, meridional_components, radial_components
            )
            
            # Print coefficients
            print_coefficients(coefficients, meridional_components, radial_components)
            
            # Calculate total variance explained (excluding a0)
            total_variance = sum(value for key, value in variance_explained.items() 
                                if key != 'a0')
            
            # Store results
            all_results.append({
                'meridional_components': meridional_components,
                'radial_components': radial_components,
                'r2_score': r2,
                'total_variance_explained': total_variance
            })
            
            # Store coefficients
            all_coefficients.append({
                'meridional_components': meridional_components,
                'radial_components': radial_components,
                **coefficients
            })
            
            print(f"\nR² Score: {r2:.4f}")
            print(f"Total Variance Explained: {total_variance:.2f}%")
            
            # Print variance explained by each component
            print("\nVariance Explained by Components:")
            for key, value in variance_explained.items():
                print(f"{key}: {value:.2f}%")

    # Create summary DataFrame
    summary_df = pd.DataFrame(all_results)
    print("\nSummary of all component combinations tested:")
    print(summary_df.to_string(index=False))

    # Create coefficients DataFrame
    coeff_df = pd.DataFrame(all_coefficients)
    
    # Save the results
    summary_df.to_csv("fourier_analysis_summary.csv", index=False)
    coeff_df.to_csv("fourier_analysis_coefficients.csv", index=False)
    print("\nResults saved to:")
    print("- fourier_analysis_summary.csv")
    print("- fourier_analysis_coefficients.csv")

if __name__ == "__main__":
    main()

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score
import os
from pathlib import Path
import concurrent.futures
from functools import lru_cache
import multiprocessing
import warnings
warnings.filterwarnings('ignore')

MERIDIONAL_COMPONENTS = 2  
RADIAL_COMPONENTS = 5     
DATA_DIR = "/home/aricept094/mydata/sheets/conv/transformed/"
CHUNK_SIZE = 300  

MAX_WORKERS = max(1, int(multiprocessing.cpu_count() * 0.99))

@lru_cache(maxsize=None)
def calculate_trig_terms(m, n_points):

    angle = 2 * np.pi * m * np.arange(n_points) / n_points
    return np.cos(angle), np.sin(angle)

def reconstruct_signal(coefficients, meridians, radial_indices, max_meridional, max_radial):

    n_meridians = len(meridians)
    n_radial = len(radial_indices)
    reconstructed = np.full((len(radial_indices), len(meridians)), coefficients['a0'])
    
    meridian_indices = np.arange(n_meridians)
    radial_indices_array = np.arange(n_radial)
    
    # Vectorized computation for meridional components
    for m in range(1, max_meridional + 1):
        cos_m, sin_m = calculate_trig_terms(m, n_meridians)
        am_key, bm_key = f'am{m}', f'bm{m}'
        if am_key in coefficients and bm_key in coefficients:
            reconstructed += (coefficients[am_key] * cos_m[None, :] + 
                            coefficients[bm_key] * sin_m[None, :])
    
    # Vectorized computation for radial components
    for r in range(1, max_radial + 1):
        cos_r, sin_r = calculate_trig_terms(r, n_radial)
        ar_key, br_key = f'ar{r}', f'br{r}'
        if ar_key in coefficients and br_key in coefficients:
            reconstructed += (coefficients[ar_key] * cos_r[:, None] + 
                            coefficients[br_key] * sin_r[:, None])
            
    return reconstructed

def calculate_2d_fourier_coefficients(meridians, radial_indices, keratometry_values, max_meridional, max_radial):

    n_meridians = len(meridians)
    n_radial = len(radial_indices)
    coefficients = {}
    energy = {}
    norm_factor = 2 / (n_meridians * n_radial)

    # DC component
    coefficients['a0'] = np.mean(keratometry_values)
    energy['a0'] = coefficients['a0']**2
    total_energy = energy['a0']
    
    # Vectorized meridional components calculation
    for m in range(1, max_meridional + 1):
        cos_m, sin_m = calculate_trig_terms(m, n_meridians)
        cos_term = cos_m[None, :]
        sin_term = sin_m[None, :]
        
        am = norm_factor * np.sum(keratometry_values * cos_term)
        bm = norm_factor * np.sum(keratometry_values * sin_term)
        
        coefficients[f'am{m}'] = am
        coefficients[f'bm{m}'] = bm
        energy[f'am{m}'] = am**2
        energy[f'bm{m}'] = bm**2
        total_energy += am**2 + bm**2

    for r in range(1, max_radial + 1):
        cos_r, sin_r = calculate_trig_terms(r, n_radial)
        cos_term = cos_r[:, None]
        sin_term = sin_r[:, None]
        
        ar = norm_factor * np.sum(keratometry_values * cos_term)
        br = norm_factor * np.sum(keratometry_values * sin_term)
        
        coefficients[f'ar{r}'] = ar
        coefficients[f'br{r}'] = br
        energy[f'ar{r}'] = ar**2
        energy[f'br{r}'] = br**2
        total_energy += ar**2 + br**2

    variance_explained = {k: (v / total_energy) * 100 for k, v in energy.items()}
    
    reconstructed_values = reconstruct_signal(coefficients, meridians, radial_indices, 
                                           max_meridional, max_radial)
    r2 = r2_score(keratometry_values.flatten(), reconstructed_values.flatten())

    return coefficients, variance_explained, r2, reconstructed_values

def perform_2d_fourier_analysis(df):

    meridians = df['Meridian_Index'].unique()
    radial_indices = df['Radial_Index'].unique()
    meridians.sort()
    radial_indices.sort()
    
    # Create lookup dictionaries for faster indexing
    meridian_lookup = {m: i for i, m in enumerate(meridians)}
    radial_lookup = {r: i for i, r in enumerate(radial_indices)}
    
    # Pre-allocate matrix
    keratometry_matrix = np.zeros((len(radial_indices), len(meridians)))
    
    # Vectorized matrix filling
    df_values = df[['Radial_Index', 'Meridian_Index', 'KR_scaled']].values
    for radial, meridian, value in df_values:
        keratometry_matrix[radial_lookup[radial], meridian_lookup[meridian]] = value

    return calculate_2d_fourier_coefficients(
        meridians, radial_indices, keratometry_matrix, 
        MERIDIONAL_COMPONENTS, RADIAL_COMPONENTS
    )

def process_file_chunk(file_chunk):

    results = []
    for csv_file in file_chunk:
        try:
            df = pd.read_csv(csv_file)
            coefficients, variance_explained, r2, _ = perform_2d_fourier_analysis(df)
            
            result = {
                'filename': csv_file.name,
                'r2_score': r2,
                'meridional_components': MERIDIONAL_COMPONENTS,
                'radial_components': RADIAL_COMPONENTS
            }
            result.update({f'coef_{k}': v for k, v in coefficients.items()})
            result.update({f'variance_{k}': v for k, v in variance_explained.items()})
            
            results.append(result)
            print(f"Processed {csv_file.name}: R² = {r2:.4f}")
            
        except Exception as e:
            print(f"Error processing {csv_file.name}: {str(e)}")
            continue
            
    return results

def process_all_files():

    csv_files = list(Path(DATA_DIR).glob("*.csv"))
    chunks = [csv_files[i:i + CHUNK_SIZE] for i in range(0, len(csv_files), CHUNK_SIZE)]
    
    all_results = []
    with concurrent.futures.ProcessPoolExecutor(max_workers=MAX_WORKERS) as executor:
        futures = [executor.submit(process_file_chunk, chunk) for chunk in chunks]
        
        for future in concurrent.futures.as_completed(futures):
            chunk_results = future.result()
            all_results.extend(chunk_results)
    
    if not all_results:
        raise ValueError("No files were processed successfully")
        
    return pd.DataFrame(all_results)

def calculate_combined_coefficients(results_df):

    coef_names = [col for col in results_df.columns if col.startswith('coef_')]
    
    # Calculate Mallows weights based on MSE (1 - R²)
    n_samples = len(results_df)
    mse = 1 - results_df['r2_score'].values  # Convert R² to MSE
    
    # Add small epsilon to prevent division by zero
    epsilon = 1e-10
    mallows_weights = 1 / ((mse + epsilon) * n_samples)
    
    # Normalize weights to sum to 1
    mallows_weights = mallows_weights / np.sum(mallows_weights)
    
    # Apply weights to coefficients using vectorized operations
    coef_values = np.array([results_df[name].values for name in coef_names]).T
    weighted_coefs = coef_values * mallows_weights[:, None]
    combined_values = np.sum(weighted_coefs, axis=0)
    
    # Create dictionary of combined coefficients
    return {name[5:]: value for name, value in zip(coef_names, combined_values)}

def test_combined_model(combined_coefficients):

    csv_files = list(Path(DATA_DIR).glob("*.csv"))
    test_results = []
    
    for csv_file in csv_files:
        try:
            df = pd.read_csv(csv_file)
            meridians = df['Meridian_Index'].unique()
            radial_indices = df['Radial_Index'].unique()
            meridians.sort()
            radial_indices.sort()
            
            meridian_lookup = {m: i for i, m in enumerate(meridians)}
            radial_lookup = {r: i for i, r in enumerate(radial_indices)}
            keratometry_matrix = np.zeros((len(radial_indices), len(meridians)))
            
            df_values = df[['Radial_Index', 'Meridian_Index', 'KR_scaled']].values
            for radial, meridian, value in df_values:
                keratometry_matrix[radial_lookup[radial], meridian_lookup[meridian]] = value
            
            reconstructed_values = reconstruct_signal(
                combined_coefficients, 
                meridians, 
                radial_indices, 
                MERIDIONAL_COMPONENTS,
                RADIAL_COMPONENTS
            )
            
            r2 = r2_score(keratometry_matrix.flatten(), reconstructed_values.flatten())
            
            test_results.append({
                'filename': csv_file.name,
                'r2_score': r2,
                'meridional_components': MERIDIONAL_COMPONENTS,
                'radial_components': RADIAL_COMPONENTS,
                'original_values_mean': np.mean(keratometry_matrix),
                'reconstructed_values_mean': np.mean(reconstructed_values),
                'absolute_error': np.mean(np.abs(keratometry_matrix - reconstructed_values))
            })
            
            print(f"Tested combined model on {csv_file.name}: R² = {r2:.4f}")
            
        except Exception as e:
            print(f"Error testing {csv_file.name}: {str(e)}")
            continue
    
    return pd.DataFrame(test_results)

def main():
    print(f"Starting optimized Fourier analysis using {MAX_WORKERS} processes...")
    print(f"Meridional components: {MERIDIONAL_COMPONENTS}")
    print(f"Radial components: {RADIAL_COMPONENTS}")
    
    try:
        results_df = process_all_files()
        combined_coefs = calculate_combined_coefficients(results_df)
        
        combined_row = {
            'filename': 'COMBINED_MODEL', 
            'r2_score': np.nan,
            'meridional_components': MERIDIONAL_COMPONENTS,
            'radial_components': RADIAL_COMPONENTS
        }
        combined_row.update({f'coef_{k}': v for k, v in combined_coefs.items()})
        combined_row.update({f'variance_{k}': np.nan for k in combined_coefs.keys()})
        
        results_df = pd.concat([results_df, pd.DataFrame([combined_row])], ignore_index=True)
        
        results_df.to_csv("fourier_analysis_results.csv", index=False)
        print("\nInitial results saved to: fourier_analysis_results.csv")
        
        print("\nTesting combined model on all files...")
        test_results_df = test_combined_model(combined_coefs)
        
        test_results_df.to_csv("combined_model_test_results.csv", index=False)
        print("\nTest results saved to: combined_model_test_results.csv")
        
        print(f"\nTraining Summary:")
        print(f"Total files processed: {len(results_df) - 1}")
        print(f"Average Training R² Score: {results_df['r2_score'].iloc[:-1].mean():.4f}")
        
        print(f"\nTesting Summary:")
        print(f"Total files tested: {len(test_results_df)}")
        print(f"Average Test R² Score: {test_results_df['r2_score'].mean():.4f}")
        print(f"Average Absolute Error: {test_results_df['absolute_error'].mean():.4f}")
        
    except Exception as e:
        print(f"Error during analysis: {str(e)}")

if __name__ == "__main__":
    main()

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score
import os
from pathlib import Path
import concurrent.futures
from functools import lru_cache
import multiprocessing
import warnings
warnings.filterwarnings('ignore')

RADIAL_COMPONENTS = 9     
DATA_DIR = "/home/aricept094/mydata/sheets/conv/transformed/"
CHUNK_SIZE = 300  

MAX_WORKERS = max(1, int(multiprocessing.cpu_count() * 0.99))

@lru_cache(maxsize=None)
def calculate_trig_terms(r, n_points):
    """Calculate trigonometric terms for Fourier series."""
    angle = 2 * np.pi * r * np.arange(n_points) / n_points
    return np.cos(angle), np.sin(angle)

def reconstruct_signal(coefficients, radial_indices, max_radial):
    """Reconstruct the signal using 1D Fourier coefficients."""
    n_radial = len(radial_indices)
    reconstructed = np.full(n_radial, coefficients['a0'])
    
    # Vectorized computation for radial components
    for r in range(1, max_radial + 1):
        cos_r, sin_r = calculate_trig_terms(r, n_radial)
        ar_key, br_key = f'ar{r}', f'br{r}'
        if ar_key in coefficients and br_key in coefficients:
            reconstructed += (coefficients[ar_key] * cos_r + 
                            coefficients[br_key] * sin_r)
            
    return reconstructed

def calculate_1d_fourier_coefficients(radial_indices, keratometry_values, max_radial):
    """Calculate 1D Fourier coefficients for radial components."""
    n_radial = len(radial_indices)
    coefficients = {}
    energy = {}
    norm_factor = 2 / n_radial

    # DC component
    coefficients['a0'] = np.mean(keratometry_values)
    energy['a0'] = coefficients['a0']**2
    total_energy = energy['a0']
    
    # Vectorized radial components calculation
    for r in range(1, max_radial + 1):
        cos_r, sin_r = calculate_trig_terms(r, n_radial)
        
        ar = norm_factor * np.sum(keratometry_values * cos_r)
        br = norm_factor * np.sum(keratometry_values * sin_r)
        
        coefficients[f'ar{r}'] = ar
        coefficients[f'br{r}'] = br
        energy[f'ar{r}'] = ar**2
        energy[f'br{r}'] = br**2
        total_energy += ar**2 + br**2

    variance_explained = {k: (v / total_energy) * 100 for k, v in energy.items()}
    
    reconstructed_values = reconstruct_signal(coefficients, radial_indices, max_radial)
    r2 = r2_score(keratometry_values, reconstructed_values)

    return coefficients, variance_explained, r2, reconstructed_values

def perform_1d_fourier_analysis(df):
    """Perform 1D Fourier analysis on the radial data."""
    # Average across meridians for each radial index
    radial_means = df.groupby('Meridian_Index')['Axial_Anterior_Value'].mean()
    radial_indices = np.array(sorted(radial_means.index))
    keratometry_values = radial_means[radial_indices].values

    return calculate_1d_fourier_coefficients(
        radial_indices, keratometry_values, RADIAL_COMPONENTS
    )

def process_file_chunk(file_chunk):
    """Process a chunk of files for 1D Fourier analysis."""
    results = []
    for csv_file in file_chunk:
        try:
            df = pd.read_csv(csv_file)
            coefficients, variance_explained, r2, _ = perform_1d_fourier_analysis(df)
            
            result = {
                'filename': csv_file.name,
                'r2_score': r2,
                'radial_components': RADIAL_COMPONENTS
            }
            result.update({f'coef_{k}': v for k, v in coefficients.items()})
            result.update({f'variance_{k}': v for k, v in variance_explained.items()})
            
            results.append(result)
            print(f"Processed {csv_file.name}: R² = {r2:.4f}")
            
        except Exception as e:
            print(f"Error processing {csv_file.name}: {str(e)}")
            continue
            
    return results

def process_all_files():
    """Process all files in the directory."""
    csv_files = list(Path(DATA_DIR).glob("*.csv"))
    chunks = [csv_files[i:i + CHUNK_SIZE] for i in range(0, len(csv_files), CHUNK_SIZE)]
    
    all_results = []
    with concurrent.futures.ProcessPoolExecutor(max_workers=MAX_WORKERS) as executor:
        futures = [executor.submit(process_file_chunk, chunk) for chunk in chunks]
        
        for future in concurrent.futures.as_completed(futures):
            chunk_results = future.result()
            all_results.extend(chunk_results)
    
    if not all_results:
        raise ValueError("No files were processed successfully")
        
    return pd.DataFrame(all_results)

def calculate_combined_coefficients(results_df):
    """Calculate combined coefficients using Mallows weights."""
    coef_names = [col for col in results_df.columns if col.startswith('coef_')]
    
    # Calculate Mallows weights based on MSE (1 - R²)
    n_samples = len(results_df)
    mse = 1 - results_df['r2_score'].values
    
    # Add small epsilon to prevent division by zero
    epsilon = 1e-10
    mallows_weights = 1 / ((mse + epsilon) * n_samples)
    mallows_weights = mallows_weights / np.sum(mallows_weights)
    
    # Apply weights to coefficients
    coef_values = np.array([results_df[name].values for name in coef_names]).T
    weighted_coefs = coef_values * mallows_weights[:, None]
    combined_values = np.sum(weighted_coefs, axis=0)
    
    return {name[5:]: value for name, value in zip(coef_names, combined_values)}

def test_combined_model(combined_coefficients):
    """Test the combined model on all files."""
    csv_files = list(Path(DATA_DIR).glob("*.csv"))
    test_results = []
    
    for csv_file in csv_files:
        try:
            df = pd.read_csv(csv_file)
            radial_means = df.groupby('Meridian_Index')['Axial_Anterior_Value'].mean()
            radial_indices = np.array(sorted(radial_means.index))
            keratometry_values = radial_means[radial_indices].values
            
            reconstructed_values = reconstruct_signal(
                combined_coefficients, 
                radial_indices,
                RADIAL_COMPONENTS
            )
            
            r2 = r2_score(keratometry_values, reconstructed_values)
            
            test_results.append({
                'filename': csv_file.name,
                'r2_score': r2,
                'radial_components': RADIAL_COMPONENTS,
                'original_values_mean': np.mean(keratometry_values),
                'reconstructed_values_mean': np.mean(reconstructed_values),
                'absolute_error': np.mean(np.abs(keratometry_values - reconstructed_values))
            })
            
            print(f"Tested combined model on {csv_file.name}: R² = {r2:.4f}")
            
        except Exception as e:
            print(f"Error testing {csv_file.name}: {str(e)}")
            continue
    
    return pd.DataFrame(test_results)

def main():
    print(f"Starting optimized 1D Fourier analysis using {MAX_WORKERS} processes...")
    print(f"Radial components: {RADIAL_COMPONENTS}")
    
    try:
        results_df = process_all_files()
        combined_coefs = calculate_combined_coefficients(results_df)
        
        combined_row = {
            'filename': 'COMBINED_MODEL', 
            'r2_score': np.nan,
            'radial_components': RADIAL_COMPONENTS
        }
        combined_row.update({f'coef_{k}': v for k, v in combined_coefs.items()})
        combined_row.update({f'variance_{k}': np.nan for k in combined_coefs.keys()})
        
        results_df = pd.concat([results_df, pd.DataFrame([combined_row])], ignore_index=True)
        
        results_df.to_csv("fourier_analysis_1d_results.csv", index=False)
        print("\nInitial results saved to: fourier_analysis_1d_results.csv")
        
        print("\nTesting combined model on all files...")
        test_results_df = test_combined_model(combined_coefs)
        
        test_results_df.to_csv("combined_model_1d_test_results.csv", index=False)
        print("\nTest results saved to: combined_model_1d_test_results.csv")
        
        print(f"\nTraining Summary:")
        print(f"Total files processed: {len(results_df) - 1}")
        print(f"Average Training R² Score: {results_df['r2_score'].iloc[:-1].mean():.4f}")
        
        print(f"\nTesting Summary:")
        print(f"Total files tested: {len(test_results_df)}")
        print(f"Average Test R² Score: {test_results_df['r2_score'].mean():.4f}")
        print(f"Average Absolute Error: {test_results_df['absolute_error'].mean():.4f}")
        
    except Exception as e:
        print(f"Error during analysis: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# Starting optimized 1D Fourier analysis using 15 processes...
# Radial components: 9
# Processed Sheet421_transformed.csv: R² = 0.9591Processed Sheet50_transformed.csv: R² = 0.9701
#
# Processed Sheet348_transformed.csv: R² = 0.9666Processed Sheet313_transformed.csv: R² = 0.9693
#
# Processed Sheet210_transformed.csv: R² = 0.9640Processed Sheet4_transformed.csv: R² = 0.9688
#
# Processed Sheet90_transformed.csv: R² = 0.9687Processed Sheet264_transformed.csv: R² = 0.9723
#
# Processed Sheet340_transformed.csv: R² = 0.9687Processed Sheet451_transformed.csv: R² = 0.9674
#
# Processed Sheet46_transformed.csv: R² = 0.9713Processed Sheet329_transformed.csv: R² = 0.9676
#
# Processed Sheet182_transformed.csv: R² = 0.9633Processed Sheet372_transformed.csv: R² = 0.9701
#
# Processed Sheet271_transformed.csv: R² = 0.9719Processed Sheet21_transformed.csv: R² = 0.9681
#
# Processed Sheet393_transformed.csv: R² = 0.9672Processed Sheet66_transformed.csv: R² = 0.9719
#
# Processed Sheet122_transformed.csv: R² = 0.9691Processed Sheet409_transformed.csv: R² = 0.9685
#
# Processed Sheet14_transformed.csv: R² = 0.9670Processed Sheet374_transformed.csv: R² = 0.9696
#
# Processed Sheet158_transformed.csv: R² = 0.9685Processed Sheet423_transformed.csv: R² = 0.9727
#
# Processed Sheet316_transformed.csv: R² = 0.9650Processed Sheet230_transformed.csv: R² = 0.9687
#
# Processed Sheet225_transformed.csv: R² = 0.9680Processed Sheet426_transformed.csv: R² = 0.9682
#
# Processed Sheet477_transformed.csv: R² = 0.9682Processed Sheet321_transformed.csv: R² = 0.9660
#
# Processed Sheet429_transformed.csv: R² = 0.9702Processed Sheet352_transformed.csv: R² = 0.9723
#
# Processed Sheet427_transformed.csv: R² = 0.9686Processed Sheet79_transformed.csv: R² = 0.9667
#
# Processed Sheet120_transformed.csv: R² = 0.9716Processed Sheet165_transformed.csv: R² = 0.9637
#
# Processed Sheet290_transformed.csv: R² = 0.9683Processed Sheet272_transformed.csv: R² = 0.9661
#
# Processed Sheet69_transformed.csv: R² = 0.9672Processed Sheet187_transformed.csv: R² = 0.9612
#
# Processed Sheet164_transformed.csv: R² = 0.9696Processed Sheet382_transformed.csv: R² = 0.9709
#
# Processed Sheet474_transformed.csv: R² = 0.9625Processed Sheet178_transformed.csv: R² = 0.9685
#
# Processed Sheet155_transformed.csv: R² = 0.9590
# Processed Sheet246_transformed.csv: R² = 0.9688
# Processed Sheet346_transformed.csv: R² = 0.9562Processed Sheet29_transformed.csv: R² = 0.9682
#
# Processed Sheet282_transformed.csv: R² = 0.9693Processed Sheet8_transformed.csv: R² = 0.9699
#
# Processed Sheet430_transformed.csv: R² = 0.9677Processed Sheet100_transformed.csv: R² = 0.9647
#
# Processed Sheet249_transformed.csv: R² = 0.9632Processed Sheet438_transformed.csv: R² = 0.9707
#
# Processed Sheet356_transformed.csv: R² = 0.9721Processed Sheet326_transformed.csv: R² = 0.9701
#
# Processed Sheet385_transformed.csv: R² = 0.9672Processed Sheet150_transformed.csv: R² = 0.9716
#
# Processed Sheet283_transformed.csv: R² = 0.9672Processed Sheet390_transformed.csv: R² = 0.9670
#
# Processed Sheet305_transformed.csv: R² = 0.9701Processed Sheet233_transformed.csv: R² = 0.9674
#
# Processed Sheet84_transformed.csv: R² = 0.9741Processed Sheet12_transformed.csv: R² = 0.9718
#
# Processed Sheet266_transformed.csv: R² = 0.9713Processed Sheet61_transformed.csv: R² = 0.9653
#
# Processed Sheet23_transformed.csv: R² = 0.9686Processed Sheet435_transformed.csv: R² = 0.9699
#
# Processed Sheet49_transformed.csv: R² = 0.9653Processed Sheet375_transformed.csv: R² = 0.9688
#
# Processed Sheet154_transformed.csv: R² = 0.9619Processed Sheet172_transformed.csv: R² = 0.9751
#
# Processed Sheet202_transformed.csv: R² = 0.9725Processed Sheet432_transformed.csv: R² = 0.9671
#
# Processed Sheet76_transformed.csv: R² = 0.9680Processed Sheet431_transformed.csv: R² = 0.9666
#
# Processed Sheet327_transformed.csv: R² = 0.9704Processed Sheet255_transformed.csv: R² = 0.9699
#
# Processed Sheet125_transformed.csv: R² = 0.9663Processed Sheet392_transformed.csv: R² = 0.9700
#
# Processed Sheet257_transformed.csv: R² = 0.9644Processed Sheet167_transformed.csv: R² = 0.9703
#
# Processed Sheet126_transformed.csv: R² = 0.9693
# Processed Sheet195_transformed.csv: R² = 0.9721
# Processed Sheet462_transformed.csv: R² = 0.9692Processed Sheet337_transformed.csv: R² = 0.9702
#
# Processed Sheet281_transformed.csv: R² = 0.9685Processed Sheet68_transformed.csv: R² = 0.9700
#
# Processed Sheet221_transformed.csv: R² = 0.9702Processed Sheet471_transformed.csv: R² = 0.9691
#
# Processed Sheet33_transformed.csv: R² = 0.9685Processed Sheet318_transformed.csv: R² = 0.9695
#
# Processed Sheet239_transformed.csv: R² = 0.9716Processed Sheet217_transformed.csv: R² = 0.9682
#
# Processed Sheet460_transformed.csv: R² = 0.9725Processed Sheet2_transformed.csv: R² = 0.9654
#
# Processed Sheet24_transformed.csv: R² = 0.9677
# Processed Sheet41_transformed.csv: R² = 0.9689
# Processed Sheet304_transformed.csv: R² = 0.9723Processed Sheet370_transformed.csv: R² = 0.9674
#
# Processed Sheet95_transformed.csv: R² = 0.9639Processed Sheet136_transformed.csv: R² = 0.9693
#
# Processed Sheet357_transformed.csv: R² = 0.9715
# Processed Sheet251_transformed.csv: R² = 0.9693
# Processed Sheet235_transformed.csv: R² = 0.9708Processed Sheet200_transformed.csv: R² = 0.9698
#
# Processed Sheet322_transformed.csv: R² = 0.9714Processed Sheet294_transformed.csv: R² = 0.9692
#
# Processed Sheet20_transformed.csv: R² = 0.9650Processed Sheet355_transformed.csv: R² = 0.9711
#
# Processed Sheet57_transformed.csv: R² = 0.9684Processed Sheet365_transformed.csv: R² = 0.9737
#
# Processed Sheet129_transformed.csv: R² = 0.9623Processed Sheet177_transformed.csv: R² = 0.9670
#
# Processed Sheet62_transformed.csv: R² = 0.9701Processed Sheet472_transformed.csv: R² = 0.9700
#
# Processed Sheet35_transformed.csv: R² = 0.9688Processed Sheet127_transformed.csv: R² = 0.9686
#
# Processed Sheet184_transformed.csv: R² = 0.9646Processed Sheet123_transformed.csv: R² = 0.9678
#
# Processed Sheet44_transformed.csv: R² = 0.9693Processed Sheet301_transformed.csv: R² = 0.9718
#
# Processed Sheet317_transformed.csv: R² = 0.9641Processed Sheet349_transformed.csv: R² = 0.9697
#
# Processed Sheet197_transformed.csv: R² = 0.9673Processed Sheet39_transformed.csv: R² = 0.9720
#
# Processed Sheet156_transformed.csv: R² = 0.9679Processed Sheet22_transformed.csv: R² = 0.9666
#
# Processed Sheet308_transformed.csv: R² = 0.9730
# Processed Sheet131_transformed.csv: R² = 0.9636
# Processed Sheet88_transformed.csv: R² = 0.9653Processed Sheet436_transformed.csv: R² = 0.9697
#
# Processed Sheet245_transformed.csv: R² = 0.9722Processed Sheet413_transformed.csv: R² = 0.9689
#
# Processed Sheet111_transformed.csv: R² = 0.9646Processed Sheet11_transformed.csv: R² = 0.9719
#
# Processed Sheet71_transformed.csv: R² = 0.9660Processed Sheet43_transformed.csv: R² = 0.9717
#
# Processed Sheet60_transformed.csv: R² = 0.9672Processed Sheet65_transformed.csv: R² = 0.9686
#
# Processed Sheet381_transformed.csv: R² = 0.9673
# Processed Sheet238_transformed.csv: R² = 0.9732
# Processed Sheet369_transformed.csv: R² = 0.9631Processed Sheet138_transformed.csv: R² = 0.9655
#
# Processed Sheet81_transformed.csv: R² = 0.9706Processed Sheet171_transformed.csv: R² = 0.9667
#
# Processed Sheet323_transformed.csv: R² = 0.9705Processed Sheet358_transformed.csv: R² = 0.9651
#
# Processed Sheet303_transformed.csv: R² = 0.9677Processed Sheet289_transformed.csv: R² = 0.9704
#
# Processed Sheet458_transformed.csv: R² = 0.9708
# Processed Sheet162_transformed.csv: R² = 0.9669
# Processed Sheet37_transformed.csv: R² = 0.9685
# Processed Sheet470_transformed.csv: R² = 0.9706
# Processed Sheet199_transformed.csv: R² = 0.9691
# Processed Sheet224_transformed.csv: R² = 0.9725
# Processed Sheet361_transformed.csv: R² = 0.9668
# Processed Sheet331_transformed.csv: R² = 0.9684
# Processed Sheet75_transformed.csv: R² = 0.9684
# Processed Sheet137_transformed.csv: R² = 0.9680
# Processed Sheet371_transformed.csv: R² = 0.9685
# Processed Sheet404_transformed.csv: R² = 0.9747
# Processed Sheet209_transformed.csv: R² = 0.9660
# Processed Sheet335_transformed.csv: R² = 0.9718
# Processed Sheet208_transformed.csv: R² = 0.9674
# Processed Sheet293_transformed.csv: R² = 0.9699Processed Sheet218_transformed.csv: R² = 0.9692
#
# Processed Sheet16_transformed.csv: R² = 0.9659Processed Sheet373_transformed.csv: R² = 0.9716
#
# Processed Sheet185_transformed.csv: R² = 0.9657Processed Sheet347_transformed.csv: R² = 0.9628
#
# Processed Sheet391_transformed.csv: R² = 0.9672Processed Sheet479_transformed.csv: R² = 0.9688
#
# Processed Sheet258_transformed.csv: R² = 0.9720Processed Sheet63_transformed.csv: R² = 0.9694
#
# Processed Sheet174_transformed.csv: R² = 0.9721Processed Sheet201_transformed.csv: R² = 0.9682
#
# Processed Sheet145_transformed.csv: R² = 0.9646Processed Sheet441_transformed.csv: R² = 0.9681
#
# Processed Sheet302_transformed.csv: R² = 0.9661Processed Sheet192_transformed.csv: R² = 0.9671
#
# Processed Sheet265_transformed.csv: R² = 0.9745Processed Sheet216_transformed.csv: R² = 0.9643
#
# Processed Sheet256_transformed.csv: R² = 0.9633Processed Sheet344_transformed.csv: R² = 0.9701
#
# Processed Sheet287_transformed.csv: R² = 0.9661Processed Sheet116_transformed.csv: R² = 0.9647
#
# Processed Sheet378_transformed.csv: R² = 0.9770Processed Sheet440_transformed.csv: R² = 0.9686
#
# Processed Sheet226_transformed.csv: R² = 0.9697Processed Sheet277_transformed.csv: R² = 0.9707
#
# Processed Sheet397_transformed.csv: R² = 0.9724Processed Sheet70_transformed.csv: R² = 0.9654
#
# Processed Sheet407_transformed.csv: R² = 0.9700Processed Sheet173_transformed.csv: R² = 0.9765
#
# Processed Sheet398_transformed.csv: R² = 0.9657Processed Sheet248_transformed.csv: R² = 0.9651
#
# Processed Sheet345_transformed.csv: R² = 0.9707Processed Sheet424_transformed.csv: R² = 0.9699
#
# Processed Sheet92_transformed.csv: R² = 0.9697Processed Sheet400_transformed.csv: R² = 0.9692
#
# Processed Sheet128_transformed.csv: R² = 0.9601Processed Sheet469_transformed.csv: R² = 0.9706
#
# Processed Sheet343_transformed.csv: R² = 0.9722Processed Sheet259_transformed.csv: R² = 0.9728
#
# Processed Sheet45_transformed.csv: R² = 0.9684Processed Sheet292_transformed.csv: R² = 0.9694
#
# Processed Sheet330_transformed.csv: R² = 0.9678Processed Sheet26_transformed.csv: R² = 0.9671
#
# Processed Sheet481_transformed.csv: R² = 0.9693Processed Sheet96_transformed.csv: R² = 0.9687
#
# Processed Sheet108_transformed.csv: R² = 0.9676Processed Sheet212_transformed.csv: R² = 0.9623
#
# Processed Sheet64_transformed.csv: R² = 0.9682Processed Sheet40_transformed.csv: R² = 0.9704
#
# Processed Sheet443_transformed.csv: R² = 0.9708Processed Sheet244_transformed.csv: R² = 0.9702
#
# Processed Sheet425_transformed.csv: R² = 0.9714Processed Sheet67_transformed.csv: R² = 0.9712
#
# Processed Sheet149_transformed.csv: R² = 0.9667Processed Sheet186_transformed.csv: R² = 0.9672
#
# Processed Sheet368_transformed.csv: R² = 0.9702Processed Sheet457_transformed.csv: R² = 0.9645
#
# Processed Sheet152_transformed.csv: R² = 0.9699Processed Sheet148_transformed.csv: R² = 0.9661
#
# Processed Sheet433_transformed.csv: R² = 0.9679
# Processed Sheet416_transformed.csv: R² = 0.9703
# Processed Sheet267_transformed.csv: R² = 0.9699
# Processed Sheet134_transformed.csv: R² = 0.9781
# Processed Sheet151_transformed.csv: R² = 0.9721Processed Sheet351_transformed.csv: R² = 0.9687
#
# Processed Sheet159_transformed.csv: R² = 0.9669Processed Sheet47_transformed.csv: R² = 0.9646
#
# Processed Sheet276_transformed.csv: R² = 0.9699Processed Sheet439_transformed.csv: R² = 0.9686
#
# Processed Sheet229_transformed.csv: R² = 0.9727Processed Sheet428_transformed.csv: R² = 0.9691
#
# Processed Sheet247_transformed.csv: R² = 0.9710Processed Sheet231_transformed.csv: R² = 0.9660
#
# Processed Sheet324_transformed.csv: R² = 0.9706Processed Sheet232_transformed.csv: R² = 0.9693
#
# Processed Sheet6_transformed.csv: R² = 0.9632Processed Sheet110_transformed.csv: R² = 0.9665
#
# Processed Sheet485_transformed.csv: R² = 0.9738Processed Sheet273_transformed.csv: R² = 0.9668
#
# Processed Sheet83_transformed.csv: R² = 0.9706Processed Sheet274_transformed.csv: R² = 0.9712
#
# Processed Sheet243_transformed.csv: R² = 0.9725Processed Sheet236_transformed.csv: R² = 0.9705
#
# Processed Sheet55_transformed.csv: R² = 0.9712Processed Sheet234_transformed.csv: R² = 0.9726
#
# Processed Sheet459_transformed.csv: R² = 0.9711Processed Sheet17_transformed.csv: R² = 0.9632
#
# Processed Sheet119_transformed.csv: R² = 0.9693Processed Sheet338_transformed.csv: R² = 0.9663
#
# Processed Sheet354_transformed.csv: R² = 0.9699Processed Sheet181_transformed.csv: R² = 0.9714
#
# Processed Sheet114_transformed.csv: R² = 0.9669Processed Sheet133_transformed.csv: R² = 0.9685
#
# Processed Sheet198_transformed.csv: R² = 0.9676Processed Sheet15_transformed.csv: R² = 0.9692
#
# Processed Sheet270_transformed.csv: R² = 0.9711
# Processed Sheet98_transformed.csv: R² = 0.9738
# Processed Sheet339_transformed.csv: R² = 0.9651
# Processed Sheet105_transformed.csv: R² = 0.9699
# Processed Sheet362_transformed.csv: R² = 0.9718Processed Sheet59_transformed.csv: R² = 0.9646
#
# Processed Sheet102_transformed.csv: R² = 0.9679Processed Sheet296_transformed.csv: R² = 0.9674
#
# Processed Sheet85_transformed.csv: R² = 0.9740Processed Sheet206_transformed.csv: R² = 0.9687
#
# Processed Sheet444_transformed.csv: R² = 0.9706Processed Sheet118_transformed.csv: R² = 0.9674
#
# Processed Sheet405_transformed.csv: R² = 0.9743Processed Sheet222_transformed.csv: R² = 0.9654
#
# Processed Sheet112_transformed.csv: R² = 0.9706Processed Sheet311_transformed.csv: R² = 0.9660
#
# Processed Sheet482_transformed.csv: R² = 0.9699Processed Sheet77_transformed.csv: R² = 0.9707
#
# Processed Sheet325_transformed.csv: R² = 0.9725Processed Sheet394_transformed.csv: R² = 0.9714
#
# Processed Sheet402_transformed.csv: R² = 0.9705Processed Sheet300_transformed.csv: R² = 0.9721
#
# Processed Sheet10_transformed.csv: R² = 0.9683Processed Sheet253_transformed.csv: R² = 0.9679
#
# Processed Sheet418_transformed.csv: R² = 0.9659
# Processed Sheet28_transformed.csv: R² = 0.9643
# Processed Sheet240_transformed.csv: R² = 0.9684
# Processed Sheet176_transformed.csv: R² = 0.9709
# Processed Sheet278_transformed.csv: R² = 0.9641Processed Sheet466_transformed.csv: R² = 0.9694
#
# Processed Sheet315_transformed.csv: R² = 0.9668Processed Sheet113_transformed.csv: R² = 0.9695
#
# Processed Sheet307_transformed.csv: R² = 0.9708Processed Sheet450_transformed.csv: R² = 0.9669
#
# Processed Sheet241_transformed.csv: R² = 0.9686Processed Sheet342_transformed.csv: R² = 0.9718
#
# Processed Sheet363_transformed.csv: R² = 0.9665Processed Sheet288_transformed.csv: R² = 0.9614
#
# Processed Sheet455_transformed.csv: R² = 0.9674Processed Sheet74_transformed.csv: R² = 0.9662
#
# Processed Sheet275_transformed.csv: R² = 0.9717Processed Sheet34_transformed.csv: R² = 0.9675
#
# Processed Sheet48_transformed.csv: R² = 0.9672Processed Sheet179_transformed.csv: R² = 0.9720
#
# Processed Sheet468_transformed.csv: R² = 0.9698Processed Sheet387_transformed.csv: R² = 0.9666
#
# Processed Sheet94_transformed.csv: R² = 0.9661Processed Sheet121_transformed.csv: R² = 0.9708
#
# Processed Sheet254_transformed.csv: R² = 0.9688Processed Sheet147_transformed.csv: R² = 0.9703
#
# Processed Sheet473_transformed.csv: R² = 0.9716Processed Sheet115_transformed.csv: R² = 0.9707
#
# Processed Sheet475_transformed.csv: R² = 0.9659Processed Sheet445_transformed.csv: R² = 0.9707
#
# Processed Sheet454_transformed.csv: R² = 0.9726Processed Sheet203_transformed.csv: R² = 0.9691
#
# Processed Sheet350_transformed.csv: R² = 0.9691Processed Sheet36_transformed.csv: R² = 0.9677
#
# Processed Sheet82_transformed.csv: R² = 0.9666Processed Sheet53_transformed.csv: R² = 0.9686
#
# Processed Sheet367_transformed.csv: R² = 0.9673Processed Sheet135_transformed.csv: R² = 0.9725
#
# Processed Sheet78_transformed.csv: R² = 0.9658Processed Sheet214_transformed.csv: R² = 0.9707
#
# Processed Sheet295_transformed.csv: R² = 0.9690Processed Sheet334_transformed.csv: R² = 0.9721
#
# Processed Sheet384_transformed.csv: R² = 0.9680Processed Sheet279_transformed.csv: R² = 0.9630
#
# Processed Sheet106_transformed.csv: R² = 0.9683Processed Sheet437_transformed.csv: R² = 0.9681
#
# Processed Sheet386_transformed.csv: R² = 0.9632Processed Sheet180_transformed.csv: R² = 0.9677
#
# Processed Sheet310_transformed.csv: R² = 0.9679
# Processed Sheet366_transformed.csv: R² = 0.9661
# Processed Sheet336_transformed.csv: R² = 0.9706Processed Sheet360_transformed.csv: R² = 0.9649
#
# Processed Sheet101_transformed.csv: R² = 0.9655Processed Sheet447_transformed.csv: R² = 0.9719
#
# Processed Sheet328_transformed.csv: R² = 0.9681Processed Sheet280_transformed.csv: R² = 0.9682
#
# Processed Sheet9_transformed.csv: R² = 0.9673Processed Sheet359_transformed.csv: R² = 0.9656
#
# Processed Sheet89_transformed.csv: R² = 0.9694Processed Sheet219_transformed.csv: R² = 0.9684
#
# Processed Sheet207_transformed.csv: R² = 0.9713
# Processed Sheet268_transformed.csv: R² = 0.9700
# Processed Sheet132_transformed.csv: R² = 0.9693
# Processed Sheet157_transformed.csv: R² = 0.9683
# Processed Sheet103_transformed.csv: R² = 0.9660
# Processed Sheet188_transformed.csv: R² = 0.9674
# Processed Sheet166_transformed.csv: R² = 0.9712
# Processed Sheet332_transformed.csv: R² = 0.9687
# Processed Sheet220_transformed.csv: R² = 0.9699Processed Sheet205_transformed.csv: R² = 0.9706
#
# Processed Sheet27_transformed.csv: R² = 0.9675
# Processed Sheet196_transformed.csv: R² = 0.9657
# Processed Sheet72_transformed.csv: R² = 0.9715
# Processed Sheet312_transformed.csv: R² = 0.9688
# Processed Sheet146_transformed.csv: R² = 0.9690
# Processed Sheet87_transformed.csv: R² = 0.9673
# Processed Sheet175_transformed.csv: R² = 0.9710
# Processed Sheet285_transformed.csv: R² = 0.9691
# Processed Sheet478_transformed.csv: R² = 0.9690
# Processed Sheet7_transformed.csv: R² = 0.9635
# Processed Sheet252_transformed.csv: R² = 0.9690
# Processed Sheet91_transformed.csv: R² = 0.9695
# Processed Sheet56_transformed.csv: R² = 0.9693
# Processed Sheet142_transformed.csv: R² = 0.9694
# Processed Sheet160_transformed.csv: R² = 0.9614
# Processed Sheet284_transformed.csv: R² = 0.9698
# Processed Sheet463_transformed.csv: R² = 0.9719
# Processed Sheet5_transformed.csv: R² = 0.9710
# Processed Sheet58_transformed.csv: R² = 0.9713
# Processed Sheet97_transformed.csv: R² = 0.9711
# Processed Sheet153_transformed.csv: R² = 0.9721
# Processed Sheet242_transformed.csv: R² = 0.9741
# Processed Sheet417_transformed.csv: R² = 0.9686
# Processed Sheet163_transformed.csv: R² = 0.9683
# Processed Sheet461_transformed.csv: R² = 0.9718
# Processed Sheet211_transformed.csv: R² = 0.9650
# Processed Sheet168_transformed.csv: R² = 0.9642
# Processed Sheet448_transformed.csv: R² = 0.9627
# Processed Sheet262_transformed.csv: R² = 0.9681
# Processed Sheet86_transformed.csv: R² = 0.9699
# Processed Sheet434_transformed.csv: R² = 0.9707
# Processed Sheet13_transformed.csv: R² = 0.9714
# Processed Sheet401_transformed.csv: R² = 0.9662
# Processed Sheet30_transformed.csv: R² = 0.9691
# Processed Sheet412_transformed.csv: R² = 0.9666
# Processed Sheet286_transformed.csv: R² = 0.9661
# Processed Sheet399_transformed.csv: R² = 0.9673
# Processed Sheet341_transformed.csv: R² = 0.9711
# Processed Sheet260_transformed.csv: R² = 0.9643
# Processed Sheet161_transformed.csv: R² = 0.9704
# Processed Sheet483_transformed.csv: R² = 0.9681
# Processed Sheet213_transformed.csv: R² = 0.9636
# Processed Sheet403_transformed.csv: R² = 0.9662
# Processed Sheet117_transformed.csv: R² = 0.9685
# Processed Sheet18_transformed.csv: R² = 0.9638
# Processed Sheet380_transformed.csv: R² = 0.9728
# Processed Sheet144_transformed.csv: R² = 0.9657
# Processed Sheet73_transformed.csv: R² = 0.9711
# Processed Sheet263_transformed.csv: R² = 0.9704
# Processed Sheet170_transformed.csv: R² = 0.9656
# Processed Sheet261_transformed.csv: R² = 0.9656
# Processed Sheet299_transformed.csv: R² = 0.9689
# Processed Sheet410_transformed.csv: R² = 0.9703
# Processed Sheet406_transformed.csv: R² = 0.9674
# Processed Sheet452_transformed.csv: R² = 0.9730
# Processed Sheet193_transformed.csv: R² = 0.9721
# Processed Sheet411_transformed.csv: R² = 0.9696
# Processed Sheet190_transformed.csv: R² = 0.9663
# Processed Sheet32_transformed.csv: R² = 0.9662
# Processed Sheet298_transformed.csv: R² = 0.9669
# Processed Sheet467_transformed.csv: R² = 0.9710
# Processed Sheet139_transformed.csv: R² = 0.9664
# Processed Sheet389_transformed.csv: R² = 0.9608
# Processed Sheet446_transformed.csv: R² = 0.9739
# Processed Sheet25_transformed.csv: R² = 0.9718
# Processed Sheet215_transformed.csv: R² = 0.9697
# Processed Sheet54_transformed.csv: R² = 0.9719
# Processed Sheet52_transformed.csv: R² = 0.9682
# Processed Sheet383_transformed.csv: R² = 0.9643
# Processed Sheet314_transformed.csv: R² = 0.9641
# Processed Sheet306_transformed.csv: R² = 0.9681
# Processed Sheet377_transformed.csv: R² = 0.9709
# Processed Sheet484_transformed.csv: R² = 0.9737
# Processed Sheet194_transformed.csv: R² = 0.9727
# Processed Sheet408_transformed.csv: R² = 0.9664
# Processed Sheet379_transformed.csv: R² = 0.9719
# Processed Sheet228_transformed.csv: R² = 0.9729
# Processed Sheet191_transformed.csv: R² = 0.9633
# Processed Sheet107_transformed.csv: R² = 0.9670
# Processed Sheet376_transformed.csv: R² = 0.9700
# Processed Sheet476_transformed.csv: R² = 0.9692
# Processed Sheet414_transformed.csv: R² = 0.9693
# Processed Sheet320_transformed.csv: R² = 0.9681
# Processed Sheet130_transformed.csv: R² = 0.9623
# Processed Sheet333_transformed.csv: R² = 0.9688
# Processed Sheet465_transformed.csv: R² = 0.9605
# Processed Sheet250_transformed.csv: R² = 0.9675
# Processed Sheet464_transformed.csv: R² = 0.9600
# Processed Sheet269_transformed.csv: R² = 0.9707
# Processed Sheet19_transformed.csv: R² = 0.9625
# Processed Sheet204_transformed.csv: R² = 0.9712
# Processed Sheet309_transformed.csv: R² = 0.9741
# Processed Sheet31_transformed.csv: R² = 0.9694
# Processed Sheet38_transformed.csv: R² = 0.9749
# Processed Sheet422_transformed.csv: R² = 0.9723
# Processed Sheet143_transformed.csv: R² = 0.9702
# Processed Sheet364_transformed.csv: R² = 0.9804
# Processed Sheet291_transformed.csv: R² = 0.9699
# Processed Sheet415_transformed.csv: R² = 0.9689
# Processed Sheet140_transformed.csv: R² = 0.9749
# Processed Sheet99_transformed.csv: R² = 0.9732
# Processed Sheet93_transformed.csv: R² = 0.9694
# Processed Sheet353_transformed.csv: R² = 0.9707
# Processed Sheet223_transformed.csv: R² = 0.9675
# Processed Sheet480_transformed.csv: R² = 0.9689
# Processed Sheet420_transformed.csv: R² = 0.9649
# Processed Sheet456_transformed.csv: R² = 0.9641
# Processed Sheet319_transformed.csv: R² = 0.9670
# Processed Sheet141_transformed.csv: R² = 0.9748
# Processed Sheet419_transformed.csv: R² = 0.9673
# Processed Sheet388_transformed.csv: R² = 0.9587
# Processed Sheet442_transformed.csv: R² = 0.9705
# Processed Sheet453_transformed.csv: R² = 0.9701
# Processed Sheet297_transformed.csv: R² = 0.9673
# Processed Sheet227_transformed.csv: R² = 0.9668
# Processed Sheet449_transformed.csv: R² = 0.9631
# Processed Sheet183_transformed.csv: R² = 0.9666
# Processed Sheet396_transformed.csv: R² = 0.9802
# Processed Sheet80_transformed.csv: R² = 0.9720
# Processed Sheet109_transformed.csv: R² = 0.9710
# Processed Sheet169_transformed.csv: R² = 0.9638
# Processed Sheet395_transformed.csv: R² = 0.9708
# Processed Sheet3_transformed.csv: R² = 0.9660
# Processed Sheet189_transformed.csv: R² = 0.9705
# Processed Sheet124_transformed.csv: R² = 0.9667
# Processed Sheet42_transformed.csv: R² = 0.9669
# Processed Sheet51_transformed.csv: R² = 0.9694
#
# Initial results saved to: fourier_analysis_1d_results.csv
#
# Testing combined model on all files...
# Tested combined model on Sheet421_transformed.csv: R² = 0.9459
# Tested combined model on Sheet313_transformed.csv: R² = 0.9632
# Tested combined model on Sheet4_transformed.csv: R² = 0.9650
# Tested combined model on Sheet264_transformed.csv: R² = 0.9677
# Tested combined model on Sheet340_transformed.csv: R² = 0.9652
# Tested combined model on Sheet329_transformed.csv: R² = 0.9600
# Tested combined model on Sheet372_transformed.csv: R² = 0.9642
# Tested combined model on Sheet21_transformed.csv: R² = 0.9665
# Tested combined model on Sheet66_transformed.csv: R² = 0.9640
# Tested combined model on Sheet122_transformed.csv: R² = 0.9613
# Tested combined model on Sheet14_transformed.csv: R² = 0.9531
# Tested combined model on Sheet423_transformed.csv: R² = 0.9560
# Tested combined model on Sheet316_transformed.csv: R² = 0.9537
# Tested combined model on Sheet225_transformed.csv: R² = 0.9665
# Tested combined model on Sheet477_transformed.csv: R² = 0.9666
# Tested combined model on Sheet429_transformed.csv: R² = 0.9573
# Tested combined model on Sheet427_transformed.csv: R² = 0.9666
# Tested combined model on Sheet165_transformed.csv: R² = 0.9509
# Tested combined model on Sheet290_transformed.csv: R² = 0.9664
# Tested combined model on Sheet69_transformed.csv: R² = 0.9489
# Tested combined model on Sheet164_transformed.csv: R² = 0.9692
# Tested combined model on Sheet474_transformed.csv: R² = 0.9538
# Tested combined model on Sheet155_transformed.csv: R² = 0.9370
# Tested combined model on Sheet29_transformed.csv: R² = 0.9652
# Tested combined model on Sheet282_transformed.csv: R² = 0.9673
# Tested combined model on Sheet430_transformed.csv: R² = 0.9657
# Tested combined model on Sheet249_transformed.csv: R² = 0.9553
# Tested combined model on Sheet356_transformed.csv: R² = 0.9617
# Tested combined model on Sheet385_transformed.csv: R² = 0.9564
# Tested combined model on Sheet283_transformed.csv: R² = 0.9654
# Tested combined model on Sheet233_transformed.csv: R² = 0.9624
# Tested combined model on Sheet12_transformed.csv: R² = 0.9616
# Tested combined model on Sheet61_transformed.csv: R² = 0.9587
# Tested combined model on Sheet435_transformed.csv: R² = 0.9500
# Tested combined model on Sheet49_transformed.csv: R² = 0.9587
# Tested combined model on Sheet172_transformed.csv: R² = 0.9704
# Tested combined model on Sheet202_transformed.csv: R² = 0.9668
# Tested combined model on Sheet431_transformed.csv: R² = 0.9650
# Tested combined model on Sheet255_transformed.csv: R² = 0.9642
# Tested combined model on Sheet125_transformed.csv: R² = 0.9652
# Tested combined model on Sheet167_transformed.csv: R² = 0.9663
# Tested combined model on Sheet195_transformed.csv: R² = 0.9454
# Tested combined model on Sheet462_transformed.csv: R² = 0.9648
# Tested combined model on Sheet281_transformed.csv: R² = 0.9667
# Tested combined model on Sheet221_transformed.csv: R² = 0.9651
# Tested combined model on Sheet33_transformed.csv: R² = 0.9667
# Tested combined model on Sheet217_transformed.csv: R² = 0.9652
# Tested combined model on Sheet460_transformed.csv: R² = 0.9389
# Tested combined model on Sheet41_transformed.csv: R² = 0.9662
# Tested combined model on Sheet304_transformed.csv: R² = 0.9677
# Tested combined model on Sheet95_transformed.csv: R² = 0.9598
# Tested combined model on Sheet357_transformed.csv: R² = 0.9579
# Tested combined model on Sheet235_transformed.csv: R² = 0.9630
# Tested combined model on Sheet322_transformed.csv: R² = 0.9647
# Tested combined model on Sheet20_transformed.csv: R² = 0.9619
# Tested combined model on Sheet57_transformed.csv: R² = 0.9670
# Tested combined model on Sheet129_transformed.csv: R² = 0.9064
# Tested combined model on Sheet472_transformed.csv: R² = 0.9670
# Tested combined model on Sheet35_transformed.csv: R² = 0.9587
# Tested combined model on Sheet123_transformed.csv: R² = 0.9628
# Tested combined model on Sheet44_transformed.csv: R² = 0.9675
# Tested combined model on Sheet317_transformed.csv: R² = 0.9540
# Tested combined model on Sheet197_transformed.csv: R² = 0.9650
# Tested combined model on Sheet22_transformed.csv: R² = 0.9508
# Tested combined model on Sheet131_transformed.csv: R² = 0.9560
# Tested combined model on Sheet88_transformed.csv: R² = 0.9537
# Tested combined model on Sheet245_transformed.csv: R² = 0.9537
# Tested combined model on Sheet111_transformed.csv: R² = 0.9614
# Tested combined model on Sheet43_transformed.csv: R² = 0.9695
# Tested combined model on Sheet60_transformed.csv: R² = 0.9566
# Tested combined model on Sheet238_transformed.csv: R² = 0.9665
# Tested combined model on Sheet369_transformed.csv: R² = 0.9522
# Tested combined model on Sheet81_transformed.csv: R² = 0.9679
# Tested combined model on Sheet358_transformed.csv: R² = 0.9468
# Tested combined model on Sheet289_transformed.csv: R² = 0.9694
# Tested combined model on Sheet458_transformed.csv: R² = 0.9612
# Tested combined model on Sheet37_transformed.csv: R² = 0.9656
# Tested combined model on Sheet199_transformed.csv: R² = 0.9662
# Tested combined model on Sheet361_transformed.csv: R² = 0.9574
# Tested combined model on Sheet75_transformed.csv: R² = 0.9644
# Tested combined model on Sheet371_transformed.csv: R² = 0.9668
# Tested combined model on Sheet209_transformed.csv: R² = 0.9578
# Tested combined model on Sheet208_transformed.csv: R² = 0.9659
# Tested combined model on Sheet218_transformed.csv: R² = 0.9601
# Tested combined model on Sheet373_transformed.csv: R² = 0.9645
# Tested combined model on Sheet185_transformed.csv: R² = 0.9450
# Tested combined model on Sheet479_transformed.csv: R² = 0.9636
# Tested combined model on Sheet63_transformed.csv: R² = 0.9683
# Tested combined model on Sheet174_transformed.csv: R² = 0.9630
# Tested combined model on Sheet441_transformed.csv: R² = 0.9651
# Tested combined model on Sheet302_transformed.csv: R² = 0.9576
# Tested combined model on Sheet216_transformed.csv: R² = 0.9538
# Tested combined model on Sheet344_transformed.csv: R² = 0.9650
# Tested combined model on Sheet116_transformed.csv: R² = 0.9557
# Tested combined model on Sheet378_transformed.csv: R² = 0.9424
# Tested combined model on Sheet277_transformed.csv: R² = 0.9682
# Tested combined model on Sheet397_transformed.csv: R² = 0.9547
# Tested combined model on Sheet173_transformed.csv: R² = 0.9618
# Tested combined model on Sheet398_transformed.csv: R² = 0.9626
# Tested combined model on Sheet345_transformed.csv: R² = 0.9648
# Tested combined model on Sheet92_transformed.csv: R² = 0.9625
# Tested combined model on Sheet128_transformed.csv: R² = 0.9110
# Tested combined model on Sheet259_transformed.csv: R² = 0.9609
# Tested combined model on Sheet292_transformed.csv: R² = 0.9612
# Tested combined model on Sheet330_transformed.csv: R² = 0.9630
# Tested combined model on Sheet481_transformed.csv: R² = 0.9592
# Tested combined model on Sheet108_transformed.csv: R² = 0.9494
# Tested combined model on Sheet40_transformed.csv: R² = 0.9674
# Tested combined model on Sheet244_transformed.csv: R² = 0.9569
# Tested combined model on Sheet67_transformed.csv: R² = 0.9620
# Tested combined model on Sheet149_transformed.csv: R² = 0.9451
# Tested combined model on Sheet368_transformed.csv: R² = 0.9437
# Tested combined model on Sheet152_transformed.csv: R² = 0.9687
# Tested combined model on Sheet416_transformed.csv: R² = 0.9689
# Tested combined model on Sheet134_transformed.csv: R² = 0.9668
# Tested combined model on Sheet151_transformed.csv: R² = 0.9567
# Tested combined model on Sheet47_transformed.csv: R² = 0.9310
# Tested combined model on Sheet276_transformed.csv: R² = 0.9650
# Tested combined model on Sheet428_transformed.csv: R² = 0.9633
# Tested combined model on Sheet231_transformed.csv: R² = 0.9559
# Tested combined model on Sheet324_transformed.csv: R² = 0.9629
# Tested combined model on Sheet6_transformed.csv: R² = 0.9398
# Tested combined model on Sheet273_transformed.csv: R² = 0.9455
# Tested combined model on Sheet83_transformed.csv: R² = 0.9682
# Tested combined model on Sheet243_transformed.csv: R² = 0.9699
# Tested combined model on Sheet55_transformed.csv: R² = 0.9620
# Tested combined model on Sheet17_transformed.csv: R² = 0.9490
# Tested combined model on Sheet338_transformed.csv: R² = 0.9562
# Tested combined model on Sheet181_transformed.csv: R² = 0.9375
# Tested combined model on Sheet133_transformed.csv: R² = 0.9591
# Tested combined model on Sheet198_transformed.csv: R² = 0.9645
# Tested combined model on Sheet98_transformed.csv: R² = 0.9485
# Tested combined model on Sheet105_transformed.csv: R² = 0.9691
# Tested combined model on Sheet59_transformed.csv: R² = 0.9310
# Tested combined model on Sheet102_transformed.csv: R² = 0.9656
# Tested combined model on Sheet206_transformed.csv: R² = 0.9677
# Tested combined model on Sheet444_transformed.csv: R² = 0.9629
# Tested combined model on Sheet405_transformed.csv: R² = 0.9565
# Tested combined model on Sheet311_transformed.csv: R² = 0.9587
# Tested combined model on Sheet77_transformed.csv: R² = 0.9669
# Tested combined model on Sheet325_transformed.csv: R² = 0.9648
# Tested combined model on Sheet300_transformed.csv: R² = 0.9686
# Tested combined model on Sheet253_transformed.csv: R² = 0.9542
# Tested combined model on Sheet28_transformed.csv: R² = 0.9538
# Tested combined model on Sheet176_transformed.csv: R² = 0.9688
# Tested combined model on Sheet278_transformed.csv: R² = 0.9600
# Tested combined model on Sheet315_transformed.csv: R² = 0.9622
# Tested combined model on Sheet450_transformed.csv: R² = 0.9629
# Tested combined model on Sheet241_transformed.csv: R² = 0.9614
# Tested combined model on Sheet363_transformed.csv: R² = 0.9584
# Tested combined model on Sheet455_transformed.csv: R² = 0.9637
# Tested combined model on Sheet34_transformed.csv: R² = 0.9610
# Tested combined model on Sheet48_transformed.csv: R² = 0.9566
# Tested combined model on Sheet468_transformed.csv: R² = 0.9692
# Tested combined model on Sheet94_transformed.csv: R² = 0.9632
# Tested combined model on Sheet147_transformed.csv: R² = 0.9620
# Tested combined model on Sheet115_transformed.csv: R² = 0.9687
# Tested combined model on Sheet445_transformed.csv: R² = 0.9642
# Tested combined model on Sheet203_transformed.csv: R² = 0.9642
# Tested combined model on Sheet350_transformed.csv: R² = 0.9618
# Tested combined model on Sheet82_transformed.csv: R² = 0.9629
# Tested combined model on Sheet135_transformed.csv: R² = 0.9700
# Tested combined model on Sheet78_transformed.csv: R² = 0.9597
# Tested combined model on Sheet295_transformed.csv: R² = 0.9678
# Tested combined model on Sheet384_transformed.csv: R² = 0.9593
# Tested combined model on Sheet437_transformed.csv: R² = 0.9656
# Tested combined model on Sheet386_transformed.csv: R² = 0.9519
# Tested combined model on Sheet310_transformed.csv: R² = 0.9645
# Tested combined model on Sheet336_transformed.csv: R² = 0.9677
# Tested combined model on Sheet101_transformed.csv: R² = 0.9446
# Tested combined model on Sheet280_transformed.csv: R² = 0.9667
# Tested combined model on Sheet9_transformed.csv: R² = 0.9661
# Tested combined model on Sheet89_transformed.csv: R² = 0.9601
# Tested combined model on Sheet207_transformed.csv: R² = 0.9683
# Tested combined model on Sheet132_transformed.csv: R² = 0.9652
# Tested combined model on Sheet103_transformed.csv: R² = 0.9634
# Tested combined model on Sheet166_transformed.csv: R² = 0.9605
# Tested combined model on Sheet220_transformed.csv: R² = 0.9674
# Tested combined model on Sheet196_transformed.csv: R² = 0.9626
# Tested combined model on Sheet312_transformed.csv: R² = 0.9633
# Tested combined model on Sheet87_transformed.csv: R² = 0.9661
# Tested combined model on Sheet285_transformed.csv: R² = 0.9683
# Tested combined model on Sheet7_transformed.csv: R² = 0.9365
# Tested combined model on Sheet252_transformed.csv: R² = 0.9614
# Tested combined model on Sheet91_transformed.csv: R² = 0.9670
# Tested combined model on Sheet56_transformed.csv: R² = 0.9675
# Tested combined model on Sheet142_transformed.csv: R² = 0.9668
# Tested combined model on Sheet160_transformed.csv: R² = 0.9533
# Tested combined model on Sheet284_transformed.csv: R² = 0.9686
# Tested combined model on Sheet463_transformed.csv: R² = 0.9662
# Tested combined model on Sheet5_transformed.csv: R² = 0.9662
# Tested combined model on Sheet58_transformed.csv: R² = 0.9456
# Tested combined model on Sheet97_transformed.csv: R² = 0.9671
# Tested combined model on Sheet153_transformed.csv: R² = 0.9695
# Tested combined model on Sheet242_transformed.csv: R² = 0.9682
# Tested combined model on Sheet417_transformed.csv: R² = 0.9670
# Tested combined model on Sheet163_transformed.csv: R² = 0.9567
# Tested combined model on Sheet461_transformed.csv: R² = 0.9394
# Tested combined model on Sheet211_transformed.csv: R² = 0.9603
# Tested combined model on Sheet168_transformed.csv: R² = 0.9366
# Tested combined model on Sheet448_transformed.csv: R² = 0.9522
# Tested combined model on Sheet262_transformed.csv: R² = 0.9585
# Tested combined model on Sheet86_transformed.csv: R² = 0.9659
# Tested combined model on Sheet434_transformed.csv: R² = 0.9583
# Tested combined model on Sheet13_transformed.csv: R² = 0.9661
# Tested combined model on Sheet401_transformed.csv: R² = 0.9579
# Tested combined model on Sheet30_transformed.csv: R² = 0.9661
# Tested combined model on Sheet412_transformed.csv: R² = 0.9525
# Tested combined model on Sheet286_transformed.csv: R² = 0.9430
# Tested combined model on Sheet399_transformed.csv: R² = 0.9650
# Tested combined model on Sheet341_transformed.csv: R² = 0.9671
# Tested combined model on Sheet260_transformed.csv: R² = 0.9596
# Tested combined model on Sheet161_transformed.csv: R² = 0.9694
# Tested combined model on Sheet483_transformed.csv: R² = 0.9631
# Tested combined model on Sheet213_transformed.csv: R² = 0.9560
# Tested combined model on Sheet403_transformed.csv: R² = 0.9617
# Tested combined model on Sheet117_transformed.csv: R² = 0.9612
# Tested combined model on Sheet18_transformed.csv: R² = 0.9539
# Tested combined model on Sheet380_transformed.csv: R² = 0.9528
# Tested combined model on Sheet144_transformed.csv: R² = 0.9544
# Tested combined model on Sheet73_transformed.csv: R² = 0.9650
# Tested combined model on Sheet263_transformed.csv: R² = 0.9635
# Tested combined model on Sheet170_transformed.csv: R² = 0.9539
# Tested combined model on Sheet261_transformed.csv: R² = 0.9613
# Tested combined model on Sheet299_transformed.csv: R² = 0.9641
# Tested combined model on Sheet410_transformed.csv: R² = 0.9668
# Tested combined model on Sheet406_transformed.csv: R² = 0.9585
# Tested combined model on Sheet452_transformed.csv: R² = 0.9616
# Tested combined model on Sheet193_transformed.csv: R² = 0.9618
# Tested combined model on Sheet411_transformed.csv: R² = 0.9670
# Tested combined model on Sheet190_transformed.csv: R² = 0.9538
# Tested combined model on Sheet32_transformed.csv: R² = 0.9646
# Tested combined model on Sheet298_transformed.csv: R² = 0.9630
# Tested combined model on Sheet467_transformed.csv: R² = 0.9678
# Tested combined model on Sheet139_transformed.csv: R² = 0.9598
# Tested combined model on Sheet389_transformed.csv: R² = 0.9467
# Tested combined model on Sheet446_transformed.csv: R² = 0.9382
# Tested combined model on Sheet25_transformed.csv: R² = 0.9690
# Tested combined model on Sheet215_transformed.csv: R² = 0.9653
# Tested combined model on Sheet54_transformed.csv: R² = 0.9640
# Tested combined model on Sheet52_transformed.csv: R² = 0.9659
# Tested combined model on Sheet383_transformed.csv: R² = 0.9474
# Tested combined model on Sheet314_transformed.csv: R² = 0.9613
# Tested combined model on Sheet306_transformed.csv: R² = 0.9659
# Tested combined model on Sheet377_transformed.csv: R² = 0.9674
# Tested combined model on Sheet484_transformed.csv: R² = 0.9666
# Tested combined model on Sheet194_transformed.csv: R² = 0.9549
# Tested combined model on Sheet408_transformed.csv: R² = 0.9628
# Tested combined model on Sheet379_transformed.csv: R² = 0.9689
# Tested combined model on Sheet228_transformed.csv: R² = 0.9551
# Tested combined model on Sheet191_transformed.csv: R² = 0.9264
# Tested combined model on Sheet107_transformed.csv: R² = 0.9608
# Tested combined model on Sheet376_transformed.csv: R² = 0.9688
# Tested combined model on Sheet476_transformed.csv: R² = 0.9672
# Tested combined model on Sheet414_transformed.csv: R² = 0.9669
# Tested combined model on Sheet320_transformed.csv: R² = 0.9661
# Tested combined model on Sheet130_transformed.csv: R² = 0.9568
# Tested combined model on Sheet333_transformed.csv: R² = 0.9673
# Tested combined model on Sheet465_transformed.csv: R² = 0.9431
# Tested combined model on Sheet250_transformed.csv: R² = 0.9634
# Tested combined model on Sheet464_transformed.csv: R² = 0.9419
# Tested combined model on Sheet269_transformed.csv: R² = 0.9669
# Tested combined model on Sheet19_transformed.csv: R² = 0.9507
# Tested combined model on Sheet204_transformed.csv: R² = 0.9492
# Tested combined model on Sheet309_transformed.csv: R² = 0.9640
# Tested combined model on Sheet31_transformed.csv: R² = 0.9636
# Tested combined model on Sheet38_transformed.csv: R² = 0.9568
# Tested combined model on Sheet422_transformed.csv: R² = 0.9611
# Tested combined model on Sheet143_transformed.csv: R² = 0.9680
# Tested combined model on Sheet364_transformed.csv: R² = 0.8911
# Tested combined model on Sheet291_transformed.csv: R² = 0.9679
# Tested combined model on Sheet415_transformed.csv: R² = 0.9646
# Tested combined model on Sheet140_transformed.csv: R² = 0.9274
# Tested combined model on Sheet99_transformed.csv: R² = 0.9617
# Tested combined model on Sheet93_transformed.csv: R² = 0.9670
# Tested combined model on Sheet353_transformed.csv: R² = 0.9638
# Tested combined model on Sheet223_transformed.csv: R² = 0.9648
# Tested combined model on Sheet480_transformed.csv: R² = 0.9625
# Tested combined model on Sheet420_transformed.csv: R² = 0.9577
# Tested combined model on Sheet456_transformed.csv: R² = 0.9598
# Tested combined model on Sheet319_transformed.csv: R² = 0.9623
# Tested combined model on Sheet141_transformed.csv: R² = 0.9280
# Tested combined model on Sheet419_transformed.csv: R² = 0.9660
# Tested combined model on Sheet388_transformed.csv: R² = 0.9441
# Tested combined model on Sheet442_transformed.csv: R² = 0.9634
# Tested combined model on Sheet453_transformed.csv: R² = 0.9573
# Tested combined model on Sheet297_transformed.csv: R² = 0.9652
# Tested combined model on Sheet227_transformed.csv: R² = 0.9630
# Tested combined model on Sheet449_transformed.csv: R² = 0.9471
# Tested combined model on Sheet183_transformed.csv: R² = 0.9624
# Tested combined model on Sheet396_transformed.csv: R² = 0.9350
# Tested combined model on Sheet80_transformed.csv: R² = 0.9677
# Tested combined model on Sheet109_transformed.csv: R² = 0.9502
# Tested combined model on Sheet169_transformed.csv: R² = 0.9597
# Tested combined model on Sheet395_transformed.csv: R² = 0.9434
# Tested combined model on Sheet3_transformed.csv: R² = 0.9354
# Tested combined model on Sheet189_transformed.csv: R² = 0.9649
# Tested combined model on Sheet124_transformed.csv: R² = 0.9639
# Tested combined model on Sheet42_transformed.csv: R² = 0.9639
# Tested combined model on Sheet51_transformed.csv: R² = 0.9683
# Tested combined model on Sheet50_transformed.csv: R² = 0.9693
# Tested combined model on Sheet348_transformed.csv: R² = 0.9498
# Tested combined model on Sheet210_transformed.csv: R² = 0.9565
# Tested combined model on Sheet90_transformed.csv: R² = 0.9658
# Tested combined model on Sheet451_transformed.csv: R² = 0.9609
# Tested combined model on Sheet46_transformed.csv: R² = 0.9456
# Tested combined model on Sheet182_transformed.csv: R² = 0.9465
# Tested combined model on Sheet271_transformed.csv: R² = 0.9666
# Tested combined model on Sheet393_transformed.csv: R² = 0.9489
# Tested combined model on Sheet409_transformed.csv: R² = 0.9682
# Tested combined model on Sheet374_transformed.csv: R² = 0.9485
# Tested combined model on Sheet158_transformed.csv: R² = 0.9653
# Tested combined model on Sheet230_transformed.csv: R² = 0.9597
# Tested combined model on Sheet426_transformed.csv: R² = 0.9659
# Tested combined model on Sheet321_transformed.csv: R² = 0.9632
# Tested combined model on Sheet352_transformed.csv: R² = 0.9688
# Tested combined model on Sheet79_transformed.csv: R² = 0.9623
# Tested combined model on Sheet120_transformed.csv: R² = 0.9671
# Tested combined model on Sheet272_transformed.csv: R² = 0.9573
# Tested combined model on Sheet187_transformed.csv: R² = 0.9524
# Tested combined model on Sheet382_transformed.csv: R² = 0.9671
# Tested combined model on Sheet178_transformed.csv: R² = 0.9587
# Tested combined model on Sheet246_transformed.csv: R² = 0.9650
# Tested combined model on Sheet346_transformed.csv: R² = 0.9230
# Tested combined model on Sheet8_transformed.csv: R² = 0.9659
# Tested combined model on Sheet100_transformed.csv: R² = 0.9411
# Tested combined model on Sheet438_transformed.csv: R² = 0.9674
# Tested combined model on Sheet326_transformed.csv: R² = 0.9676
# Tested combined model on Sheet150_transformed.csv: R² = 0.9543
# Tested combined model on Sheet390_transformed.csv: R² = 0.9658
# Tested combined model on Sheet305_transformed.csv: R² = 0.9662
# Tested combined model on Sheet84_transformed.csv: R² = 0.9599
# Tested combined model on Sheet266_transformed.csv: R² = 0.9589
# Tested combined model on Sheet23_transformed.csv: R² = 0.9561
# Tested combined model on Sheet375_transformed.csv: R² = 0.9403
# Tested combined model on Sheet154_transformed.csv: R² = 0.9479
# Tested combined model on Sheet432_transformed.csv: R² = 0.9570
# Tested combined model on Sheet76_transformed.csv: R² = 0.9610
# Tested combined model on Sheet327_transformed.csv: R² = 0.9674
# Tested combined model on Sheet392_transformed.csv: R² = 0.9651
# Tested combined model on Sheet257_transformed.csv: R² = 0.9586
# Tested combined model on Sheet126_transformed.csv: R² = 0.9617
# Tested combined model on Sheet337_transformed.csv: R² = 0.9679
# Tested combined model on Sheet68_transformed.csv: R² = 0.9651
# Tested combined model on Sheet471_transformed.csv: R² = 0.9670
# Tested combined model on Sheet318_transformed.csv: R² = 0.9664
# Tested combined model on Sheet239_transformed.csv: R² = 0.9670
# Tested combined model on Sheet2_transformed.csv: R² = 0.9379
# Tested combined model on Sheet24_transformed.csv: R² = 0.9642
# Tested combined model on Sheet370_transformed.csv: R² = 0.9646
# Tested combined model on Sheet136_transformed.csv: R² = 0.9631
# Tested combined model on Sheet251_transformed.csv: R² = 0.9685
# Tested combined model on Sheet200_transformed.csv: R² = 0.9664
# Tested combined model on Sheet294_transformed.csv: R² = 0.9680
# Tested combined model on Sheet355_transformed.csv: R² = 0.9688
# Tested combined model on Sheet365_transformed.csv: R² = 0.9543
# Tested combined model on Sheet177_transformed.csv: R² = 0.9665
# Tested combined model on Sheet62_transformed.csv: R² = 0.9693
# Tested combined model on Sheet127_transformed.csv: R² = 0.9655
# Tested combined model on Sheet184_transformed.csv: R² = 0.9500
# Tested combined model on Sheet301_transformed.csv: R² = 0.9642
# Tested combined model on Sheet349_transformed.csv: R² = 0.9499
# Tested combined model on Sheet39_transformed.csv: R² = 0.9577
# Tested combined model on Sheet156_transformed.csv: R² = 0.9597
# Tested combined model on Sheet308_transformed.csv: R² = 0.9564
# Tested combined model on Sheet436_transformed.csv: R² = 0.9668
# Tested combined model on Sheet413_transformed.csv: R² = 0.9636
# Tested combined model on Sheet11_transformed.csv: R² = 0.9651
# Tested combined model on Sheet71_transformed.csv: R² = 0.9354
# Tested combined model on Sheet65_transformed.csv: R² = 0.9666
# Tested combined model on Sheet381_transformed.csv: R² = 0.9621
# Tested combined model on Sheet138_transformed.csv: R² = 0.9578
# Tested combined model on Sheet171_transformed.csv: R² = 0.9596
# Tested combined model on Sheet323_transformed.csv: R² = 0.9669
# Tested combined model on Sheet303_transformed.csv: R² = 0.9578
# Tested combined model on Sheet162_transformed.csv: R² = 0.9518
# Tested combined model on Sheet470_transformed.csv: R² = 0.9682
# Tested combined model on Sheet224_transformed.csv: R² = 0.9691
# Tested combined model on Sheet331_transformed.csv: R² = 0.9630
# Tested combined model on Sheet137_transformed.csv: R² = 0.9636
# Tested combined model on Sheet404_transformed.csv: R² = 0.9646
# Tested combined model on Sheet335_transformed.csv: R² = 0.9642
# Tested combined model on Sheet293_transformed.csv: R² = 0.9670
# Tested combined model on Sheet16_transformed.csv: R² = 0.9569
# Tested combined model on Sheet347_transformed.csv: R² = 0.9297
# Tested combined model on Sheet391_transformed.csv: R² = 0.9658
# Tested combined model on Sheet258_transformed.csv: R² = 0.9588
# Tested combined model on Sheet201_transformed.csv: R² = 0.9662
# Tested combined model on Sheet145_transformed.csv: R² = 0.9591
# Tested combined model on Sheet192_transformed.csv: R² = 0.9557
# Tested combined model on Sheet265_transformed.csv: R² = 0.9652
# Tested combined model on Sheet256_transformed.csv: R² = 0.9548
# Tested combined model on Sheet287_transformed.csv: R² = 0.9468
# Tested combined model on Sheet440_transformed.csv: R² = 0.9640
# Tested combined model on Sheet226_transformed.csv: R² = 0.9645
# Tested combined model on Sheet70_transformed.csv: R² = 0.9379
# Tested combined model on Sheet407_transformed.csv: R² = 0.9632
# Tested combined model on Sheet248_transformed.csv: R² = 0.9559
# Tested combined model on Sheet424_transformed.csv: R² = 0.9645
# Tested combined model on Sheet400_transformed.csv: R² = 0.9588
# Tested combined model on Sheet469_transformed.csv: R² = 0.9672
# Tested combined model on Sheet343_transformed.csv: R² = 0.9667
# Tested combined model on Sheet45_transformed.csv: R² = 0.9670
# Tested combined model on Sheet26_transformed.csv: R² = 0.9661
# Tested combined model on Sheet96_transformed.csv: R² = 0.9652
# Tested combined model on Sheet212_transformed.csv: R² = 0.9568
# Tested combined model on Sheet64_transformed.csv: R² = 0.9659
# Tested combined model on Sheet443_transformed.csv: R² = 0.9606
# Tested combined model on Sheet425_transformed.csv: R² = 0.9662
# Tested combined model on Sheet186_transformed.csv: R² = 0.9605
# Tested combined model on Sheet457_transformed.csv: R² = 0.9600
# Tested combined model on Sheet148_transformed.csv: R² = 0.9487
# Tested combined model on Sheet433_transformed.csv: R² = 0.9649
# Tested combined model on Sheet267_transformed.csv: R² = 0.9599
# Tested combined model on Sheet351_transformed.csv: R² = 0.9609
# Tested combined model on Sheet159_transformed.csv: R² = 0.9630
# Tested combined model on Sheet439_transformed.csv: R² = 0.9642
# Tested combined model on Sheet229_transformed.csv: R² = 0.9591
# Tested combined model on Sheet247_transformed.csv: R² = 0.9662
# Tested combined model on Sheet232_transformed.csv: R² = 0.9608
# Tested combined model on Sheet110_transformed.csv: R² = 0.9649
# Tested combined model on Sheet485_transformed.csv: R² = 0.9685
# Tested combined model on Sheet274_transformed.csv: R² = 0.9660
# Tested combined model on Sheet236_transformed.csv: R² = 0.9504
# Tested combined model on Sheet234_transformed.csv: R² = 0.9620
# Tested combined model on Sheet459_transformed.csv: R² = 0.9636
# Tested combined model on Sheet119_transformed.csv: R² = 0.9644
# Tested combined model on Sheet354_transformed.csv: R² = 0.9669
# Tested combined model on Sheet114_transformed.csv: R² = 0.9627
# Tested combined model on Sheet15_transformed.csv: R² = 0.9544
# Tested combined model on Sheet270_transformed.csv: R² = 0.9671
# Tested combined model on Sheet339_transformed.csv: R² = 0.9524
# Tested combined model on Sheet362_transformed.csv: R² = 0.9646
# Tested combined model on Sheet296_transformed.csv: R² = 0.9649
# Tested combined model on Sheet85_transformed.csv: R² = 0.9648
# Tested combined model on Sheet118_transformed.csv: R² = 0.9646
# Tested combined model on Sheet222_transformed.csv: R² = 0.9602
# Tested combined model on Sheet112_transformed.csv: R² = 0.9675
# Tested combined model on Sheet482_transformed.csv: R² = 0.9614
# Tested combined model on Sheet394_transformed.csv: R² = 0.9437
# Tested combined model on Sheet402_transformed.csv: R² = 0.9589
# Tested combined model on Sheet10_transformed.csv: R² = 0.9617
# Tested combined model on Sheet418_transformed.csv: R² = 0.9642
# Tested combined model on Sheet240_transformed.csv: R² = 0.9634
# Tested combined model on Sheet466_transformed.csv: R² = 0.9678
# Tested combined model on Sheet113_transformed.csv: R² = 0.9674
# Tested combined model on Sheet307_transformed.csv: R² = 0.9656
# Tested combined model on Sheet342_transformed.csv: R² = 0.9683
# Tested combined model on Sheet288_transformed.csv: R² = 0.9533
# Tested combined model on Sheet74_transformed.csv: R² = 0.9615
# Tested combined model on Sheet275_transformed.csv: R² = 0.9640
# Tested combined model on Sheet179_transformed.csv: R² = 0.9677
# Tested combined model on Sheet387_transformed.csv: R² = 0.9538
# Tested combined model on Sheet121_transformed.csv: R² = 0.9697
# Tested combined model on Sheet254_transformed.csv: R² = 0.9602
# Tested combined model on Sheet473_transformed.csv: R² = 0.9692
# Tested combined model on Sheet475_transformed.csv: R² = 0.9589
# Tested combined model on Sheet454_transformed.csv: R² = 0.9620
# Tested combined model on Sheet36_transformed.csv: R² = 0.9644
# Tested combined model on Sheet53_transformed.csv: R² = 0.9666
# Tested combined model on Sheet367_transformed.csv: R² = 0.9505
# Tested combined model on Sheet214_transformed.csv: R² = 0.9654
# Tested combined model on Sheet334_transformed.csv: R² = 0.9686
# Tested combined model on Sheet279_transformed.csv: R² = 0.9583
# Tested combined model on Sheet106_transformed.csv: R² = 0.9579
# Tested combined model on Sheet180_transformed.csv: R² = 0.9082
# Tested combined model on Sheet366_transformed.csv: R² = 0.9554
# Tested combined model on Sheet360_transformed.csv: R² = 0.9422
# Tested combined model on Sheet447_transformed.csv: R² = 0.9523
# Tested combined model on Sheet328_transformed.csv: R² = 0.9571
# Tested combined model on Sheet359_transformed.csv: R² = 0.9381
# Tested combined model on Sheet219_transformed.csv: R² = 0.9625
# Tested combined model on Sheet268_transformed.csv: R² = 0.9662
# Tested combined model on Sheet157_transformed.csv: R² = 0.9613
# Tested combined model on Sheet188_transformed.csv: R² = 0.9622
# Tested combined model on Sheet332_transformed.csv: R² = 0.9654
# Tested combined model on Sheet205_transformed.csv: R² = 0.9580
# Tested combined model on Sheet27_transformed.csv: R² = 0.9658
# Tested combined model on Sheet72_transformed.csv: R² = 0.9668
# Tested combined model on Sheet146_transformed.csv: R² = 0.9619
# Tested combined model on Sheet175_transformed.csv: R² = 0.9673
# Tested combined model on Sheet478_transformed.csv: R² = 0.9672
#
# Test results saved to: combined_model_1d_test_results.csv
#
# Training Summary:
# Total files processed: 482
# Average Training R² Score: 0.9686
#
# Testing Summary:
# Total files tested: 482
# Average Test R² Score: 0.9598
# Average Absolute Error: 0.1234

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score
from pathlib import Path
import concurrent.futures
from functools import lru_cache
import multiprocessing
import warnings
warnings.filterwarnings('ignore')

# Constants
MAX_MERIDIAN_COMPONENTS = 10  # Increased maximum components to test     
BASE_DATA_DIR = Path("/home/aricept094/mydata/sheets/combined_data")
OUTPUT_DIR = Path("/home/aricept094/mydata/sheets/combined_data/radial_results/Height_Anterior_Value")
RADIAL_FOLDERS = [1, 4, 8, 12, 16, 20, 24,]
VARIANCE_THRESHOLD = 99.99  # Setting threshold close to 100% to account for numerical precision
MAX_WORKERS = max(1, int(multiprocessing.cpu_count() * 0.99))

# Rest of the functions remain the same up until main()
@lru_cache(maxsize=None)
def calculate_trig_terms(m, n_points):
    """Calculate trigonometric terms for Fourier series."""
    angle = 2 * np.pi * m * np.arange(n_points) / n_points
    return np.cos(angle), np.sin(angle)

def calculate_fourier_components(meridian_indices, keratometry_values):
    """Calculate Fourier components until variance explained reaches threshold."""
    n_meridian = len(meridian_indices)
    norm_factor = 2 / n_meridian
    
    # Initialize result dictionaries
    coefficients = {'a0': np.mean(keratometry_values)}  # DC component
    energy = {'a0': coefficients['a0']**2}
    amplitudes = {}
    component_coeffs = {}  # New dictionary for storing coefficients
    total_energy = energy['a0']
    
    m = 1
    cumulative_variance = 0
    higher_order_amplitude = 0
    
    while cumulative_variance < VARIANCE_THRESHOLD and m <= MAX_MERIDIAN_COMPONENTS:
        cos_m, sin_m = calculate_trig_terms(m, n_meridian)
        am = norm_factor * np.sum(keratometry_values * cos_m)
        bm = norm_factor * np.sum(keratometry_values * sin_m)
        
        current_energy = am**2 + bm**2
        energy.update({f'am{m}': am**2, f'bm{m}': bm**2})
        total_energy += current_energy
        
        # Calculate amplitude for current component
        current_amplitude = np.sqrt(am**2 + bm**2)
        
        # Store specific components and their coefficients
        if m <= 2:
            amplitudes[f'component_{m}_amplitude'] = current_amplitude
            component_coeffs[f'component_{m}_cos'] = am  # Store cosine coefficient
            component_coeffs[f'component_{m}_sin'] = bm  # Store sine coefficient
        else:
            higher_order_amplitude += current_amplitude
            
        m += 1
    
    # Calculate final metrics
    components_used = m - 1
    cumulative_variance = (total_energy / total_energy) * 100
    
    # Add higher order amplitude sum
    amplitudes['higher_order_amplitude_sum'] = higher_order_amplitude
    
    # Calculate reconstructed signal
    reconstructed = np.full(n_meridian, coefficients['a0'])
    for m in range(1, components_used + 1):
        cos_m, sin_m = calculate_trig_terms(m, n_meridian)
        if m <= 2:
            reconstructed += (component_coeffs[f'component_{m}_cos'] * cos_m + 
                            component_coeffs[f'component_{m}_sin'] * sin_m)
        else:
            # Use regular Fourier series for higher components
            am = norm_factor * np.sum(keratometry_values * cos_m)
            bm = norm_factor * np.sum(keratometry_values * sin_m)
            reconstructed += (am * cos_m + bm * sin_m)
    
    r2 = r2_score(keratometry_values, reconstructed)
    
    return {
        'dc_component': coefficients['a0'],
        'components_used': components_used,
        'total_variance_explained': cumulative_variance,
        'r2_score': r2,
        **amplitudes,
        **component_coeffs  # Include the coefficients in the output
    }

def process_file(file_path):
    """Process a single file and return its Fourier analysis results."""
    try:
        df = pd.read_csv(file_path)
        meridian_means = df.groupby('Meridian_Index')['Height_Anterior_Value'].mean()
        meridian_indices = np.array(sorted(meridian_means.index))
        keratometry_values = meridian_means[meridian_indices].values
        
        results = calculate_fourier_components(meridian_indices, keratometry_values)
        results['filename'] = file_path.name
        
        print(f"Processed {file_path.name}: R² = {results['r2_score']:.4f}, Components = {results['components_used']}")
        return results
    
    except Exception as e:
        print(f"Error processing {file_path.name}: {str(e)}")
        return None

def calculate_combined_model(results_df):
    """Calculate combined model using Mallows weights."""
    result_columns = [
        'dc_component', 
        'component_1_amplitude', 
        'component_2_amplitude',
        'component_1_cos',
        'component_1_sin',
        'component_2_cos',
        'component_2_sin', 
        'higher_order_amplitude_sum'
    ]
    
    mse = 1 - results_df['r2_score'].values
    weights = 1 / (mse + 1e-10)
    weights /= weights.sum()
    
    combined_values = {col: np.average(results_df[col], weights=weights) 
                      for col in result_columns}
    
    return combined_values

def process_radial_folder(radial_number):
    """Process all files in a specific radial folder."""
    data_dir = BASE_DATA_DIR / f"radial_{radial_number}"
    output_file = OUTPUT_DIR / f"analysis_results_radial_{radial_number}.csv"
    
    print(f"\nProcessing radial_{radial_number} folder...")
    
    try:
        # Process files in parallel
        csv_files = list(data_dir.glob("*.csv"))
        if not csv_files:
            print(f"No CSV files found in {data_dir}")
            return
            
        with concurrent.futures.ProcessPoolExecutor(max_workers=MAX_WORKERS) as executor:
            results = list(filter(None, executor.map(process_file, csv_files)))
        
        # Create results DataFrame and calculate combined model
        results_df = pd.DataFrame(results)
        combined_model = calculate_combined_model(results_df)
        
        # Add combined model to results
        combined_row = {
            'filename': 'COMBINED_MODEL',
            'r2_score': np.nan,
            'components_used': np.nan,
            'total_variance_explained': np.nan,
            **combined_model
        }
        results_df = pd.concat([results_df, pd.DataFrame([combined_row])], ignore_index=True)
        
        # Save results and print summary
        output_file.parent.mkdir(parents=True, exist_ok=True)
        results_df.to_csv(output_file, index=False)
        print(f"Results saved to: {output_file}")
        print(f"Analysis Summary for radial_{radial_number}:")
        print(f"Files processed: {len(results_df) - 1}")
        print(f"Average R² Score: {results_df['r2_score'].iloc[:-1].mean():.4f}")
        print(f"Average Components Used: {results_df['components_used'].iloc[:-1].mean():.1f}")
        
    except Exception as e:
        print(f"Error processing radial_{radial_number}: {str(e)}")

def main():
    print(f"Starting Fourier analysis using {MAX_WORKERS} processes...")
    print(f"Will process the following radial folders: {RADIAL_FOLDERS}")
    
    # Create output directory if it doesn't exist
    OUTPUT_DIR.mkdir(parents=True, exist_ok=True)
    
    # Process each radial folder
    for radial_number in RADIAL_FOLDERS:
        process_radial_folder(radial_number)
    
    print("\nAll radial folders have been processed.")

if __name__ == "__main__":
    main()
# Out:
# Starting Fourier analysis using 15 processes...
# Will process the following radial folders: [1, 4, 8, 12, 16, 20, 24]
#
# Processing radial_1 folder...
# Processed Sheet124_combined.csv: R² = 0.9960, Components = 10Processed Sheet480_combined.csv: R² = 0.9951, Components = 10Processed Sheet201_combined.csv: R² = 0.9925, Components = 10
#
#
# Processed Sheet460_combined.csv: R² = 0.9731, Components = 10Processed Sheet295_combined.csv: R² = 0.9799, Components = 10Processed Sheet404_combined.csv: R² = 0.9757, Components = 10Processed Sheet23_combined.csv: R² = 0.9539, Components = 10Processed Sheet262_combined.csv: R² = 0.9553, Components = 10Processed Sheet91_combined.csv: R² = 0.9924, Components = 10Processed Sheet132_combined.csv: R² = 0.9758, Components = 10
# Processed Sheet412_combined.csv: R² = 0.9724, Components = 10
#
#
# Processed Sheet431_combined.csv: R² = 0.9812, Components = 10
#
# Processed Sheet373_combined.csv: R² = 0.9813, Components = 10Processed Sheet125_combined.csv: R² = 0.9522, Components = 10
# Processed Sheet74_combined.csv: R² = 0.9838, Components = 10
# Processed Sheet312_combined.csv: R² = 0.9737, Components = 10
#
# Processed Sheet466_combined.csv: R² = 0.9962, Components = 10
#
# Processed Sheet304_combined.csv: R² = 0.9962, Components = 10Processed Sheet153_combined.csv: R² = 0.9790, Components = 10
#
# Processed Sheet321_combined.csv: R² = 0.9277, Components = 10
# Processed Sheet148_combined.csv: R² = 0.9532, Components = 10Processed Sheet209_combined.csv: R² = 0.9908, Components = 10Processed Sheet225_combined.csv: R² = 0.9599, Components = 10
#
#
#
# Processed Sheet423_combined.csv: R² = 0.9814, Components = 10Processed Sheet311_combined.csv: R² = 0.9754, Components = 10
#
# Processed Sheet133_combined.csv: R² = 0.9821, Components = 10Processed Sheet160_combined.csv: R² = 0.9473, Components = 10Processed Sheet349_combined.csv: R² = 0.9775, Components = 10Processed Sheet29_combined.csv: R² = 0.9765, Components = 10Processed Sheet483_combined.csv: R² = 0.9785, Components = 10Processed Sheet296_combined.csv: R² = 0.9876, Components = 10
#
#
# Processed Sheet231_combined.csv: R² = 0.9879, Components = 10
# Processed Sheet78_combined.csv: R² = 0.9934, Components = 10
#
# Processed Sheet302_combined.csv: R² = 0.9599, Components = 10Processed Sheet434_combined.csv: R² = 0.9688, Components = 10Processed Sheet84_combined.csv: R² = 0.9854, Components = 10Processed Sheet397_combined.csv: R² = 0.9857, Components = 10
#
# Processed Sheet2_combined.csv: R² = 0.9329, Components = 10Processed Sheet173_combined.csv: R² = 0.9419, Components = 10Processed Sheet227_combined.csv: R² = 0.9876, Components = 10Processed Sheet95_combined.csv: R² = 0.9590, Components = 10Processed Sheet419_combined.csv: R² = 0.9769, Components = 10
#
#
# Processed Sheet217_combined.csv: R² = 0.9765, Components = 10
#
#
# Processed Sheet230_combined.csv: R² = 0.9917, Components = 10
# Processed Sheet45_combined.csv: R² = 0.9931, Components = 10
# Processed Sheet228_combined.csv: R² = 0.9673, Components = 10Processed Sheet129_combined.csv: R² = 0.9932, Components = 10
#
#
#
#
#
# Processed Sheet285_combined.csv: R² = 0.9826, Components = 10Processed Sheet437_combined.csv: R² = 0.9653, Components = 10Processed Sheet438_combined.csv: R² = 0.9947, Components = 10
#
# Processed Sheet421_combined.csv: R² = 0.9698, Components = 10
#
# Processed Sheet446_combined.csv: R² = 0.9642, Components = 10Processed Sheet40_combined.csv: R² = 0.9809, Components = 10Processed Sheet301_combined.csv: R² = 0.9829, Components = 10Processed Sheet367_combined.csv: R² = 0.9809, Components = 10Processed Sheet439_combined.csv: R² = 0.9874, Components = 10
#
#
# Processed Sheet291_combined.csv: R² = 0.9866, Components = 10Processed Sheet118_combined.csv: R² = 0.9821, Components = 10Processed Sheet44_combined.csv: R² = 0.9931, Components = 10Processed Sheet449_combined.csv: R² = 0.9642, Components = 10Processed Sheet320_combined.csv: R² = 0.9903, Components = 10Processed Sheet41_combined.csv: R² = 0.9875, Components = 10
#
# Processed Sheet61_combined.csv: R² = 0.9921, Components = 10Processed Sheet432_combined.csv: R² = 0.9943, Components = 10Processed Sheet465_combined.csv: R² = 0.9947, Components = 10Processed Sheet453_combined.csv: R² = 0.9875, Components = 10Processed Sheet110_combined.csv: R² = 0.9727, Components = 10
#
#
# Processed Sheet251_combined.csv: R² = 0.9828, Components = 10
#
#
#
#
#
#
#
#
#
# Processed Sheet171_combined.csv: R² = 0.9698, Components = 10Processed Sheet5_combined.csv: R² = 0.9813, Components = 10Processed Sheet236_combined.csv: R² = 0.9963, Components = 10
# Processed Sheet339_combined.csv: R² = 0.9824, Components = 10Processed Sheet425_combined.csv: R² = 0.9911, Components = 10
# Processed Sheet145_combined.csv: R² = 0.9808, Components = 10
# Processed Sheet13_combined.csv: R² = 0.9902, Components = 10Processed Sheet332_combined.csv: R² = 0.9858, Components = 10
# Processed Sheet116_combined.csv: R² = 0.9884, Components = 10
#
#
# Processed Sheet388_combined.csv: R² = 0.9863, Components = 10Processed Sheet342_combined.csv: R² = 0.9930, Components = 10
# Processed Sheet378_combined.csv: R² = 0.9876, Components = 10
# Processed Sheet253_combined.csv: R² = 0.9768, Components = 10Processed Sheet233_combined.csv: R² = 0.9894, Components = 10
# Processed Sheet360_combined.csv: R² = 0.9724, Components = 10
#
#
# Processed Sheet119_combined.csv: R² = 0.9868, Components = 10
#
# Processed Sheet92_combined.csv: R² = 0.9917, Components = 10Processed Sheet131_combined.csv: R² = 0.9868, Components = 10Processed Sheet130_combined.csv: R² = 0.9754, Components = 10Processed Sheet333_combined.csv: R² = 0.9912, Components = 10
#
# Processed Sheet126_combined.csv: R² = 0.9818, Components = 10
# Processed Sheet181_combined.csv: R² = 0.9871, Components = 10Processed Sheet175_combined.csv: R² = 0.9867, Components = 10
#
# Processed Sheet210_combined.csv: R² = 0.9577, Components = 10Processed Sheet135_combined.csv: R² = 0.9714, Components = 10Processed Sheet347_combined.csv: R² = 0.9873, Components = 10
#
# Processed Sheet65_combined.csv: R² = 0.9822, Components = 10
#
# Processed Sheet353_combined.csv: R² = 0.9778, Components = 10
#
#
# Processed Sheet234_combined.csv: R² = 0.9900, Components = 10Processed Sheet459_combined.csv: R² = 0.9732, Components = 10
# Processed Sheet268_combined.csv: R² = 0.9622, Components = 10Processed Sheet472_combined.csv: R² = 0.9845, Components = 10Processed Sheet177_combined.csv: R² = 0.9744, Components = 10
#
#
# Processed Sheet485_combined.csv: R² = 0.9947, Components = 10
#
# Processed Sheet208_combined.csv: R² = 0.9793, Components = 10
# Processed Sheet330_combined.csv: R² = 0.9817, Components = 10
# Processed Sheet15_combined.csv: R² = 0.9654, Components = 10
# Processed Sheet391_combined.csv: R² = 0.9778, Components = 10Processed Sheet139_combined.csv: R² = 0.9944, Components = 10Processed Sheet469_combined.csv: R² = 0.9918, Components = 10Processed Sheet244_combined.csv: R² = 0.9938, Components = 10Processed Sheet344_combined.csv: R² = 0.9889, Components = 10Processed Sheet72_combined.csv: R² = 0.9826, Components = 10Processed Sheet436_combined.csv: R² = 0.9906, Components = 10Processed Sheet478_combined.csv: R² = 0.9976, Components = 10
#
#
#
#
#
#
# Processed Sheet37_combined.csv: R² = 0.9926, Components = 10Processed Sheet413_combined.csv: R² = 0.9917, Components = 10Processed Sheet369_combined.csv: R² = 0.9741, Components = 10
#
# Processed Sheet407_combined.csv: R² = 0.9873, Components = 10Processed Sheet394_combined.csv: R² = 0.9952, Components = 10
#
#
#
#
# Processed Sheet357_combined.csv: R² = 0.9856, Components = 10
# Processed Sheet164_combined.csv: R² = 0.9887, Components = 10Processed Sheet50_combined.csv: R² = 0.9809, Components = 10Processed Sheet105_combined.csv: R² = 0.9921, Components = 10Processed Sheet470_combined.csv: R² = 0.9798, Components = 10
#
#
# Processed Sheet224_combined.csv: R² = 0.9951, Components = 10
# Processed Sheet48_combined.csv: R² = 0.9920, Components = 10Processed Sheet451_combined.csv: R² = 0.9894, Components = 10Processed Sheet415_combined.csv: R² = 0.9916, Components = 10
# Processed Sheet161_combined.csv: R² = 0.9902, Components = 10Processed Sheet142_combined.csv: R² = 0.9503, Components = 10
# Processed Sheet219_combined.csv: R² = 0.9834, Components = 10
#
#
#
#
# Processed Sheet338_combined.csv: R² = 0.9847, Components = 10Processed Sheet294_combined.csv: R² = 0.9757, Components = 10
# Processed Sheet156_combined.csv: R² = 0.9917, Components = 10Processed Sheet39_combined.csv: R² = 0.9909, Components = 10
# Processed Sheet36_combined.csv: R² = 0.9773, Components = 10Processed Sheet243_combined.csv: R² = 0.9920, Components = 10Processed Sheet16_combined.csv: R² = 0.9310, Components = 10Processed Sheet267_combined.csv: R² = 0.9780, Components = 10Processed Sheet477_combined.csv: R² = 0.9740, Components = 10Processed Sheet286_combined.csv: R² = 0.9854, Components = 10Processed Sheet479_combined.csv: R² = 0.9878, Components = 10Processed Sheet214_combined.csv: R² = 0.9836, Components = 10
#
# Processed Sheet73_combined.csv: R² = 0.9706, Components = 10
#
#
#
#
#
#
#
# Processed Sheet303_combined.csv: R² = 0.9941, Components = 10Processed Sheet355_combined.csv: R² = 0.9222, Components = 10Processed Sheet55_combined.csv: R² = 0.9825, Components = 10Processed Sheet35_combined.csv: R² = 0.9785, Components = 10
#
#
# Processed Sheet75_combined.csv: R² = 0.9860, Components = 10Processed Sheet63_combined.csv: R² = 0.9636, Components = 10
# Processed Sheet315_combined.csv: R² = 0.9641, Components = 10Processed Sheet350_combined.csv: R² = 0.9777, Components = 10Processed Sheet191_combined.csv: R² = 0.9968, Components = 10Processed Sheet213_combined.csv: R² = 0.9868, Components = 10
# Processed Sheet190_combined.csv: R² = 0.9952, Components = 10Processed Sheet374_combined.csv: R² = 0.9870, Components = 10
# Processed Sheet348_combined.csv: R² = 0.9827, Components = 10Processed Sheet255_combined.csv: R² = 0.9808, Components = 10Processed Sheet106_combined.csv: R² = 0.9753, Components = 10
#
# Processed Sheet28_combined.csv: R² = 0.9854, Components = 10
#
#
#
#
#
# Processed Sheet467_combined.csv: R² = 0.9787, Components = 10
#
#
# Processed Sheet211_combined.csv: R² = 0.9821, Components = 10Processed Sheet420_combined.csv: R² = 0.9943, Components = 10Processed Sheet109_combined.csv: R² = 0.9876, Components = 10Processed Sheet123_combined.csv: R² = 0.9743, Components = 10Processed Sheet283_combined.csv: R² = 0.9141, Components = 10Processed Sheet239_combined.csv: R² = 0.9833, Components = 10
#
#
# Processed Sheet272_combined.csv: R² = 0.9913, Components = 10Processed Sheet399_combined.csv: R² = 0.9909, Components = 10
# Processed Sheet261_combined.csv: R² = 0.9726, Components = 10Processed Sheet266_combined.csv: R² = 0.9947, Components = 10Processed Sheet450_combined.csv: R² = 0.9952, Components = 10
#
#
#
# Processed Sheet263_combined.csv: R² = 0.9512, Components = 10
# Processed Sheet337_combined.csv: R² = 0.9567, Components = 10Processed Sheet166_combined.csv: R² = 0.9610, Components = 10Processed Sheet194_combined.csv: R² = 0.9984, Components = 10
#
# Processed Sheet42_combined.csv: R² = 0.9778, Components = 10
#
#
# Processed Sheet3_combined.csv: R² = 0.9740, Components = 10
# Processed Sheet386_combined.csv: R² = 0.9690, Components = 10Processed Sheet98_combined.csv: R² = 0.9840, Components = 10Processed Sheet363_combined.csv: R² = 0.9917, Components = 10Processed Sheet90_combined.csv: R² = 0.9592, Components = 10Processed Sheet383_combined.csv: R² = 0.9875, Components = 10Processed Sheet345_combined.csv: R² = 0.9829, Components = 10
#
# Processed Sheet140_combined.csv: R² = 0.9679, Components = 10
# Processed Sheet85_combined.csv: R² = 0.9868, Components = 10Processed Sheet426_combined.csv: R² = 0.9867, Components = 10Processed Sheet127_combined.csv: R² = 0.9555, Components = 10
#
#
#
#
# Processed Sheet365_combined.csv: R² = 0.9912, Components = 10
# Processed Sheet277_combined.csv: R² = 0.9876, Components = 10
#
#
#
#
# Processed Sheet396_combined.csv: R² = 0.9464, Components = 10
# Processed Sheet122_combined.csv: R² = 0.9961, Components = 10Processed Sheet196_combined.csv: R² = 0.9807, Components = 10
#
#
# Processed Sheet222_combined.csv: R² = 0.9842, Components = 10Processed Sheet368_combined.csv: R² = 0.9730, Components = 10Processed Sheet33_combined.csv: R² = 0.9861, Components = 10Processed Sheet245_combined.csv: R² = 0.9899, Components = 10Processed Sheet387_combined.csv: R² = 0.9710, Components = 10Processed Sheet319_combined.csv: R² = 0.9840, Components = 10Processed Sheet100_combined.csv: R² = 0.9871, Components = 10
# Processed Sheet17_combined.csv: R² = 0.9660, Components = 10
# Processed Sheet114_combined.csv: R² = 0.9927, Components = 10Processed Sheet150_combined.csv: R² = 0.9931, Components = 10Processed Sheet275_combined.csv: R² = 0.9537, Components = 10
#
# Processed Sheet121_combined.csv: R² = 0.9675, Components = 10Processed Sheet162_combined.csv: R² = 0.9939, Components = 10
#
#
#
#
#
# Processed Sheet463_combined.csv: R² = 0.9692, Components = 10
# Processed Sheet307_combined.csv: R² = 0.9876, Components = 10Processed Sheet206_combined.csv: R² = 0.9904, Components = 10
# Processed Sheet326_combined.csv: R² = 0.9470, Components = 10
# Processed Sheet464_combined.csv: R² = 0.9929, Components = 10Processed Sheet408_combined.csv: R² = 0.9812, Components = 10Processed Sheet168_combined.csv: R² = 0.9847, Components = 10
# Processed Sheet71_combined.csv: R² = 0.9740, Components = 10Processed Sheet113_combined.csv: R² = 0.9895, Components = 10
#
# Processed Sheet461_combined.csv: R² = 0.9808, Components = 10Processed Sheet99_combined.csv: R² = 0.9700, Components = 10
#
# Processed Sheet11_combined.csv: R² = 0.9872, Components = 10
# Processed Sheet455_combined.csv: R² = 0.9806, Components = 10Processed Sheet154_combined.csv: R² = 0.9652, Components = 10
# Processed Sheet247_combined.csv: R² = 0.9813, Components = 10Processed Sheet482_combined.csv: R² = 0.9946, Components = 10
#
#
#
#
#
#
# Processed Sheet305_combined.csv: R² = 0.9830, Components = 10
#
# Processed Sheet187_combined.csv: R² = 0.9846, Components = 10Processed Sheet185_combined.csv: R² = 0.9977, Components = 10Processed Sheet220_combined.csv: R² = 0.9851, Components = 10Processed Sheet136_combined.csv: R² = 0.9826, Components = 10
#
#
#
# Processed Sheet351_combined.csv: R² = 0.9726, Components = 10
# Processed Sheet27_combined.csv: R² = 0.9287, Components = 10Processed Sheet448_combined.csv: R² = 0.9965, Components = 10Processed Sheet377_combined.csv: R² = 0.9901, Components = 10Processed Sheet241_combined.csv: R² = 0.9886, Components = 10Processed Sheet401_combined.csv: R² = 0.9864, Components = 10
#
#
#
#
# Processed Sheet250_combined.csv: R² = 0.9951, Components = 10Processed Sheet258_combined.csv: R² = 0.9769, Components = 10Processed Sheet14_combined.csv: R² = 0.9936, Components = 10
# Processed Sheet428_combined.csv: R² = 0.9773, Components = 10Processed Sheet193_combined.csv: R² = 0.9928, Components = 10Processed Sheet87_combined.csv: R² = 0.9433, Components = 10
#
#
#
#
# Processed Sheet149_combined.csv: R² = 0.9822, Components = 10Processed Sheet309_combined.csv: R² = 0.9894, Components = 10
# Processed Sheet143_combined.csv: R² = 0.9945, Components = 10Processed Sheet32_combined.csv: R² = 0.9918, Components = 10Processed Sheet51_combined.csv: R² = 0.9636, Components = 10Processed Sheet192_combined.csv: R² = 0.9977, Components = 10Processed Sheet93_combined.csv: R² = 0.9830, Components = 10Processed Sheet288_combined.csv: R² = 0.9473, Components = 10Processed Sheet115_combined.csv: R² = 0.9937, Components = 10Processed Sheet155_combined.csv: R² = 0.9930, Components = 10
# Processed Sheet179_combined.csv: R² = 0.9919, Components = 10
#
# Processed Sheet457_combined.csv: R² = 0.9770, Components = 10
#
#
# Processed Sheet199_combined.csv: R² = 0.9873, Components = 10Processed Sheet380_combined.csv: R² = 0.9616, Components = 10
#
#
#
#
#
#
# Processed Sheet165_combined.csv: R² = 0.9735, Components = 10Processed Sheet331_combined.csv: R² = 0.9962, Components = 10
#
# Processed Sheet329_combined.csv: R² = 0.9925, Components = 10Processed Sheet473_combined.csv: R² = 0.9910, Components = 10Processed Sheet79_combined.csv: R² = 0.9902, Components = 10Processed Sheet409_combined.csv: R² = 0.9882, Components = 10Processed Sheet456_combined.csv: R² = 0.9813, Components = 10Processed Sheet371_combined.csv: R² = 0.9437, Components = 10Processed Sheet484_combined.csv: R² = 0.9808, Components = 10Processed Sheet144_combined.csv: R² = 0.9928, Components = 10
#
#
# Processed Sheet359_combined.csv: R² = 0.9523, Components = 10
# Processed Sheet46_combined.csv: R² = 0.9815, Components = 10
#
# Processed Sheet441_combined.csv: R² = 0.9610, Components = 10
# Processed Sheet159_combined.csv: R² = 0.9670, Components = 10Processed Sheet249_combined.csv: R² = 0.9402, Components = 10Processed Sheet218_combined.csv: R² = 0.9916, Components = 10
#
#
#
#
# Processed Sheet64_combined.csv: R² = 0.9867, Components = 10
#
# Processed Sheet94_combined.csv: R² = 0.9612, Components = 10Processed Sheet358_combined.csv: R² = 0.9833, Components = 10
# Processed Sheet443_combined.csv: R² = 0.9866, Components = 10Processed Sheet376_combined.csv: R² = 0.9838, Components = 10
# Processed Sheet384_combined.csv: R² = 0.9929, Components = 10Processed Sheet141_combined.csv: R² = 0.9808, Components = 10Processed Sheet366_combined.csv: R² = 0.9822, Components = 10Processed Sheet299_combined.csv: R² = 0.9912, Components = 10
#
# Processed Sheet197_combined.csv: R² = 0.9909, Components = 10Processed Sheet435_combined.csv: R² = 0.9836, Components = 10
# Processed Sheet429_combined.csv: R² = 0.9793, Components = 10Processed Sheet151_combined.csv: R² = 0.9877, Components = 10
# Processed Sheet146_combined.csv: R² = 0.9863, Components = 10
#
#
# Processed Sheet49_combined.csv: R² = 0.9921, Components = 10
#
# Processed Sheet364_combined.csv: R² = 0.9775, Components = 10
#
#
#
#
# Processed Sheet21_combined.csv: R² = 0.9758, Components = 10Processed Sheet276_combined.csv: R² = 0.9715, Components = 10Processed Sheet252_combined.csv: R² = 0.9667, Components = 10
# Processed Sheet184_combined.csv: R² = 0.9435, Components = 10
# Processed Sheet317_combined.csv: R² = 0.9440, Components = 10
# Processed Sheet427_combined.csv: R² = 0.9822, Components = 10Processed Sheet382_combined.csv: R² = 0.9913, Components = 10
#
#
# Processed Sheet265_combined.csv: R² = 0.9899, Components = 10Processed Sheet7_combined.csv: R² = 0.9861, Components = 10
# Processed Sheet284_combined.csv: R² = 0.9786, Components = 10Processed Sheet289_combined.csv: R² = 0.9902, Components = 10
#
# Processed Sheet418_combined.csv: R² = 0.9933, Components = 10Processed Sheet475_combined.csv: R² = 0.9753, Components = 10Processed Sheet57_combined.csv: R² = 0.9931, Components = 10
#
#
# Processed Sheet88_combined.csv: R² = 0.9730, Components = 10
# Processed Sheet215_combined.csv: R² = 0.9887, Components = 10Processed Sheet137_combined.csv: R² = 0.9861, Components = 10Processed Sheet352_combined.csv: R² = 0.9672, Components = 10Processed Sheet379_combined.csv: R² = 0.9832, Components = 10
#
# Processed Sheet256_combined.csv: R² = 0.9862, Components = 10
#
# Processed Sheet298_combined.csv: R² = 0.9894, Components = 10
#
# Processed Sheet400_combined.csv: R² = 0.9907, Components = 10
#
# Processed Sheet216_combined.csv: R² = 0.9854, Components = 10
# Processed Sheet81_combined.csv: R² = 0.9859, Components = 10
#
# Processed Sheet204_combined.csv: R² = 0.9953, Components = 10
# Processed Sheet26_combined.csv: R² = 0.9858, Components = 10Processed Sheet405_combined.csv: R² = 0.9800, Components = 10Processed Sheet189_combined.csv: R² = 0.9935, Components = 10Processed Sheet19_combined.csv: R² = 0.9809, Components = 10Processed Sheet481_combined.csv: R² = 0.9959, Components = 10Processed Sheet25_combined.csv: R² = 0.9942, Components = 10
# Processed Sheet221_combined.csv: R² = 0.9946, Components = 10Processed Sheet54_combined.csv: R² = 0.9921, Components = 10Processed Sheet176_combined.csv: R² = 0.9628, Components = 10
#
# Processed Sheet264_combined.csv: R² = 0.9728, Components = 10
#
#
# Processed Sheet257_combined.csv: R² = 0.9820, Components = 10
#
#
#
# Processed Sheet128_combined.csv: R² = 0.9875, Components = 10Processed Sheet38_combined.csv: R² = 0.9790, Components = 10Processed Sheet476_combined.csv: R² = 0.9775, Components = 10
#
# Processed Sheet117_combined.csv: R² = 0.9695, Components = 10Processed Sheet20_combined.csv: R² = 0.9881, Components = 10
# Processed Sheet393_combined.csv: R² = 0.9929, Components = 10Processed Sheet96_combined.csv: R² = 0.9806, Components = 10
#
#
# Processed Sheet157_combined.csv: R² = 0.9676, Components = 10Processed Sheet424_combined.csv: R² = 0.9965, Components = 10
# Processed Sheet458_combined.csv: R² = 0.9925, Components = 10
# Processed Sheet212_combined.csv: R² = 0.9754, Components = 10Processed Sheet82_combined.csv: R² = 0.9747, Components = 10Processed Sheet183_combined.csv: R² = 0.9927, Components = 10
#
#
# Processed Sheet395_combined.csv: R² = 0.9808, Components = 10
#
#
# Processed Sheet68_combined.csv: R² = 0.9868, Components = 10Processed Sheet422_combined.csv: R² = 0.9932, Components = 10
# Processed Sheet280_combined.csv: R² = 0.9301, Components = 10
#
#
# Processed Sheet248_combined.csv: R² = 0.9725, Components = 10
# Processed Sheet198_combined.csv: R² = 0.9785, Components = 10Processed Sheet235_combined.csv: R² = 0.9919, Components = 10Processed Sheet471_combined.csv: R² = 0.9828, Components = 10
# Processed Sheet226_combined.csv: R² = 0.9888, Components = 10Processed Sheet77_combined.csv: R² = 0.9895, Components = 10Processed Sheet8_combined.csv: R² = 0.9581, Components = 10
# Processed Sheet274_combined.csv: R² = 0.9912, Components = 10
#
#
#
# Processed Sheet102_combined.csv: R² = 0.9891, Components = 10Processed Sheet170_combined.csv: R² = 0.9940, Components = 10
# Processed Sheet278_combined.csv: R² = 0.9856, Components = 10
# Processed Sheet138_combined.csv: R² = 0.9855, Components = 10
# Processed Sheet31_combined.csv: R² = 0.9790, Components = 10
# Processed Sheet238_combined.csv: R² = 0.9934, Components = 10Processed Sheet86_combined.csv: R² = 0.9581, Components = 10Processed Sheet163_combined.csv: R² = 0.9666, Components = 10Processed Sheet202_combined.csv: R² = 0.9856, Components = 10Processed Sheet370_combined.csv: R² = 0.9880, Components = 10
#
#
# Processed Sheet462_combined.csv: R² = 0.9652, Components = 10
# Processed Sheet4_combined.csv: R² = 0.9875, Components = 10
#
# Processed Sheet70_combined.csv: R² = 0.9329, Components = 10Processed Sheet308_combined.csv: R² = 0.9692, Components = 10
#
#
#
# Processed Sheet273_combined.csv: R² = 0.9754, Components = 10Processed Sheet287_combined.csv: R² = 0.9957, Components = 10Processed Sheet410_combined.csv: R² = 0.9869, Components = 10Processed Sheet200_combined.csv: R² = 0.9858, Components = 10Processed Sheet324_combined.csv: R² = 0.9800, Components = 10Processed Sheet282_combined.csv: R² = 0.9228, Components = 10Processed Sheet327_combined.csv: R² = 0.9778, Components = 10
#
#
#
#
#
#
#
# Processed Sheet180_combined.csv: R² = 0.9956, Components = 10Processed Sheet147_combined.csv: R² = 0.9865, Components = 10Processed Sheet108_combined.csv: R² = 0.9714, Components = 10Processed Sheet293_combined.csv: R² = 0.9914, Components = 10
# Processed Sheet254_combined.csv: R² = 0.9842, Components = 10
#
# Processed Sheet325_combined.csv: R² = 0.9879, Components = 10Processed Sheet340_combined.csv: R² = 0.9806, Components = 10Processed Sheet107_combined.csv: R² = 0.9833, Components = 10Processed Sheet316_combined.csv: R² = 0.9859, Components = 10Processed Sheet356_combined.csv: R² = 0.9962, Components = 10
# Processed Sheet52_combined.csv: R² = 0.9867, Components = 10
# Processed Sheet60_combined.csv: R² = 0.9920, Components = 10Processed Sheet18_combined.csv: R² = 0.9496, Components = 10
# Processed Sheet398_combined.csv: R² = 0.9807, Components = 10
#
#
#
# Processed Sheet12_combined.csv: R² = 0.9915, Components = 10Processed Sheet9_combined.csv: R² = 0.9433, Components = 10
#
#
#
# Processed Sheet406_combined.csv: R² = 0.9842, Components = 10
# Processed Sheet186_combined.csv: R² = 0.9904, Components = 10
# Processed Sheet385_combined.csv: R² = 0.9951, Components = 10
#
# Processed Sheet474_combined.csv: R² = 0.9429, Components = 10Processed Sheet30_combined.csv: R² = 0.9850, Components = 10Processed Sheet103_combined.csv: R² = 0.9851, Components = 10
# Processed Sheet111_combined.csv: R² = 0.9792, Components = 10Processed Sheet134_combined.csv: R² = 0.9895, Components = 10Processed Sheet246_combined.csv: R² = 0.9875, Components = 10
# Processed Sheet323_combined.csv: R² = 0.9850, Components = 10
# Processed Sheet174_combined.csv: R² = 0.9893, Components = 10Processed Sheet468_combined.csv: R² = 0.9867, Components = 10Processed Sheet354_combined.csv: R² = 0.9881, Components = 10
#
# Processed Sheet452_combined.csv: R² = 0.9931, Components = 10
#
#
# Processed Sheet322_combined.csv: R² = 0.9895, Components = 10
#
#
#
#
#
# Processed Sheet67_combined.csv: R² = 0.9825, Components = 10Processed Sheet172_combined.csv: R² = 0.9595, Components = 10Processed Sheet223_combined.csv: R² = 0.9919, Components = 10Processed Sheet372_combined.csv: R² = 0.9954, Components = 10Processed Sheet59_combined.csv: R² = 0.9950, Components = 10Processed Sheet375_combined.csv: R² = 0.9782, Components = 10Processed Sheet89_combined.csv: R² = 0.9735, Components = 10Processed Sheet290_combined.csv: R² = 0.9929, Components = 10
#
# Processed Sheet300_combined.csv: R² = 0.9774, Components = 10Processed Sheet389_combined.csv: R² = 0.9702, Components = 10
#
#
# Processed Sheet381_combined.csv: R² = 0.9823, Components = 10Processed Sheet120_combined.csv: R² = 0.9925, Components = 10
#
# Processed Sheet152_combined.csv: R² = 0.9880, Components = 10
# Processed Sheet433_combined.csv: R² = 0.9951, Components = 10
#
# Processed Sheet6_combined.csv: R² = 0.9889, Components = 10
#
#
# Processed Sheet281_combined.csv: R² = 0.9931, Components = 10Processed Sheet112_combined.csv: R² = 0.9936, Components = 10Processed Sheet416_combined.csv: R² = 0.9889, Components = 10Processed Sheet195_combined.csv: R² = 0.9908, Components = 10
#
# Processed Sheet22_combined.csv: R² = 0.9400, Components = 10
#
# Processed Sheet411_combined.csv: R² = 0.9655, Components = 10
# Processed Sheet335_combined.csv: R² = 0.9829, Components = 10
#
# Processed Sheet314_combined.csv: R² = 0.9836, Components = 10
#
# Processed Sheet430_combined.csv: R² = 0.9717, Components = 10Processed Sheet80_combined.csv: R² = 0.9802, Components = 10
# Processed Sheet101_combined.csv: R² = 0.9922, Components = 10
#
# Processed Sheet417_combined.csv: R² = 0.9858, Components = 10Processed Sheet318_combined.csv: R² = 0.9732, Components = 10Processed Sheet53_combined.csv: R² = 0.9822, Components = 10
# Processed Sheet292_combined.csv: R² = 0.9842, Components = 10Processed Sheet270_combined.csv: R² = 0.9784, Components = 10
#
#
#
# Processed Sheet240_combined.csv: R² = 0.9796, Components = 10Processed Sheet169_combined.csv: R² = 0.9793, Components = 10Processed Sheet83_combined.csv: R² = 0.9663, Components = 10Processed Sheet440_combined.csv: R² = 0.9924, Components = 10Processed Sheet10_combined.csv: R² = 0.9916, Components = 10
# Processed Sheet297_combined.csv: R² = 0.9681, Components = 10Processed Sheet341_combined.csv: R² = 0.9907, Components = 10
#
# Processed Sheet313_combined.csv: R² = 0.9810, Components = 10Processed Sheet76_combined.csv: R² = 0.9985, Components = 10Processed Sheet260_combined.csv: R² = 0.9540, Components = 10
# Processed Sheet328_combined.csv: R² = 0.9978, Components = 10
# Processed Sheet271_combined.csv: R² = 0.9838, Components = 10
#
# Processed Sheet205_combined.csv: R² = 0.9314, Components = 10
#
#
# Processed Sheet207_combined.csv: R² = 0.9899, Components = 10
#
#
#
# Processed Sheet97_combined.csv: R² = 0.9907, Components = 10Processed Sheet24_combined.csv: R² = 0.9511, Components = 10Processed Sheet43_combined.csv: R² = 0.9873, Components = 10Processed Sheet362_combined.csv: R² = 0.9858, Components = 10Processed Sheet242_combined.csv: R² = 0.9910, Components = 10
# Processed Sheet402_combined.csv: R² = 0.9864, Components = 10Processed Sheet229_combined.csv: R² = 0.9745, Components = 10
# Processed Sheet444_combined.csv: R² = 0.9915, Components = 10
#
#
#
#
# Processed Sheet203_combined.csv: R² = 0.9641, Components = 10Processed Sheet390_combined.csv: R² = 0.9811, Components = 10Processed Sheet182_combined.csv: R² = 0.9978, Components = 10
#
# Processed Sheet167_combined.csv: R² = 0.9587, Components = 10Processed Sheet188_combined.csv: R² = 0.9865, Components = 10
# Processed Sheet310_combined.csv: R² = 0.9274, Components = 10
# Processed Sheet69_combined.csv: R² = 0.9929, Components = 10
# Processed Sheet447_combined.csv: R² = 0.9858, Components = 10
# Processed Sheet279_combined.csv: R² = 0.9718, Components = 10
# Processed Sheet47_combined.csv: R² = 0.9950, Components = 10
# Processed Sheet158_combined.csv: R² = 0.9841, Components = 10Processed Sheet62_combined.csv: R² = 0.9809, Components = 10Processed Sheet58_combined.csv: R² = 0.9815, Components = 10
#
#
# Processed Sheet336_combined.csv: R² = 0.9645, Components = 10
# Processed Sheet403_combined.csv: R² = 0.9886, Components = 10Processed Sheet361_combined.csv: R² = 0.9855, Components = 10Processed Sheet56_combined.csv: R² = 0.9931, Components = 10
#
#
# Processed Sheet414_combined.csv: R² = 0.9934, Components = 10Processed Sheet454_combined.csv: R² = 0.9969, Components = 10Processed Sheet442_combined.csv: R² = 0.9939, Components = 10
# Processed Sheet259_combined.csv: R² = 0.9689, Components = 10Processed Sheet269_combined.csv: R² = 0.9874, Components = 10
#
#
#
#
#
#
# Processed Sheet392_combined.csv: R² = 0.9868, Components = 10Processed Sheet66_combined.csv: R² = 0.9921, Components = 10
# Processed Sheet346_combined.csv: R² = 0.9833, Components = 10Processed Sheet306_combined.csv: R² = 0.9821, Components = 10Processed Sheet445_combined.csv: R² = 0.9769, Components = 10
#
#
#
#
# Processed Sheet34_combined.csv: R² = 0.9792, Components = 10
#
#
# Processed Sheet343_combined.csv: R² = 0.9822, Components = 10Processed Sheet232_combined.csv: R² = 0.9494, Components = 10Results saved to: /home/aricept094/mydata/sheets/combined_data/radial_results/Height_Anterior_Value/analysis_results_radial_1.csv
# Analysis Summary for radial_1:
# Files processed: 480
# Average R² Score: 0.9805
# Average Components Used: 10.0
#
# Processing radial_4 folder...
# Processed Sheet74_combined.csv: R² = 0.9932, Components = 10Processed Sheet412_combined.csv: R² = 0.9979, Components = 10Processed Sheet201_combined.csv: R² = 0.9990, Components = 10Processed Sheet404_combined.csv: R² = 0.9995, Components = 10Processed Sheet431_combined.csv: R² = 0.9941, Components = 10Processed Sheet373_combined.csv: R² = 0.9944, Components = 10Processed Sheet480_combined.csv: R² = 0.9973, Components = 10
#
#
# Processed Sheet124_combined.csv: R² = 0.9894, Components = 10
# Processed Sheet132_combined.csv: R² = 0.9920, Components = 10Processed Sheet312_combined.csv: R² = 0.9969, Components = 10Processed Sheet262_combined.csv: R² = 0.9969, Components = 10Processed Sheet125_combined.csv: R² = 0.9905, Components = 10Processed Sheet423_combined.csv: R² = 0.9907, Components = 10
#
#
#
#
#
#
# Processed Sheet466_combined.csv: R² = 0.9994, Components = 10
#
# Processed Sheet460_combined.csv: R² = 0.9970, Components = 10Processed Sheet295_combined.csv: R² = 0.9941, Components = 10Processed Sheet23_combined.csv: R² = 0.9954, Components = 10
# Processed Sheet321_combined.csv: R² = 0.9970, Components = 10
#
#
# Processed Sheet91_combined.csv: R² = 0.9884, Components = 10Processed Sheet209_combined.csv: R² = 0.9955, Components = 10Processed Sheet153_combined.csv: R² = 0.8632, Components = 10Processed Sheet304_combined.csv: R² = 0.9985, Components = 10
#
# Processed Sheet148_combined.csv: R² = 0.9865, Components = 10
#
# Processed Sheet160_combined.csv: R² = 0.9829, Components = 10Processed Sheet225_combined.csv: R² = 0.9984, Components = 10
# Processed Sheet311_combined.csv: R² = 0.9856, Components = 10
# Processed Sheet133_combined.csv: R² = 0.9851, Components = 10
#
# Processed Sheet95_combined.csv: R² = 0.9770, Components = 10
# Processed Sheet349_combined.csv: R² = 0.9936, Components = 10Processed Sheet29_combined.csv: R² = 0.9950, Components = 10
# Processed Sheet296_combined.csv: R² = 0.9924, Components = 10
# Processed Sheet483_combined.csv: R² = 0.9971, Components = 10Processed Sheet84_combined.csv: R² = 0.9931, Components = 10
# Processed Sheet419_combined.csv: R² = 0.9978, Components = 10Processed Sheet302_combined.csv: R² = 0.9926, Components = 10
# Processed Sheet397_combined.csv: R² = 0.9983, Components = 10
#
# Processed Sheet231_combined.csv: R² = 0.9522, Components = 10Processed Sheet434_combined.csv: R² = 0.9990, Components = 10
#
#
# Processed Sheet2_combined.csv: R² = 0.9693, Components = 10Processed Sheet227_combined.csv: R² = 0.9834, Components = 10Processed Sheet173_combined.csv: R² = 0.9797, Components = 10Processed Sheet230_combined.csv: R² = 0.9872, Components = 10Processed Sheet45_combined.csv: R² = 0.9970, Components = 10Processed Sheet217_combined.csv: R² = 0.9950, Components = 10Processed Sheet129_combined.csv: R² = 0.9940, Components = 10Processed Sheet228_combined.csv: R² = 0.9963, Components = 10
# Processed Sheet78_combined.csv: R² = 0.9988, Components = 10
#
#
#
#
#
#
#
#
#
#
# Processed Sheet421_combined.csv: R² = 0.9936, Components = 10Processed Sheet285_combined.csv: R² = 0.9947, Components = 10Processed Sheet41_combined.csv: R² = 0.9959, Components = 10Processed Sheet449_combined.csv: R² = 0.9980, Components = 10Processed Sheet437_combined.csv: R² = 0.9995, Components = 10Processed Sheet438_combined.csv: R² = 0.9997, Components = 10
#
# Processed Sheet291_combined.csv: R² = 0.9850, Components = 10
#
# Processed Sheet118_combined.csv: R² = 0.9539, Components = 10
#
# Processed Sheet439_combined.csv: R² = 0.9993, Components = 10Processed Sheet446_combined.csv: R² = 0.9991, Components = 10Processed Sheet367_combined.csv: R² = 0.9987, Components = 10Processed Sheet301_combined.csv: R² = 0.9880, Components = 10
#
#
# Processed Sheet40_combined.csv: R² = 0.9661, Components = 10Processed Sheet44_combined.csv: R² = 0.9969, Components = 10
#
#
# Processed Sheet320_combined.csv: R² = 0.9869, Components = 10Processed Sheet251_combined.csv: R² = 0.9849, Components = 10Processed Sheet432_combined.csv: R² = 0.9990, Components = 10
# Processed Sheet61_combined.csv: R² = 0.9916, Components = 10Processed Sheet465_combined.csv: R² = 0.9997, Components = 10Processed Sheet110_combined.csv: R² = 0.9868, Components = 10Processed Sheet378_combined.csv: R² = 0.9969, Components = 10Processed Sheet388_combined.csv: R² = 0.9891, Components = 10Processed Sheet453_combined.csv: R² = 0.9988, Components = 10
#
# Processed Sheet5_combined.csv: R² = 0.9959, Components = 10
#
# Processed Sheet332_combined.csv: R² = 0.9953, Components = 10
# Processed Sheet253_combined.csv: R² = 0.9893, Components = 10
# Processed Sheet171_combined.csv: R² = 0.9853, Components = 10
#
#
#
#
#
# Processed Sheet425_combined.csv: R² = 0.9996, Components = 10Processed Sheet236_combined.csv: R² = 0.9967, Components = 10Processed Sheet339_combined.csv: R² = 0.9995, Components = 10Processed Sheet116_combined.csv: R² = 0.9883, Components = 10
# Processed Sheet145_combined.csv: R² = 0.9638, Components = 10Processed Sheet13_combined.csv: R² = 0.9845, Components = 10Processed Sheet233_combined.csv: R² = 0.9985, Components = 10Processed Sheet342_combined.csv: R² = 0.9975, Components = 10Processed Sheet333_combined.csv: R² = 0.9984, Components = 10Processed Sheet360_combined.csv: R² = 0.9974, Components = 10Processed Sheet119_combined.csv: R² = 0.9906, Components = 10
#
#
#
#
#
#
#
#
#
#
# Processed Sheet131_combined.csv: R² = 0.9974, Components = 10Processed Sheet92_combined.csv: R² = 0.9791, Components = 10
# Processed Sheet126_combined.csv: R² = 0.9818, Components = 10Processed Sheet347_combined.csv: R² = 0.9949, Components = 10Processed Sheet175_combined.csv: R² = 0.9936, Components = 10Processed Sheet210_combined.csv: R² = 0.9956, Components = 10
# Processed Sheet65_combined.csv: R² = 0.9992, Components = 10Processed Sheet135_combined.csv: R² = 0.9952, Components = 10Processed Sheet130_combined.csv: R² = 0.9793, Components = 10Processed Sheet181_combined.csv: R² = 0.9997, Components = 10
#
#
#
#
# Processed Sheet268_combined.csv: R² = 0.9968, Components = 10Processed Sheet459_combined.csv: R² = 0.9956, Components = 10
# Processed Sheet234_combined.csv: R² = 0.9875, Components = 10Processed Sheet472_combined.csv: R² = 0.9996, Components = 10
#
#
# Processed Sheet330_combined.csv: R² = 0.9975, Components = 10Processed Sheet177_combined.csv: R² = 0.9933, Components = 10
# Processed Sheet353_combined.csv: R² = 0.9923, Components = 10Processed Sheet485_combined.csv: R² = 0.9995, Components = 10
#
#
# Processed Sheet436_combined.csv: R² = 0.9989, Components = 10
#
# Processed Sheet208_combined.csv: R² = 0.9827, Components = 10Processed Sheet15_combined.csv: R² = 0.9961, Components = 10
# Processed Sheet139_combined.csv: R² = 0.9947, Components = 10Processed Sheet391_combined.csv: R² = 0.9991, Components = 10
#
# Processed Sheet469_combined.csv: R² = 0.9973, Components = 10
# Processed Sheet244_combined.csv: R² = 0.9963, Components = 10
#
# Processed Sheet478_combined.csv: R² = 0.9995, Components = 10
# Processed Sheet344_combined.csv: R² = 0.9934, Components = 10Processed Sheet37_combined.csv: R² = 0.9977, Components = 10Processed Sheet72_combined.csv: R² = 0.9968, Components = 10Processed Sheet369_combined.csv: R² = 0.9974, Components = 10
#
# Processed Sheet413_combined.csv: R² = 0.9982, Components = 10
# Processed Sheet407_combined.csv: R² = 0.9956, Components = 10
# Processed Sheet48_combined.csv: R² = 0.9818, Components = 10Processed Sheet394_combined.csv: R² = 0.9989, Components = 10
#
# Processed Sheet164_combined.csv: R² = 0.9924, Components = 10
# Processed Sheet357_combined.csv: R² = 0.9990, Components = 10
# Processed Sheet50_combined.csv: R² = 0.9972, Components = 10
# Processed Sheet105_combined.csv: R² = 0.9810, Components = 10Processed Sheet470_combined.csv: R² = 0.9991, Components = 10Processed Sheet451_combined.csv: R² = 0.9984, Components = 10
#
#
#
#
# Processed Sheet415_combined.csv: R² = 0.9995, Components = 10
#
# Processed Sheet224_combined.csv: R² = 0.9961, Components = 10Processed Sheet338_combined.csv: R² = 0.9954, Components = 10Processed Sheet142_combined.csv: R² = 0.9837, Components = 10Processed Sheet214_combined.csv: R² = 0.9979, Components = 10
# Processed Sheet36_combined.csv: R² = 0.9932, Components = 10Processed Sheet161_combined.csv: R² = 0.9928, Components = 10Processed Sheet219_combined.csv: R² = 0.9978, Components = 10Processed Sheet16_combined.csv: R² = 0.9905, Components = 10
# Processed Sheet294_combined.csv: R² = 0.9941, Components = 10Processed Sheet477_combined.csv: R² = 0.9994, Components = 10Processed Sheet156_combined.csv: R² = 0.9819, Components = 10
#
#
#
#
#
# Processed Sheet39_combined.csv: R² = 0.9478, Components = 10
#
#
#
#
# Processed Sheet286_combined.csv: R² = 0.9962, Components = 10
# Processed Sheet303_combined.csv: R² = 0.9992, Components = 10Processed Sheet73_combined.csv: R² = 0.9682, Components = 10Processed Sheet267_combined.csv: R² = 0.9969, Components = 10Processed Sheet191_combined.csv: R² = 0.9996, Components = 10Processed Sheet75_combined.csv: R² = 0.9964, Components = 10Processed Sheet243_combined.csv: R² = 0.9988, Components = 10Processed Sheet55_combined.csv: R² = 0.9968, Components = 10
#
# Processed Sheet315_combined.csv: R² = 0.9915, Components = 10
# Processed Sheet35_combined.csv: R² = 0.9925, Components = 10
# Processed Sheet355_combined.csv: R² = 0.9956, Components = 10Processed Sheet479_combined.csv: R² = 0.9902, Components = 10
#
#
#
#
# Processed Sheet350_combined.csv: R² = 0.9958, Components = 10
# Processed Sheet213_combined.csv: R² = 0.9974, Components = 10Processed Sheet255_combined.csv: R² = 0.9912, Components = 10Processed Sheet190_combined.csv: R² = 0.9983, Components = 10
# Processed Sheet63_combined.csv: R² = 0.9901, Components = 10Processed Sheet106_combined.csv: R² = 0.9897, Components = 10
#
#
# Processed Sheet374_combined.csv: R² = 0.9995, Components = 10
#
# Processed Sheet348_combined.csv: R² = 0.9831, Components = 10
#
# Processed Sheet28_combined.csv: R² = 0.9684, Components = 10Processed Sheet467_combined.csv: R² = 0.9989, Components = 10
#
#
#
# Processed Sheet399_combined.csv: R² = 0.9912, Components = 10
# Processed Sheet211_combined.csv: R² = 0.9991, Components = 10Processed Sheet386_combined.csv: R² = 0.9910, Components = 10Processed Sheet272_combined.csv: R² = 0.9973, Components = 10Processed Sheet283_combined.csv: R² = 0.9905, Components = 10Processed Sheet109_combined.csv: R² = 0.9876, Components = 10Processed Sheet123_combined.csv: R² = 0.9735, Components = 10Processed Sheet266_combined.csv: R² = 0.9983, Components = 10Processed Sheet239_combined.csv: R² = 0.9972, Components = 10Processed Sheet263_combined.csv: R² = 0.9871, Components = 10Processed Sheet166_combined.csv: R² = 0.9795, Components = 10Processed Sheet420_combined.csv: R² = 0.9993, Components = 10Processed Sheet42_combined.csv: R² = 0.9993, Components = 10Processed Sheet194_combined.csv: R² = 0.9993, Components = 10
#
#
#
#
#
#
#
# Processed Sheet450_combined.csv: R² = 0.9988, Components = 10
#
#
# Processed Sheet261_combined.csv: R² = 0.9941, Components = 10
#
#
#
# Processed Sheet363_combined.csv: R² = 0.9899, Components = 10Processed Sheet127_combined.csv: R² = 0.9880, Components = 10Processed Sheet98_combined.csv: R² = 0.9843, Components = 10Processed Sheet337_combined.csv: R² = 0.9950, Components = 10
#
#
# Processed Sheet85_combined.csv: R² = 0.9834, Components = 10Processed Sheet90_combined.csv: R² = 0.9939, Components = 10Processed Sheet365_combined.csv: R² = 0.9985, Components = 10Processed Sheet383_combined.csv: R² = 0.9976, Components = 10Processed Sheet426_combined.csv: R² = 0.9969, Components = 10
# Processed Sheet3_combined.csv: R² = 0.9928, Components = 10
#
#
#
# Processed Sheet122_combined.csv: R² = 0.9987, Components = 10Processed Sheet140_combined.csv: R² = 0.9891, Components = 10Processed Sheet277_combined.csv: R² = 0.9943, Components = 10Processed Sheet396_combined.csv: R² = 0.9984, Components = 10Processed Sheet345_combined.csv: R² = 0.9993, Components = 10
#
# Processed Sheet196_combined.csv: R² = 0.9956, Components = 10
#
# Processed Sheet33_combined.csv: R² = 0.9893, Components = 10
#
#
#
# Processed Sheet319_combined.csv: R² = 0.9800, Components = 10Processed Sheet368_combined.csv: R² = 0.9974, Components = 10Processed Sheet162_combined.csv: R² = 0.9773, Components = 10Processed Sheet245_combined.csv: R² = 0.9933, Components = 10
# Processed Sheet387_combined.csv: R² = 0.9953, Components = 10Processed Sheet100_combined.csv: R² = 0.9774, Components = 10
#
#
#
# Processed Sheet114_combined.csv: R² = 0.9883, Components = 10Processed Sheet150_combined.csv: R² = 0.9983, Components = 10Processed Sheet307_combined.csv: R² = 0.9971, Components = 10
#
# Processed Sheet17_combined.csv: R² = 0.9838, Components = 10
# Processed Sheet121_combined.csv: R² = 0.9963, Components = 10
# Processed Sheet275_combined.csv: R² = 0.9975, Components = 10Processed Sheet168_combined.csv: R² = 0.9632, Components = 10Processed Sheet464_combined.csv: R² = 0.9998, Components = 10
#
#
# Processed Sheet326_combined.csv: R² = 0.9934, Components = 10Processed Sheet71_combined.csv: R² = 0.9928, Components = 10Processed Sheet463_combined.csv: R² = 0.9982, Components = 10Processed Sheet222_combined.csv: R² = 0.9973, Components = 10Processed Sheet461_combined.csv: R² = 0.9966, Components = 10
# Processed Sheet408_combined.csv: R² = 0.9996, Components = 10
#
#
#
# Processed Sheet113_combined.csv: R² = 0.9894, Components = 10Processed Sheet206_combined.csv: R² = 0.9990, Components = 10
#
#
#
# Processed Sheet154_combined.csv: R² = 0.9952, Components = 10Processed Sheet11_combined.csv: R² = 0.9948, Components = 10Processed Sheet99_combined.csv: R² = 0.9915, Components = 10
#
# Processed Sheet187_combined.csv: R² = 0.9977, Components = 10
#
#
# Processed Sheet247_combined.csv: R² = 0.9959, Components = 10
# Processed Sheet455_combined.csv: R² = 0.9983, Components = 10
# Processed Sheet220_combined.csv: R² = 0.9983, Components = 10Processed Sheet305_combined.csv: R² = 0.9953, Components = 10Processed Sheet185_combined.csv: R² = 0.9952, Components = 10
#
#
# Processed Sheet401_combined.csv: R² = 0.9953, Components = 10Processed Sheet87_combined.csv: R² = 0.9874, Components = 10
#
# Processed Sheet482_combined.csv: R² = 0.9994, Components = 10Processed Sheet377_combined.csv: R² = 0.9959, Components = 10Processed Sheet241_combined.csv: R² = 0.9817, Components = 10Processed Sheet448_combined.csv: R² = 0.9992, Components = 10Processed Sheet351_combined.csv: R² = 0.9869, Components = 10
# Processed Sheet27_combined.csv: R² = 0.9970, Components = 10Processed Sheet250_combined.csv: R² = 0.9793, Components = 10
#
# Processed Sheet193_combined.csv: R² = 0.9945, Components = 10
#
#
#
# Processed Sheet14_combined.csv: R² = 0.9915, Components = 10Processed Sheet428_combined.csv: R² = 0.9998, Components = 10
#
# Processed Sheet136_combined.csv: R² = 0.9912, Components = 10
# Processed Sheet149_combined.csv: R² = 0.9924, Components = 10
# Processed Sheet309_combined.csv: R² = 0.9990, Components = 10Processed Sheet32_combined.csv: R² = 0.9960, Components = 10Processed Sheet288_combined.csv: R² = 0.9829, Components = 10
# Processed Sheet192_combined.csv: R² = 0.9996, Components = 10
# Processed Sheet199_combined.csv: R² = 0.9993, Components = 10Processed Sheet258_combined.csv: R² = 0.9933, Components = 10Processed Sheet93_combined.csv: R² = 0.9853, Components = 10
# Processed Sheet51_combined.csv: R² = 0.9901, Components = 10
#
#
#
# Processed Sheet380_combined.csv: R² = 0.9937, Components = 10Processed Sheet155_combined.csv: R² = 0.9507, Components = 10Processed Sheet179_combined.csv: R² = 0.9996, Components = 10
#
#
# Processed Sheet115_combined.csv: R² = 0.9959, Components = 10
#
#
# Processed Sheet143_combined.csv: R² = 0.9989, Components = 10
# Processed Sheet457_combined.csv: R² = 0.9893, Components = 10Processed Sheet165_combined.csv: R² = 0.9872, Components = 10
# Processed Sheet46_combined.csv: R² = 0.9981, Components = 10
# Processed Sheet331_combined.csv: R² = 0.9989, Components = 10Processed Sheet79_combined.csv: R² = 0.9988, Components = 10Processed Sheet473_combined.csv: R² = 0.9990, Components = 10Processed Sheet159_combined.csv: R² = 0.9735, Components = 10
#
#
# Processed Sheet144_combined.csv: R² = 0.9911, Components = 10
# Processed Sheet371_combined.csv: R² = 0.9963, Components = 10Processed Sheet441_combined.csv: R² = 0.9963, Components = 10
#
#
# Processed Sheet409_combined.csv: R² = 0.9992, Components = 10Processed Sheet329_combined.csv: R² = 0.9942, Components = 10
# Processed Sheet359_combined.csv: R² = 0.9961, Components = 10
#
#
# Processed Sheet484_combined.csv: R² = 0.9983, Components = 10Processed Sheet197_combined.csv: R² = 0.9912, Components = 10Processed Sheet64_combined.csv: R² = 0.9969, Components = 10Processed Sheet358_combined.csv: R² = 0.9967, Components = 10Processed Sheet218_combined.csv: R² = 0.9961, Components = 10Processed Sheet249_combined.csv: R² = 0.9913, Components = 10Processed Sheet456_combined.csv: R² = 0.9958, Components = 10
#
#
# Processed Sheet94_combined.csv: R² = 0.9720, Components = 10
# Processed Sheet376_combined.csv: R² = 0.9920, Components = 10
#
#
# Processed Sheet151_combined.csv: R² = 0.9982, Components = 10
# Processed Sheet364_combined.csv: R² = 0.9839, Components = 10Processed Sheet429_combined.csv: R² = 0.9994, Components = 10
#
#
# Processed Sheet366_combined.csv: R² = 0.9442, Components = 10Processed Sheet146_combined.csv: R² = 0.9930, Components = 10Processed Sheet141_combined.csv: R² = 0.9880, Components = 10Processed Sheet443_combined.csv: R² = 0.9995, Components = 10Processed Sheet299_combined.csv: R² = 0.9781, Components = 10
# Processed Sheet384_combined.csv: R² = 0.9993, Components = 10
#
#
#
#
# Processed Sheet49_combined.csv: R² = 0.9916, Components = 10Processed Sheet276_combined.csv: R² = 0.9902, Components = 10Processed Sheet184_combined.csv: R² = 0.9572, Components = 10Processed Sheet427_combined.csv: R² = 0.9992, Components = 10
#
# Processed Sheet435_combined.csv: R² = 0.9984, Components = 10
#
#
# Processed Sheet289_combined.csv: R² = 0.9928, Components = 10
#
# Processed Sheet252_combined.csv: R² = 0.9984, Components = 10
#
# Processed Sheet21_combined.csv: R² = 0.9965, Components = 10
# ...
#
#
#
#
#
#
#
#
# Processed Sheet351_combined.csv: R² = 0.9988, Components = 10Processed Sheet258_combined.csv: R² = 0.9984, Components = 10Processed Sheet32_combined.csv: R² = 0.9815, Components = 10Processed Sheet192_combined.csv: R² = 0.9684, Components = 10
# Processed Sheet149_combined.csv: R² = 0.9992, Components = 10Processed Sheet288_combined.csv: R² = 0.9807, Components = 10Processed Sheet14_combined.csv: R² = 0.9940, Components = 10Processed Sheet220_combined.csv: R² = 0.9950, Components = 10Processed Sheet309_combined.csv: R² = 0.9716, Components = 10Processed Sheet51_combined.csv: R² = 0.9926, Components = 10Processed Sheet93_combined.csv: R² = 0.9995, Components = 10
#
#
#
# Processed Sheet199_combined.csv: R² = 0.9994, Components = 10Processed Sheet27_combined.csv: R² = 0.9982, Components = 10Processed Sheet448_combined.csv: R² = 0.9935, Components = 10
#
#
#
# Processed Sheet380_combined.csv: R² = 0.9655, Components = 10
# Processed Sheet155_combined.csv: R² = 0.9952, Components = 10Processed Sheet428_combined.csv: R² = 0.9874, Components = 10Processed Sheet143_combined.csv: R² = 0.9975, Components = 10
#
# Processed Sheet457_combined.csv: R² = 0.9928, Components = 10
#
#
#
#
# Processed Sheet115_combined.csv: R² = 0.9850, Components = 10
#
# Processed Sheet179_combined.csv: R² = 0.9994, Components = 10Processed Sheet79_combined.csv: R² = 0.9938, Components = 10Processed Sheet46_combined.csv: R² = 0.9971, Components = 10Processed Sheet165_combined.csv: R² = 0.9762, Components = 10
# Processed Sheet331_combined.csv: R² = 0.9980, Components = 10
#
#
#
# Processed Sheet159_combined.csv: R² = 0.9889, Components = 10Processed Sheet144_combined.csv: R² = 0.9318, Components = 10Processed Sheet473_combined.csv: R² = 0.9980, Components = 10Processed Sheet441_combined.csv: R² = 0.9826, Components = 10Processed Sheet484_combined.csv: R² = 0.9801, Components = 10
# Processed Sheet359_combined.csv: R² = 0.9924, Components = 10
#
# Processed Sheet218_combined.csv: R² = 0.9880, Components = 10Processed Sheet409_combined.csv: R² = 0.9847, Components = 10
# Processed Sheet371_combined.csv: R² = 0.8980, Components = 10Processed Sheet329_combined.csv: R² = 0.9774, Components = 10
#
# Processed Sheet358_combined.csv: R² = 0.9323, Components = 10
#
#
#
# Processed Sheet456_combined.csv: R² = 0.9712, Components = 10Processed Sheet249_combined.csv: R² = 0.9987, Components = 10Processed Sheet197_combined.csv: R² = 0.8699, Components = 10Processed Sheet376_combined.csv: R² = 0.9943, Components = 10
#
# Processed Sheet146_combined.csv: R² = 0.8741, Components = 10
# Processed Sheet443_combined.csv: R² = 0.9978, Components = 10Processed Sheet364_combined.csv: R² = 0.9292, Components = 10Processed Sheet151_combined.csv: R² = 0.8812, Components = 10
# Processed Sheet64_combined.csv: R² = 0.9918, Components = 10Processed Sheet94_combined.csv: R² = 0.9972, Components = 10
#
#
# Processed Sheet384_combined.csv: R² = 0.9920, Components = 10Processed Sheet429_combined.csv: R² = 0.9894, Components = 10
#
#
#
#
# Processed Sheet49_combined.csv: R² = 0.8881, Components = 10Processed Sheet299_combined.csv: R² = 0.9978, Components = 10Processed Sheet435_combined.csv: R² = 0.9960, Components = 10Processed Sheet141_combined.csv: R² = 0.9944, Components = 10
# Processed Sheet289_combined.csv: R² = 0.9901, Components = 10Processed Sheet184_combined.csv: R² = 0.9927, Components = 10
# Processed Sheet276_combined.csv: R² = 0.9374, Components = 10
#
#
# Processed Sheet21_combined.csv: R² = 0.9997, Components = 10Processed Sheet366_combined.csv: R² = 0.9954, Components = 10
# Processed Sheet427_combined.csv: R² = 0.9412, Components = 10
#
# Processed Sheet317_combined.csv: R² = 0.9919, Components = 10Processed Sheet252_combined.csv: R² = 0.9707, Components = 10
# Processed Sheet382_combined.csv: R² = 0.9973, Components = 10Processed Sheet475_combined.csv: R² = 0.9776, Components = 10Processed Sheet284_combined.csv: R² = 0.9932, Components = 10
#
#
# Processed Sheet7_combined.csv: R² = 0.9968, Components = 10
# Processed Sheet352_combined.csv: R² = 0.9425, Components = 10Processed Sheet265_combined.csv: R² = 0.9946, Components = 10
#
#
#
#
# Processed Sheet418_combined.csv: R² = 0.9306, Components = 10Processed Sheet215_combined.csv: R² = 0.9994, Components = 10Processed Sheet81_combined.csv: R² = 0.9984, Components = 10
# Processed Sheet57_combined.csv: R² = 0.9979, Components = 10
# Processed Sheet379_combined.csv: R² = 0.9859, Components = 10
#
#
# Processed Sheet204_combined.csv: R² = 0.9975, Components = 10Processed Sheet137_combined.csv: R² = 0.9877, Components = 10Processed Sheet216_combined.csv: R² = 0.9227, Components = 10Processed Sheet400_combined.csv: R² = 0.9620, Components = 10
# Processed Sheet256_combined.csv: R² = 0.9993, Components = 10
#
#
# Processed Sheet26_combined.csv: R² = 0.9942, Components = 10
#
#
# Processed Sheet19_combined.csv: R² = 0.9929, Components = 10Processed Sheet88_combined.csv: R² = 0.9967, Components = 10Processed Sheet298_combined.csv: R² = 0.9500, Components = 10
# Processed Sheet481_combined.csv: R² = 0.9997, Components = 10Processed Sheet25_combined.csv: R² = 0.9857, Components = 10
# Processed Sheet405_combined.csv: R² = 0.9970, Components = 10Processed Sheet189_combined.csv: R² = 0.9962, Components = 10
# Processed Sheet221_combined.csv: R² = 0.9951, Components = 10
#
#
#
# Processed Sheet257_combined.csv: R² = 0.9993, Components = 10
# Processed Sheet176_combined.csv: R² = 0.9944, Components = 10
#
# Processed Sheet424_combined.csv: R² = 0.9792, Components = 10Processed Sheet20_combined.csv: R² = 0.9994, Components = 10Processed Sheet54_combined.csv: R² = 0.9966, Components = 10
# Processed Sheet128_combined.csv: R² = 0.9957, Components = 10Processed Sheet264_combined.csv: R² = 0.9916, Components = 10Processed Sheet117_combined.csv: R² = 0.9990, Components = 10
# Processed Sheet157_combined.csv: R² = 0.9851, Components = 10
#
#
# Processed Sheet183_combined.csv: R² = 0.9969, Components = 10Processed Sheet68_combined.csv: R² = 0.9851, Components = 10Processed Sheet476_combined.csv: R² = 0.9655, Components = 10
# Processed Sheet393_combined.csv: R² = 0.9932, Components = 10
# Processed Sheet96_combined.csv: R² = 0.9978, Components = 10Processed Sheet395_combined.csv: R² = 0.9969, Components = 10Processed Sheet280_combined.csv: R² = 0.9995, Components = 10
#
# Processed Sheet38_combined.csv: R² = 0.9198, Components = 10Processed Sheet235_combined.csv: R² = 0.9976, Components = 10
#
# Processed Sheet212_combined.csv: R² = 0.9763, Components = 10
#
# Processed Sheet82_combined.csv: R² = 0.9954, Components = 10Processed Sheet422_combined.csv: R² = 0.9996, Components = 10
#
# Processed Sheet458_combined.csv: R² = 0.9831, Components = 10
#
#
#
#
# Processed Sheet274_combined.csv: R² = 0.9972, Components = 10Processed Sheet471_combined.csv: R² = 0.9995, Components = 10Processed Sheet102_combined.csv: R² = 0.9986, Components = 10Processed Sheet278_combined.csv: R² = 0.9147, Components = 10Processed Sheet8_combined.csv: R² = 0.9972, Components = 10Processed Sheet226_combined.csv: R² = 0.9962, Components = 10
#
# Processed Sheet170_combined.csv: R² = 0.9795, Components = 10Processed Sheet31_combined.csv: R² = 0.9874, Components = 10
# Processed Sheet77_combined.csv: R² = 0.9978, Components = 10
#
# Processed Sheet202_combined.csv: R² = 0.9950, Components = 10
#
#
# Processed Sheet138_combined.csv: R² = 0.9892, Components = 10Processed Sheet248_combined.csv: R² = 0.9943, Components = 10Processed Sheet198_combined.csv: R² = 0.9992, Components = 10Processed Sheet238_combined.csv: R² = 0.9503, Components = 10
# Processed Sheet163_combined.csv: R² = 0.9991, Components = 10
#
# Processed Sheet86_combined.csv: R² = 0.9972, Components = 10
#
# Processed Sheet370_combined.csv: R² = 0.9721, Components = 10
#
#
#
# Processed Sheet70_combined.csv: R² = 0.9916, Components = 10Processed Sheet410_combined.csv: R² = 0.9998, Components = 10Processed Sheet308_combined.csv: R² = 0.9435, Components = 10Processed Sheet462_combined.csv: R² = 0.9997, Components = 10Processed Sheet4_combined.csv: R² = 0.9965, Components = 10Processed Sheet282_combined.csv: R² = 0.9896, Components = 10
# Processed Sheet327_combined.csv: R² = 0.9818, Components = 10
#
#
#
#
#
#
# Processed Sheet273_combined.csv: R² = 0.9808, Components = 10
# Processed Sheet287_combined.csv: R² = 0.9983, Components = 10Processed Sheet324_combined.csv: R² = 0.9931, Components = 10
# Processed Sheet108_combined.csv: R² = 0.9965, Components = 10Processed Sheet340_combined.csv: R² = 0.9978, Components = 10Processed Sheet200_combined.csv: R² = 0.9958, Components = 10
# Processed Sheet9_combined.csv: R² = 0.9987, Components = 10
# Processed Sheet147_combined.csv: R² = 0.9484, Components = 10
#
# Processed Sheet254_combined.csv: R² = 0.9554, Components = 10Processed Sheet293_combined.csv: R² = 0.9922, Components = 10
# Processed Sheet52_combined.csv: R² = 0.9918, Components = 10
#
# Processed Sheet180_combined.csv: R² = 0.9845, Components = 10Processed Sheet316_combined.csv: R² = 0.9968, Components = 10Processed Sheet325_combined.csv: R² = 0.9679, Components = 10Processed Sheet356_combined.csv: R² = 0.9995, Components = 10
#
#
# Processed Sheet12_combined.csv: R² = 0.9731, Components = 10
# Processed Sheet18_combined.csv: R² = 0.9968, Components = 10
# Processed Sheet398_combined.csv: R² = 0.9940, Components = 10Processed Sheet107_combined.csv: R² = 0.9991, Components = 10Processed Sheet406_combined.csv: R² = 0.9997, Components = 10Processed Sheet385_combined.csv: R² = 0.9953, Components = 10Processed Sheet186_combined.csv: R² = 0.9973, Components = 10Processed Sheet60_combined.csv: R² = 0.9784, Components = 10
# Processed Sheet103_combined.csv: R² = 0.9920, Components = 10Processed Sheet246_combined.csv: R² = 0.9965, Components = 10Processed Sheet474_combined.csv: R² = 0.9706, Components = 10
#
#
#
#
#
#
# Processed Sheet30_combined.csv: R² = 0.9989, Components = 10Processed Sheet174_combined.csv: R² = 0.9931, Components = 10
# Processed Sheet172_combined.csv: R² = 0.9530, Components = 10
# Processed Sheet111_combined.csv: R² = 0.9996, Components = 10
# Processed Sheet323_combined.csv: R² = 0.9970, Components = 10
#
#
# Processed Sheet468_combined.csv: R² = 0.9764, Components = 10Processed Sheet67_combined.csv: R² = 0.9958, Components = 10
# Processed Sheet322_combined.csv: R² = 0.9958, Components = 10Processed Sheet452_combined.csv: R² = 0.9870, Components = 10
# Processed Sheet354_combined.csv: R² = 0.9995, Components = 10
#
#
# Processed Sheet223_combined.csv: R² = 0.9983, Components = 10
# Processed Sheet134_combined.csv: R² = 0.9580, Components = 10
# Processed Sheet372_combined.csv: R² = 0.9849, Components = 10Processed Sheet59_combined.csv: R² = 0.9907, Components = 10
# Processed Sheet89_combined.csv: R² = 0.9972, Components = 10
#
# Processed Sheet389_combined.csv: R² = 0.8620, Components = 10
#
#
# Processed Sheet375_combined.csv: R² = 0.9529, Components = 10Processed Sheet152_combined.csv: R² = 0.9954, Components = 10Processed Sheet290_combined.csv: R² = 0.9980, Components = 10Processed Sheet120_combined.csv: R² = 0.9992, Components = 10
#
#
# Processed Sheet22_combined.csv: R² = 0.8683, Components = 10Processed Sheet112_combined.csv: R² = 0.9455, Components = 10Processed Sheet281_combined.csv: R² = 0.9993, Components = 10
# Processed Sheet300_combined.csv: R² = 0.6177, Components = 10Processed Sheet335_combined.csv: R² = 0.9993, Components = 10
#
# Processed Sheet101_combined.csv: R² = 0.9850, Components = 10Processed Sheet411_combined.csv: R² = 0.9992, Components = 10
# Processed Sheet416_combined.csv: R² = 0.9986, Components = 10
# Processed Sheet430_combined.csv: R² = 0.9989, Components = 10
# Processed Sheet433_combined.csv: R² = 0.9986, Components = 10Processed Sheet381_combined.csv: R² = 0.9991, Components = 10Processed Sheet80_combined.csv: R² = 0.9987, Components = 10Processed Sheet318_combined.csv: R² = 0.9974, Components = 10
# Processed Sheet314_combined.csv: R² = 0.9753, Components = 10
# Processed Sheet195_combined.csv: R² = 0.9994, Components = 10
#
#
#
#
#
#
#
# Processed Sheet292_combined.csv: R² = 0.9944, Components = 10Processed Sheet240_combined.csv: R² = 0.9837, Components = 10
# Processed Sheet169_combined.csv: R² = 0.9577, Components = 10Processed Sheet417_combined.csv: R² = 0.9993, Components = 10Processed Sheet53_combined.csv: R² = 0.9412, Components = 10Processed Sheet297_combined.csv: R² = 0.9991, Components = 10Processed Sheet6_combined.csv: R² = 0.9885, Components = 10Processed Sheet10_combined.csv: R² = 0.9991, Components = 10
#
#
# Processed Sheet270_combined.csv: R² = 0.9969, Components = 10Processed Sheet341_combined.csv: R² = 0.9988, Components = 10
# Processed Sheet260_combined.csv: R² = 0.9969, Components = 10Processed Sheet440_combined.csv: R² = 0.9419, Components = 10Processed Sheet83_combined.csv: R² = 0.9973, Components = 10
#
#
# Processed Sheet205_combined.csv: R² = 0.9995, Components = 10
# Processed Sheet313_combined.csv: R² = 0.9988, Components = 10
# Processed Sheet271_combined.csv: R² = 0.9988, Components = 10Processed Sheet76_combined.csv: R² = 0.9985, Components = 10
#
#
#
#
#
#
# Processed Sheet328_combined.csv: R² = 0.9991, Components = 10
# Processed Sheet362_combined.csv: R² = 0.9918, Components = 10
# Processed Sheet97_combined.csv: R² = 0.9988, Components = 10Processed Sheet43_combined.csv: R² = 0.9975, Components = 10
# Processed Sheet24_combined.csv: R² = 0.9991, Components = 10
# Processed Sheet402_combined.csv: R² = 0.9941, Components = 10
#
# Processed Sheet229_combined.csv: R² = 0.9628, Components = 10Processed Sheet203_combined.csv: R² = 0.9977, Components = 10
#
# Processed Sheet188_combined.csv: R² = 0.9964, Components = 10
# Processed Sheet47_combined.csv: R² = 0.9907, Components = 10Processed Sheet444_combined.csv: R² = 0.9976, Components = 10
# Processed Sheet62_combined.csv: R² = 0.9225, Components = 10Processed Sheet310_combined.csv: R² = 0.9990, Components = 10Processed Sheet242_combined.csv: R² = 0.9982, Components = 10
#
#
# Processed Sheet390_combined.csv: R² = 0.9904, Components = 10Processed Sheet182_combined.csv: R² = 0.9937, Components = 10Processed Sheet167_combined.csv: R² = 0.7660, Components = 10
#
# Processed Sheet69_combined.csv: R² = 0.9932, Components = 10
# Processed Sheet58_combined.csv: R² = 0.9971, Components = 10Processed Sheet207_combined.csv: R² = 0.9982, Components = 10Processed Sheet279_combined.csv: R² = 0.9745, Components = 10Processed Sheet336_combined.csv: R² = 0.9982, Components = 10
#
# Processed Sheet158_combined.csv: R² = 0.9983, Components = 10
# Processed Sheet447_combined.csv: R² = 0.9996, Components = 10
#
#
#
#
# Processed Sheet56_combined.csv: R² = 0.9894, Components = 10Processed Sheet403_combined.csv: R² = 0.9927, Components = 10Processed Sheet454_combined.csv: R² = 0.9843, Components = 10Processed Sheet259_combined.csv: R² = 0.9989, Components = 10Processed Sheet442_combined.csv: R² = 0.9755, Components = 10
# Processed Sheet392_combined.csv: R² = 0.9851, Components = 10Processed Sheet269_combined.csv: R² = 0.9984, Components = 10
# Processed Sheet361_combined.csv: R² = 0.9988, Components = 10Processed Sheet343_combined.csv: R² = 0.9961, Components = 10Processed Sheet66_combined.csv: R² = 0.9966, Components = 10
#
#
#
#
#
#
# Processed Sheet414_combined.csv: R² = 0.9988, Components = 10Processed Sheet346_combined.csv: R² = 0.9129, Components = 10Processed Sheet34_combined.csv: R² = 0.9915, Components = 10
#
#
#
# Processed Sheet445_combined.csv: R² = 0.9989, Components = 10
#
# Processed Sheet232_combined.csv: R² = 0.8206, Components = 10Processed Sheet306_combined.csv: R² = 0.9993, Components = 10
#
# Results saved to: /home/aricept094/mydata/sheets/combined_data/radial_results/Height_Anterior_Value/analysis_results_radial_24.csv
# Analysis Summary for radial_24:
# Files processed: 480
# Average R² Score: 0.9792
# Average Components Used: 10.0
#
# All radial folders have been processed.

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import r2_score
from pathlib import Path
import concurrent.futures
from functools import lru_cache
import multiprocessing
import warnings
warnings.filterwarnings('ignore')

# Constants
MAX_MERIDIAN_COMPONENTS = 10     
DATA_DIR = Path("/home/aricept094/mydata/sheets/combined_data")
VARIANCE_THRESHOLD = 99.99
MAX_WORKERS = max(1, int(multiprocessing.cpu_count() * 0.99))
OUTPUT_FILE = "fourier_analysis_results.csv"

@lru_cache(maxsize=None)
def calculate_trig_terms(m, n_points):
    """Calculate trigonometric terms for Fourier series."""
    angle = 2 * np.pi * m * np.arange(n_points) / n_points
    return np.cos(angle), np.sin(angle)

def calculate_phase_angle(am, bm):
    """Calculate phase angle from Fourier coefficients."""
    return np.arctan2(bm, am)

def calculate_fourier_components(meridian_indices, keratometry_values):
    """Calculate Fourier components using amplitudes (cn) approach."""
    n_meridian = len(meridian_indices)
    norm_factor = 2 / n_meridian
    
    # Initialize result dictionaries
    dc_component = np.mean(keratometry_values)
    amplitudes = {'a0': dc_component}
    phases = {}
    total_energy = dc_component**2
    
    m = 1
    cumulative_variance = 0
    higher_order_amplitude = 0
    
    while cumulative_variance < VARIANCE_THRESHOLD and m <= MAX_MERIDIAN_COMPONENTS:
        cos_m, sin_m = calculate_trig_terms(m, n_meridian)
        am = norm_factor * np.sum(keratometry_values * cos_m)
        bm = norm_factor * np.sum(keratometry_values * sin_m)
        
        # Calculate amplitude (cn) and phase
        cn = np.sqrt(am**2 + bm**2)
        phase = calculate_phase_angle(am, bm)
        
        current_energy = cn**2
        total_energy += current_energy
        
        # Store specific components
        if m <= 2:
            amplitudes[f'component_{m}_amplitude'] = cn
            phases[f'component_{m}_phase'] = phase
        else:
            higher_order_amplitude += cn
            
        m += 1
    
    # Calculate final metrics
    components_used = m - 1
    cumulative_variance = (total_energy / total_energy) * 100
    
    # Add higher order amplitude sum
    amplitudes['higher_order_amplitude_sum'] = higher_order_amplitude
    
    # Calculate reconstructed signal using amplitudes and phases
    reconstructed = np.full(n_meridian, dc_component)
    for m in range(1, components_used + 1):
        angle = 2 * np.pi * m * np.arange(n_meridian) / n_meridian
        if m <= 2:
            cn = amplitudes[f'component_{m}_amplitude']
            phase = phases[f'component_{m}_phase']
            reconstructed += cn * np.cos(angle - phase)
        else:
            cos_m, sin_m = calculate_trig_terms(m, n_meridian)
            am = norm_factor * np.sum(keratometry_values * cos_m)
            bm = norm_factor * np.sum(keratometry_values * sin_m)
            cn = np.sqrt(am**2 + bm**2)
            phase = calculate_phase_angle(am, bm)
            reconstructed += cn * np.cos(angle - phase)
    
    r2 = r2_score(keratometry_values, reconstructed)
    
    return {
        'dc_component': dc_component,
        'components_used': components_used,
        'total_variance_explained': cumulative_variance,
        'r2_score': r2,
        **amplitudes,
        **phases
    }

def process_file(file_path):
    """Process a single file and return its Fourier analysis results."""
    try:
        df = pd.read_csv(file_path)
        meridian_means = df.groupby('Meridian_Index')['Axial_Anterior_Value'].mean()
        meridian_indices = np.array(sorted(meridian_means.index))
        keratometry_values = meridian_means[meridian_indices].values
        
        results = calculate_fourier_components(meridian_indices, keratometry_values)
        results['filename'] = file_path.name
        
        print(f"Processed {file_path.name}: R² = {results['r2_score']:.4f}, Components = {results['components_used']}")
        return results
    
    except Exception as e:
        print(f"Error processing {file_path.name}: {str(e)}")
        return None

def calculate_combined_model(results_df):
    """Calculate combined model using Mallows weights with amplitudes."""
    result_columns = [
        'dc_component', 
        'component_1_amplitude', 
        'component_2_amplitude',
        'component_1_phase',
        'component_2_phase',
        'higher_order_amplitude_sum'
    ]
    
    mse = 1 - results_df['r2_score'].values
    weights = 1 / (mse + 1e-10)
    weights /= weights.sum()
    
    combined_values = {col: np.average(results_df[col], weights=weights) 
                      for col in result_columns}
    
    return combined_values

def reconstruct_signal_from_model(model_params, meridian_indices):
    """Reconstruct signal using model parameters."""
    n_meridian = len(meridian_indices)
    reconstructed = np.full(n_meridian, model_params['dc_component'])
    
    for m in range(1, 3):  # Using components 1 and 2
        angle = 2 * np.pi * m * np.arange(n_meridian) / n_meridian
        cn = model_params[f'component_{m}_amplitude']
        phase = model_params[f'component_{m}_phase']
        reconstructed += cn * np.cos(angle - phase)
    
    return reconstructed

def evaluate_combined_model(combined_model, original_data_files):
    """Test combined model against each original case and calculate R² scores."""
    r2_scores = []
    detailed_results = []
    
    print("\nEvaluating Combined Model Performance:")
    print("-" * 40)
    
    for file_path in original_data_files:
        try:
            # Read original data
            df = pd.read_csv(file_path)
            meridian_means = df.groupby('Meridian_Index')['Axial_Anterior_Value'].mean()
            meridian_indices = np.array(sorted(meridian_means.index))
            original_values = meridian_means[meridian_indices].values
            
            # Reconstruct signal using combined model
            reconstructed = reconstruct_signal_from_model(combined_model, meridian_indices)
            
            # Calculate R² score
            r2 = r2_score(original_values, reconstructed)
            r2_scores.append(r2)
            
            # Store detailed results
            detailed_results.append({
                'filename': file_path.name,
                'r2_score': r2,
                'original_values': original_values.tolist(),
                'reconstructed_values': reconstructed.tolist()
            })
            
            print(f"File: {file_path.name:<30} R² = {r2:.4f}")
            
        except Exception as e:
            print(f"Error evaluating {file_path.name}: {str(e)}")
    
    mean_r2 = np.mean(r2_scores)
    std_r2 = np.std(r2_scores)
    
    print("\nCombined Model Performance Summary:")
    print(f"Average R² Score: {mean_r2:.4f} ± {std_r2:.4f}")
    print(f"Min R² Score: {min(r2_scores):.4f}")
    print(f"Max R² Score: {max(r2_scores):.4f}")
    
    # Save detailed results to a file
    detailed_df = pd.DataFrame(detailed_results)
    detailed_df.to_csv("combined_model_detailed_results.csv", index=False)
    
    return {
        'mean_r2': mean_r2,
        'std_r2': std_r2,
        'min_r2': min(r2_scores),
        'max_r2': max(r2_scores),
        'individual_scores': r2_scores,
        'detailed_results': detailed_results
    }

def main():
    print(f"Starting Fourier analysis using {MAX_WORKERS} processes...")
    
    try:
        # Process files in parallel
        csv_files = list(DATA_DIR.glob("*.csv"))
        with concurrent.futures.ProcessPoolExecutor(max_workers=MAX_WORKERS) as executor:
            results = list(filter(None, executor.map(process_file, csv_files)))
        
        # Create results DataFrame and calculate combined model
        results_df = pd.DataFrame(results)
        combined_model = calculate_combined_model(results_df)
        
        # Add combined model to results
        combined_row = {
            'filename': 'COMBINED_MODEL',
            'r2_score': np.nan,
            'components_used': np.nan,
            'total_variance_explained': np.nan,
            **combined_model
        }
        results_df = pd.concat([results_df, pd.DataFrame([combined_row])], ignore_index=True)
        
        # Save initial results
        results_df.to_csv(OUTPUT_FILE, index=False)
        print(f"\nResults saved to: {OUTPUT_FILE}")
        
        # Print initial analysis summary
        print(f"\nInitial Analysis Summary:")
        print(f"Files processed: {len(results_df) - 1}")
        print(f"Average R² Score: {results_df['r2_score'].iloc[:-1].mean():.4f}")
        print(f"Average Components Used: {results_df['components_used'].iloc[:-1].mean():.1f}")
        
        # Evaluate combined model
        combined_model_performance = evaluate_combined_model(combined_model, csv_files)
        
        # Save combined model performance metrics
        performance_df = pd.DataFrame({
            'metric': ['mean_r2', 'std_r2', 'min_r2', 'max_r2'],
            'value': [
                combined_model_performance['mean_r2'],
                combined_model_performance['std_r2'],
                combined_model_performance['min_r2'],
                combined_model_performance['max_r2']
            ]
        })
        performance_df.to_csv("combined_model_performance.csv", index=False)
        print(f"\nCombined model performance metrics saved to: combined_model_performance.csv")
        print(f"Detailed results saved to: combined_model_detailed_results.csv")
        
    except Exception as e:
        print(f"Error during analysis: {str(e)}")

if __name__ == "__main__":
    main()
# Out:
# Starting Fourier analysis using 15 processes...
# Processed Sheet312_combined.csv: R² = 0.9993, Components = 10Processed Sheet132_combined.csv: R² = 0.9906, Components = 10Processed Sheet423_combined.csv: R² = 0.9986, Components = 10Processed Sheet295_combined.csv: R² = 0.9943, Components = 10
#
# Processed Sheet125_combined.csv: R² = 0.9937, Components = 10
#
#
# Processed Sheet412_combined.csv: R² = 0.9989, Components = 10
# Processed Sheet431_combined.csv: R² = 0.9988, Components = 10Processed Sheet480_combined.csv: R² = 0.9965, Components = 10
# Processed Sheet466_combined.csv: R² = 0.9990, Components = 10
#
# Processed Sheet404_combined.csv: R² = 0.9984, Components = 10Processed Sheet262_combined.csv: R² = 0.9976, Components = 10Processed Sheet124_combined.csv: R² = 0.9809, Components = 10
#
#
# Processed Sheet373_combined.csv: R² = 0.9965, Components = 10Processed Sheet74_combined.csv: R² = 0.9946, Components = 10Processed Sheet201_combined.csv: R² = 0.9929, Components = 10
# Processed Sheet23_combined.csv: R² = 0.9945, Components = 10
#
#
# Processed Sheet321_combined.csv: R² = 0.9960, Components = 10Processed Sheet153_combined.csv: R² = 0.9970, Components = 10Processed Sheet460_combined.csv: R² = 0.9980, Components = 10
#
#
# Processed Sheet91_combined.csv: R² = 0.9885, Components = 10Processed Sheet148_combined.csv: R² = 0.9864, Components = 10
#
# Processed Sheet483_combined.csv: R² = 0.9954, Components = 10
# Processed Sheet304_combined.csv: R² = 0.9966, Components = 10
# Processed Sheet225_combined.csv: R² = 0.9534, Components = 10Processed Sheet209_combined.csv: R² = 0.9996, Components = 10
# Processed Sheet133_combined.csv: R² = 0.9974, Components = 10
# Processed Sheet160_combined.csv: R² = 0.9888, Components = 10
# Processed Sheet311_combined.csv: R² = 0.9884, Components = 10
# Processed Sheet349_combined.csv: R² = 0.9818, Components = 10
#
# Processed Sheet29_combined.csv: R² = 0.9956, Components = 10
# Processed Sheet84_combined.csv: R² = 0.9941, Components = 10
#
# Processed Sheet296_combined.csv: R² = 0.9957, Components = 10Processed Sheet95_combined.csv: R² = 0.9756, Components = 10
# Processed Sheet231_combined.csv: R² = 0.9964, Components = 10Processed Sheet419_combined.csv: R² = 0.9972, Components = 10Processed Sheet302_combined.csv: R² = 0.9847, Components = 10Processed Sheet434_combined.csv: R² = 0.9989, Components = 10
#
#
#
# Processed Sheet78_combined.csv: R² = 0.9925, Components = 10Processed Sheet227_combined.csv: R² = 0.9978, Components = 10Processed Sheet230_combined.csv: R² = 0.9937, Components = 10Processed Sheet2_combined.csv: R² = 0.9968, Components = 10
# Processed Sheet173_combined.csv: R² = 0.9966, Components = 10
#
#
#
# Processed Sheet397_combined.csv: R² = 0.9868, Components = 10Processed Sheet217_combined.csv: R² = 0.9956, Components = 10Processed Sheet129_combined.csv: R² = 0.9971, Components = 10
#
# Processed Sheet228_combined.csv: R² = 0.9977, Components = 10
# Processed Sheet421_combined.csv: R² = 0.9979, Components = 10
# Processed Sheet45_combined.csv: R² = 0.9963, Components = 10
#
# Processed Sheet291_combined.csv: R² = 0.9956, Components = 10Processed Sheet437_combined.csv: R² = 0.9995, Components = 10Processed Sheet367_combined.csv: R² = 0.9952, Components = 10
#
#
# Processed Sheet285_combined.csv: R² = 0.9958, Components = 10
# Processed Sheet41_combined.csv: R² = 0.9866, Components = 10
# Processed Sheet438_combined.csv: R² = 0.9951, Components = 10
# Processed Sheet449_combined.csv: R² = 0.9992, Components = 10Processed Sheet439_combined.csv: R² = 0.9977, Components = 10
#
# Processed Sheet446_combined.csv: R² = 0.9997, Components = 10Processed Sheet40_combined.csv: R² = 0.9885, Components = 10Processed Sheet118_combined.csv: R² = 0.9947, Components = 10
#
# Processed Sheet61_combined.csv: R² = 0.9484, Components = 10Processed Sheet320_combined.csv: R² = 0.9957, Components = 10Processed Sheet44_combined.csv: R² = 0.9947, Components = 10
#
# Processed Sheet465_combined.csv: R² = 0.9995, Components = 10
#
#
# Processed Sheet432_combined.csv: R² = 0.9985, Components = 10
# Processed Sheet301_combined.csv: R² = 0.9989, Components = 10
# Processed Sheet251_combined.csv: R² = 0.9970, Components = 10
# Processed Sheet253_combined.csv: R² = 0.9990, Components = 10Processed Sheet388_combined.csv: R² = 0.9760, Components = 10
#
# Processed Sheet453_combined.csv: R² = 0.9989, Components = 10Processed Sheet378_combined.csv: R² = 0.9838, Components = 10
# Processed Sheet110_combined.csv: R² = 0.9989, Components = 10
#
# Processed Sheet171_combined.csv: R² = 0.9944, Components = 10Processed Sheet339_combined.csv: R² = 0.9978, Components = 10Processed Sheet332_combined.csv: R² = 0.9756, Components = 10
#
#
# Processed Sheet236_combined.csv: R² = 0.9704, Components = 10
# Processed Sheet13_combined.csv: R² = 0.9946, Components = 10Processed Sheet116_combined.csv: R² = 0.9980, Components = 10
#
# Processed Sheet145_combined.csv: R² = 0.9816, Components = 10
# Processed Sheet425_combined.csv: R² = 0.9947, Components = 10
# Processed Sheet5_combined.csv: R² = 0.9960, Components = 10
# Processed Sheet342_combined.csv: R² = 0.9903, Components = 10
# Processed Sheet233_combined.csv: R² = 0.9956, Components = 10
# Processed Sheet119_combined.csv: R² = 0.9983, Components = 10Processed Sheet92_combined.csv: R² = 0.9977, Components = 10
#
# Processed Sheet333_combined.csv: R² = 0.9872, Components = 10Processed Sheet131_combined.csv: R² = 0.9961, Components = 10Processed Sheet360_combined.csv: R² = 0.9965, Components = 10
#
# Processed Sheet181_combined.csv: R² = 0.9987, Components = 10
# Processed Sheet130_combined.csv: R² = 0.9933, Components = 10
# Processed Sheet347_combined.csv: R² = 0.9915, Components = 10
# Processed Sheet126_combined.csv: R² = 0.9924, Components = 10Processed Sheet210_combined.csv: R² = 0.9967, Components = 10
#
#
# Processed Sheet175_combined.csv: R² = 0.9968, Components = 10
# Processed Sheet353_combined.csv: R² = 0.9957, Components = 10Processed Sheet135_combined.csv: R² = 0.9973, Components = 10
#
# Processed Sheet65_combined.csv: R² = 0.9905, Components = 10Processed Sheet472_combined.csv: R² = 0.9944, Components = 10
#
# Processed Sheet268_combined.csv: R² = 0.9993, Components = 10
# Processed Sheet459_combined.csv: R² = 0.9982, Components = 10Processed Sheet334_combined.csv: R² = 0.8879, Components = 10Processed Sheet234_combined.csv: R² = 0.9964, Components = 10
#
#
# Processed Sheet485_combined.csv: R² = 0.9990, Components = 10Processed Sheet330_combined.csv: R² = 0.9934, Components = 10Processed Sheet177_combined.csv: R² = 0.9951, Components = 10
#
# Processed Sheet15_combined.csv: R² = 0.9947, Components = 10
#
# Processed Sheet208_combined.csv: R² = 0.9997, Components = 10
# Processed Sheet436_combined.csv: R² = 0.9984, Components = 10
# Processed Sheet391_combined.csv: R² = 0.9980, Components = 10
# Processed Sheet139_combined.csv: R² = 0.9969, Components = 10
# Processed Sheet344_combined.csv: R² = 0.9996, Components = 10
# Processed Sheet72_combined.csv: R² = 0.9990, Components = 10
# Processed Sheet244_combined.csv: R² = 0.9767, Components = 10
# Processed Sheet37_combined.csv: R² = 0.9937, Components = 10Processed Sheet469_combined.csv: R² = 0.9950, Components = 10Processed Sheet394_combined.csv: R² = 0.9969, Components = 10
# Processed Sheet407_combined.csv: R² = 0.9413, Components = 10
# Processed Sheet478_combined.csv: R² = 0.9985, Components = 10
# Processed Sheet357_combined.csv: R² = 0.9905, Components = 10
#
# Processed Sheet164_combined.csv: R² = 0.9900, Components = 10
# Processed Sheet413_combined.csv: R² = 0.9984, Components = 10
# Processed Sheet48_combined.csv: R² = 0.9821, Components = 10
#
# Processed Sheet369_combined.csv: R² = 0.9925, Components = 10
# Processed Sheet50_combined.csv: R² = 0.9805, Components = 10
# Processed Sheet105_combined.csv: R² = 0.9968, Components = 10Processed Sheet470_combined.csv: R² = 0.9988, Components = 10
#
# Processed Sheet224_combined.csv: R² = 0.9906, Components = 10
# Processed Sheet415_combined.csv: R² = 0.9999, Components = 10Processed Sheet451_combined.csv: R² = 0.9962, Components = 10
#
# Processed Sheet219_combined.csv: R² = 0.9917, Components = 10Processed Sheet338_combined.csv: R² = 0.9943, Components = 10Processed Sheet161_combined.csv: R² = 0.9951, Components = 10
#
#
# Processed Sheet36_combined.csv: R² = 0.9934, Components = 10Processed Sheet477_combined.csv: R² = 0.9784, Components = 10
#
# Processed Sheet294_combined.csv: R² = 0.9972, Components = 10
# Processed Sheet156_combined.csv: R² = 0.9885, Components = 10
# Processed Sheet286_combined.csv: R² = 0.9816, Components = 10Processed Sheet39_combined.csv: R² = 0.9818, Components = 10
# Processed Sheet142_combined.csv: R² = 0.9982, Components = 10
#
# Processed Sheet267_combined.csv: R² = 0.9808, Components = 10Processed Sheet214_combined.csv: R² = 0.9920, Components = 10
# Processed Sheet479_combined.csv: R² = 0.9982, Components = 10
# Processed Sheet355_combined.csv: R² = 0.9969, Components = 10
# Processed Sheet16_combined.csv: R² = 0.9963, Components = 10Processed Sheet243_combined.csv: R² = 0.9968, Components = 10
# Processed Sheet303_combined.csv: R² = 0.9921, Components = 10
#
# Processed Sheet55_combined.csv: R² = 0.9963, Components = 10
#
# Processed Sheet35_combined.csv: R² = 0.9867, Components = 10
# Processed Sheet73_combined.csv: R² = 0.9990, Components = 10
# Processed Sheet315_combined.csv: R² = 0.9978, Components = 10Processed Sheet191_combined.csv: R² = 0.9988, Components = 10
#
# Processed Sheet63_combined.csv: R² = 0.9932, Components = 10Processed Sheet75_combined.csv: R² = 0.9985, Components = 10
#
# Processed Sheet190_combined.csv: R² = 0.9992, Components = 10
# Processed Sheet213_combined.csv: R² = 0.9961, Components = 10Processed Sheet255_combined.csv: R² = 0.9861, Components = 10
#
# Processed Sheet348_combined.csv: R² = 0.9342, Components = 10
# Processed Sheet28_combined.csv: R² = 0.9919, Components = 10Processed Sheet374_combined.csv: R² = 0.9664, Components = 10
#
# Processed Sheet106_combined.csv: R² = 0.9993, Components = 10
# Processed Sheet350_combined.csv: R² = 0.9964, Components = 10
# Processed Sheet399_combined.csv: R² = 0.9523, Components = 10Processed Sheet467_combined.csv: R² = 0.9979, Components = 10Processed Sheet211_combined.csv: R² = 0.9929, Components = 10
#
#
# Processed Sheet109_combined.csv: R² = 0.9992, Components = 10Processed Sheet239_combined.csv: R² = 0.9907, Components = 10
#
# Processed Sheet283_combined.csv: R² = 0.9960, Components = 10Processed Sheet420_combined.csv: R² = 0.9990, Components = 10Processed Sheet123_combined.csv: R² = 0.9956, Components = 10
#
# Processed Sheet261_combined.csv: R² = 0.9935, Components = 10
#
# Processed Sheet386_combined.csv: R² = 0.9934, Components = 10Processed Sheet263_combined.csv: R² = 0.9878, Components = 10
# Processed Sheet272_combined.csv: R² = 0.9961, Components = 10
# Processed Sheet450_combined.csv: R² = 0.9951, Components = 10
#
# Processed Sheet266_combined.csv: R² = 0.9903, Components = 10Processed Sheet42_combined.csv: R² = 0.9860, Components = 10Processed Sheet337_combined.csv: R² = 0.9994, Components = 10Processed Sheet166_combined.csv: R² = 0.9960, Components = 10
#
#
# Processed Sheet194_combined.csv: R² = 0.9979, Components = 10
#
#
# Processed Sheet127_combined.csv: R² = 0.9962, Components = 10Processed Sheet90_combined.csv: R² = 0.9877, Components = 10
# Processed Sheet3_combined.csv: R² = 0.9964, Components = 10
# Processed Sheet98_combined.csv: R² = 0.9986, Components = 10
# Processed Sheet363_combined.csv: R² = 0.9974, Components = 10Processed Sheet383_combined.csv: R² = 0.9948, Components = 10
#
# Processed Sheet426_combined.csv: R² = 0.9959, Components = 10
# Processed Sheet345_combined.csv: R² = 0.9996, Components = 10
# Processed Sheet140_combined.csv: R² = 0.9971, Components = 10Processed Sheet85_combined.csv: R² = 0.9964, Components = 10
#
# Processed Sheet365_combined.csv: R² = 0.9725, Components = 10Processed Sheet277_combined.csv: R² = 0.9839, Components = 10Processed Sheet122_combined.csv: R² = 0.9944, Components = 10
#
#
# Processed Sheet33_combined.csv: R² = 0.9983, Components = 10
# Processed Sheet396_combined.csv: R² = 0.9822, Components = 10Processed Sheet196_combined.csv: R² = 0.9978, Components = 10
#
# Processed Sheet368_combined.csv: R² = 0.9867, Components = 10Processed Sheet319_combined.csv: R² = 0.9987, Components = 10
#
# Processed Sheet387_combined.csv: R² = 0.9939, Components = 10Processed Sheet162_combined.csv: R² = 0.9976, Components = 10
#
# Processed Sheet245_combined.csv: R² = 0.9971, Components = 10
# Processed Sheet114_combined.csv: R² = 0.9629, Components = 10
# Processed Sheet121_combined.csv: R² = 0.9960, Components = 10
# Processed Sheet17_combined.csv: R² = 0.9986, Components = 10
# Processed Sheet307_combined.csv: R² = 0.9964, Components = 10Processed Sheet100_combined.csv: R² = 0.9992, Components = 10Processed Sheet463_combined.csv: R² = 0.9977, Components = 10
# Processed Sheet150_combined.csv: R² = 0.9778, Components = 10
#
# Processed Sheet464_combined.csv: R² = 0.9971, Components = 10
#
# Processed Sheet168_combined.csv: R² = 0.9293, Components = 10
# Processed Sheet222_combined.csv: R² = 0.9805, Components = 10Processed Sheet275_combined.csv: R² = 0.9963, Components = 10Processed Sheet461_combined.csv: R² = 0.9979, Components = 10
#
# Processed Sheet326_combined.csv: R² = 0.9952, Components = 10
# Processed Sheet11_combined.csv: R² = 0.9998, Components = 10Processed Sheet408_combined.csv: R² = 0.9682, Components = 10
#
# Processed Sheet71_combined.csv: R² = 0.9964, Components = 10
#
# Processed Sheet206_combined.csv: R² = 0.9993, Components = 10
# Processed Sheet113_combined.csv: R² = 0.9898, Components = 10
# Processed Sheet154_combined.csv: R² = 0.9929, Components = 10Processed Sheet482_combined.csv: R² = 0.9978, Components = 10Processed Sheet99_combined.csv: R² = 0.9900, Components = 10
#
#
# Processed Sheet247_combined.csv: R² = 0.9960, Components = 10Processed Sheet455_combined.csv: R² = 0.9984, Components = 10
#
# Processed Sheet187_combined.csv: R² = 0.9970, Components = 10Processed Sheet305_combined.csv: R² = 0.9994, Components = 10
# Processed Sheet351_combined.csv: R² = 0.9997, Components = 10
# Processed Sheet220_combined.csv: R² = 0.9980, Components = 10
# Processed Sheet401_combined.csv: R² = 0.9946, Components = 10Processed Sheet185_combined.csv: R² = 0.9940, Components = 10
#
#
# Processed Sheet136_combined.csv: R² = 0.9911, Components = 10
# Processed Sheet87_combined.csv: R² = 0.9982, Components = 10
# Processed Sheet27_combined.csv: R² = 0.9994, Components = 10Processed Sheet193_combined.csv: R² = 0.9894, Components = 10Processed Sheet377_combined.csv: R² = 0.9739, Components = 10
#
# Processed Sheet241_combined.csv: R² = 0.9953, Components = 10
#
# Processed Sheet448_combined.csv: R² = 0.9979, Components = 10Processed Sheet250_combined.csv: R² = 0.9990, Components = 10
# Processed Sheet258_combined.csv: R² = 0.9991, Components = 10
# Processed Sheet14_combined.csv: R² = 0.9990, Components = 10
#
# Processed Sheet149_combined.csv: R² = 0.9979, Components = 10
# Processed Sheet428_combined.csv: R² = 0.9966, Components = 10Processed Sheet32_combined.csv: R² = 0.9918, Components = 10Processed Sheet288_combined.csv: R² = 0.9888, Components = 10Processed Sheet309_combined.csv: R² = 0.9926, Components = 10
#
#
#
# Processed Sheet93_combined.csv: R² = 0.9984, Components = 10Processed Sheet192_combined.csv: R² = 0.9906, Components = 10Processed Sheet199_combined.csv: R² = 0.9982, Components = 10
#
# Processed Sheet143_combined.csv: R² = 0.9990, Components = 10Processed Sheet51_combined.csv: R² = 0.9932, Components = 10Processed Sheet380_combined.csv: R² = 0.9950, Components = 10
#
#
#
# Processed Sheet115_combined.csv: R² = 0.9904, Components = 10
# Processed Sheet155_combined.csv: R² = 0.9961, Components = 10
# Processed Sheet179_combined.csv: R² = 0.9996, Components = 10
# Processed Sheet457_combined.csv: R² = 0.9975, Components = 10Processed Sheet165_combined.csv: R² = 0.9905, Components = 10
#
# Processed Sheet79_combined.csv: R² = 0.9989, Components = 10
# Processed Sheet329_combined.csv: R² = 0.9706, Components = 10
# Processed Sheet331_combined.csv: R² = 0.9971, Components = 10Processed Sheet473_combined.csv: R² = 0.9954, Components = 10Processed Sheet159_combined.csv: R² = 0.9942, Components = 10Processed Sheet484_combined.csv: R² = 0.9942, Components = 10
#
#
# Processed Sheet409_combined.csv: R² = 0.9969, Components = 10Processed Sheet46_combined.csv: R² = 0.9965, Components = 10
#
#
# Processed Sheet359_combined.csv: R² = 0.9948, Components = 10Processed Sheet371_combined.csv: R² = 0.9545, Components = 10Processed Sheet441_combined.csv: R² = 0.9968, Components = 10
#
#
# Processed Sheet144_combined.csv: R² = 0.9566, Components = 10Processed Sheet456_combined.csv: R² = 0.9950, Components = 10Processed Sheet249_combined.csv: R² = 0.9960, Components = 10
# Processed Sheet64_combined.csv: R² = 0.9959, Components = 10Processed Sheet218_combined.csv: R² = 0.9972, Components = 10
#
#
# Processed Sheet358_combined.csv: R² = 0.9948, Components = 10
#
# Processed Sheet376_combined.csv: R² = 0.9967, Components = 10Processed Sheet197_combined.csv: R² = 0.9523, Components = 10
#
# Processed Sheet94_combined.csv: R² = 0.9948, Components = 10
# Processed Sheet151_combined.csv: R² = 0.9186, Components = 10
# Processed Sheet366_combined.csv: R² = 0.9913, Components = 10Processed Sheet364_combined.csv: R² = 0.9790, Components = 10
#
# Processed Sheet429_combined.csv: R² = 0.9975, Components = 10Processed Sheet443_combined.csv: R² = 0.9989, Components = 10
# Processed Sheet141_combined.csv: R² = 0.9915, Components = 10
#
# Processed Sheet49_combined.csv: R² = 0.9484, Components = 10Processed Sheet146_combined.csv: R² = 0.9477, Components = 10
#
# Processed Sheet276_combined.csv: R² = 0.9704, Components = 10
# Processed Sheet289_combined.csv: R² = 0.9951, Components = 10Processed Sheet299_combined.csv: R² = 0.9963, Components = 10
# Processed Sheet384_combined.csv: R² = 0.9980, Components = 10Processed Sheet435_combined.csv: R² = 0.9975, Components = 10Processed Sheet427_combined.csv: R² = 0.9905, Components = 10
#
# Processed Sheet21_combined.csv: R² = 0.9994, Components = 10
#
# Processed Sheet184_combined.csv: R² = 0.9923, Components = 10Processed Sheet317_combined.csv: R² = 0.9944, Components = 10Processed Sheet252_combined.csv: R² = 0.9939, Components = 10
#
#
#
# Processed Sheet475_combined.csv: R² = 0.9926, Components = 10
# Processed Sheet382_combined.csv: R² = 0.9994, Components = 10Processed Sheet284_combined.csv: R² = 0.9986, Components = 10
#
# Processed Sheet265_combined.csv: R² = 0.9977, Components = 10Processed Sheet7_combined.csv: R² = 0.9988, Components = 10
#
# Processed Sheet418_combined.csv: R² = 0.9885, Components = 10Processed Sheet352_combined.csv: R² = 0.9933, Components = 10
#
# Processed Sheet88_combined.csv: R² = 0.9956, Components = 10Processed Sheet298_combined.csv: R² = 0.9849, Components = 10
# Processed Sheet379_combined.csv: R² = 0.9927, Components = 10
# Processed Sheet57_combined.csv: R² = 0.9963, Components = 10
# Processed Sheet215_combined.csv: R² = 0.9984, Components = 10
# Processed Sheet256_combined.csv: R² = 0.9996, Components = 10
# Processed Sheet81_combined.csv: R² = 0.9986, Components = 10
# Processed Sheet204_combined.csv: R² = 0.9962, Components = 10
#
# Processed Sheet216_combined.csv: R² = 0.9919, Components = 10Processed Sheet400_combined.csv: R² = 0.9901, Components = 10Processed Sheet137_combined.csv: R² = 0.9986, Components = 10
#
# Processed Sheet26_combined.csv: R² = 0.9981, Components = 10Processed Sheet405_combined.csv: R² = 0.9998, Components = 10
#
# Processed Sheet19_combined.csv: R² = 0.9967, Components = 10
#
# Processed Sheet481_combined.csv: R² = 0.9995, Components = 10
# Processed Sheet25_combined.csv: R² = 0.9952, Components = 10
# Processed Sheet221_combined.csv: R² = 0.9969, Components = 10
# Processed Sheet176_combined.csv: R² = 0.9973, Components = 10Processed Sheet104_combined.csv: R² = 0.9716, Components = 10
#
# Processed Sheet189_combined.csv: R² = 0.9985, Components = 10Processed Sheet264_combined.csv: R² = 0.9940, Components = 10
#
# Processed Sheet257_combined.csv: R² = 0.9987, Components = 10Processed Sheet54_combined.csv: R² = 0.9969, Components = 10
# Processed Sheet128_combined.csv: R² = 0.9963, Components = 10
#
# Processed Sheet117_combined.csv: R² = 0.9974, Components = 10Processed Sheet96_combined.csv: R² = 0.9986, Components = 10
#
# Processed Sheet424_combined.csv: R² = 0.9952, Components = 10Processed Sheet157_combined.csv: R² = 0.9945, Components = 10Processed Sheet20_combined.csv: R² = 0.9988, Components = 10
#
#
# Processed Sheet38_combined.csv: R² = 0.9773, Components = 10Processed Sheet476_combined.csv: R² = 0.9943, Components = 10Processed Sheet393_combined.csv: R² = 0.9987, Components = 10Processed Sheet68_combined.csv: R² = 0.9985, Components = 10
#
# Processed Sheet183_combined.csv: R² = 0.9987, Components = 10
#
#
# Processed Sheet458_combined.csv: R² = 0.9869, Components = 10
# Processed Sheet235_combined.csv: R² = 0.9977, Components = 10Processed Sheet395_combined.csv: R² = 0.9981, Components = 10Processed Sheet212_combined.csv: R² = 0.9933, Components = 10
# Processed Sheet280_combined.csv: R² = 0.9990, Components = 10
#
#
# Processed Sheet82_combined.csv: R² = 0.9949, Components = 10Processed Sheet422_combined.csv: R² = 0.9984, Components = 10
#
# Processed Sheet471_combined.csv: R² = 0.9973, Components = 10Processed Sheet170_combined.csv: R² = 0.9950, Components = 10Processed Sheet274_combined.csv: R² = 0.9990, Components = 10
#
#
# Processed Sheet226_combined.csv: R² = 0.9974, Components = 10Processed Sheet248_combined.csv: R² = 0.9975, Components = 10
#
# Processed Sheet278_combined.csv: R² = 0.9745, Components = 10
# Processed Sheet102_combined.csv: R² = 0.9998, Components = 10
# Processed Sheet8_combined.csv: R² = 0.9974, Components = 10
# Processed Sheet138_combined.csv: R² = 0.9950, Components = 10Processed Sheet77_combined.csv: R² = 0.9976, Components = 10Processed Sheet31_combined.csv: R² = 0.9907, Components = 10Processed Sheet238_combined.csv: R² = 0.9746, Components = 10
#
#
#
# Processed Sheet198_combined.csv: R² = 0.9977, Components = 10Processed Sheet163_combined.csv: R² = 0.9993, Components = 10Processed Sheet462_combined.csv: R² = 0.9986, Components = 10
#
#
# Processed Sheet202_combined.csv: R² = 0.9980, Components = 10Processed Sheet370_combined.csv: R² = 0.9882, Components = 10
# Processed Sheet70_combined.csv: R² = 0.9968, Components = 10
# Processed Sheet86_combined.csv: R² = 0.9974, Components = 10
#
# Processed Sheet308_combined.csv: R² = 0.9760, Components = 10Processed Sheet4_combined.csv: R² = 0.9967, Components = 10
# Processed Sheet410_combined.csv: R² = 0.9991, Components = 10
#
# Processed Sheet327_combined.csv: R² = 0.9915, Components = 10
# Processed Sheet282_combined.csv: R² = 0.9907, Components = 10Processed Sheet273_combined.csv: R² = 0.9931, Components = 10
# Processed Sheet340_combined.csv: R² = 0.9986, Components = 10
# Processed Sheet324_combined.csv: R² = 0.9968, Components = 10
#
# Processed Sheet254_combined.csv: R² = 0.9865, Components = 10Processed Sheet287_combined.csv: R² = 0.9984, Components = 10
# Processed Sheet200_combined.csv: R² = 0.9919, Components = 10
# Processed Sheet293_combined.csv: R² = 0.9958, Components = 10Processed Sheet180_combined.csv: R² = 0.9982, Components = 10
#
#
# Processed Sheet147_combined.csv: R² = 0.9690, Components = 10Processed Sheet108_combined.csv: R² = 0.9961, Components = 10
#
# Processed Sheet9_combined.csv: R² = 0.9982, Components = 10Processed Sheet107_combined.csv: R² = 0.9989, Components = 10
# Processed Sheet52_combined.csv: R² = 0.9959, Components = 10
#
# Processed Sheet325_combined.csv: R² = 0.9857, Components = 10
# Processed Sheet12_combined.csv: R² = 0.9953, Components = 10Processed Sheet356_combined.csv: R² = 0.9997, Components = 10Processed Sheet398_combined.csv: R² = 0.9978, Components = 10
#
#
# Processed Sheet316_combined.csv: R² = 0.9944, Components = 10Processed Sheet60_combined.csv: R² = 0.9821, Components = 10
# Processed Sheet111_combined.csv: R² = 0.9994, Components = 10
#
# Processed Sheet406_combined.csv: R² = 0.9985, Components = 10
# Processed Sheet18_combined.csv: R² = 0.9942, Components = 10
# Processed Sheet186_combined.csv: R² = 0.9958, Components = 10Processed Sheet385_combined.csv: R² = 0.9976, Components = 10
# Processed Sheet103_combined.csv: R² = 0.9991, Components = 10
# Processed Sheet474_combined.csv: R² = 0.9979, Components = 10
#
# Processed Sheet246_combined.csv: R² = 0.9967, Components = 10
# Processed Sheet172_combined.csv: R² = 0.9759, Components = 10
# Processed Sheet30_combined.csv: R² = 0.9975, Components = 10Processed Sheet323_combined.csv: R² = 0.9987, Components = 10
#
# Processed Sheet174_combined.csv: R² = 0.9980, Components = 10Processed Sheet468_combined.csv: R² = 0.9899, Components = 10
#
# Processed Sheet322_combined.csv: R² = 0.9987, Components = 10
# Processed Sheet354_combined.csv: R² = 0.9995, Components = 10Processed Sheet452_combined.csv: R² = 0.9984, Components = 10Processed Sheet178_combined.csv: R² = 0.9988, Components = 10Processed Sheet67_combined.csv: R² = 0.9963, Components = 10
#
# Processed Sheet375_combined.csv: R² = 0.9900, Components = 10Processed Sheet89_combined.csv: R² = 0.9961, Components = 10
#
#
# Processed Sheet223_combined.csv: R² = 0.9948, Components = 10Processed Sheet134_combined.csv: R² = 0.9910, Components = 10
#
#
# Processed Sheet59_combined.csv: R² = 0.9938, Components = 10
# Processed Sheet300_combined.csv: R² = 0.8879, Components = 10Processed Sheet290_combined.csv: R² = 0.9991, Components = 10Processed Sheet120_combined.csv: R² = 0.9967, Components = 10
# Processed Sheet372_combined.csv: R² = 0.9984, Components = 10
#
# Processed Sheet389_combined.csv: R² = 0.9777, Components = 10
#
# Processed Sheet433_combined.csv: R² = 0.9993, Components = 10Processed Sheet101_combined.csv: R² = 0.9951, Components = 10Processed Sheet112_combined.csv: R² = 0.9873, Components = 10
#
#
# Processed Sheet152_combined.csv: R² = 0.9989, Components = 10
# Processed Sheet22_combined.csv: R² = 0.9582, Components = 10Processed Sheet195_combined.csv: R² = 0.9991, Components = 10
#
# Processed Sheet281_combined.csv: R² = 0.9983, Components = 10
# Processed Sheet335_combined.csv: R² = 0.9989, Components = 10
# Processed Sheet411_combined.csv: R² = 0.9976, Components = 10
# Processed Sheet416_combined.csv: R² = 0.9987, Components = 10
# Processed Sheet80_combined.csv: R² = 0.9989, Components = 10Processed Sheet314_combined.csv: R² = 0.9967, Components = 10
# Processed Sheet430_combined.csv: R² = 0.9991, Components = 10Processed Sheet292_combined.csv: R² = 0.9976, Components = 10Processed Sheet381_combined.csv: R² = 0.9975, Components = 10Processed Sheet53_combined.csv: R² = 0.9905, Components = 10
#
# Processed Sheet318_combined.csv: R² = 0.9974, Components = 10
#
# Processed Sheet341_combined.csv: R² = 0.9993, Components = 10
#
# Processed Sheet237_combined.csv: R² = 0.9884, Components = 10
#
# Processed Sheet169_combined.csv: R² = 0.9826, Components = 10Processed Sheet240_combined.csv: R² = 0.9961, Components = 10
# Processed Sheet270_combined.csv: R² = 0.9987, Components = 10
# Processed Sheet417_combined.csv: R² = 0.9994, Components = 10
# Processed Sheet297_combined.csv: R² = 0.9991, Components = 10
#
# Processed Sheet440_combined.csv: R² = 0.9957, Components = 10
# Processed Sheet313_combined.csv: R² = 0.9949, Components = 10
# Processed Sheet328_combined.csv: R² = 0.9974, Components = 10Processed Sheet76_combined.csv: R² = 0.9974, Components = 10Processed Sheet260_combined.csv: R² = 0.9980, Components = 10
#
# Processed Sheet10_combined.csv: R² = 0.9981, Components = 10Processed Sheet205_combined.csv: R² = 0.9988, Components = 10Processed Sheet6_combined.csv: R² = 0.9938, Components = 10Processed Sheet271_combined.csv: R² = 0.9969, Components = 10
#
#
#
# Processed Sheet207_combined.csv: R² = 0.9979, Components = 10Processed Sheet83_combined.csv: R² = 0.9963, Components = 10
#
#
# Processed Sheet362_combined.csv: R² = 0.9945, Components = 10Processed Sheet97_combined.csv: R² = 0.9993, Components = 10Processed Sheet43_combined.csv: R² = 0.9974, Components = 10Processed Sheet242_combined.csv: R² = 0.9983, Components = 10
# Processed Sheet229_combined.csv: R² = 0.9905, Components = 10
#
#
# Processed Sheet24_combined.csv: R² = 0.9975, Components = 10
#
# Processed Sheet444_combined.csv: R² = 0.9947, Components = 10
# Processed Sheet402_combined.csv: R² = 0.9916, Components = 10Processed Sheet390_combined.csv: R² = 0.9979, Components = 10
# Processed Sheet167_combined.csv: R² = 0.9372, Components = 10Processed Sheet182_combined.csv: R² = 0.9989, Components = 10
#
# Processed Sheet203_combined.csv: R² = 0.9995, Components = 10Processed Sheet188_combined.csv: R² = 0.9987, Components = 10
#
#
# Processed Sheet47_combined.csv: R² = 0.9938, Components = 10
# Processed Sheet447_combined.csv: R² = 0.9974, Components = 10
# Processed Sheet279_combined.csv: R² = 0.9915, Components = 10Processed Sheet62_combined.csv: R² = 0.9805, Components = 10Processed Sheet56_combined.csv: R² = 0.9947, Components = 10Processed Sheet69_combined.csv: R² = 0.9987, Components = 10
#
#
# Processed Sheet58_combined.csv: R² = 0.9965, Components = 10Processed Sheet310_combined.csv: R² = 0.9992, Components = 10
# Processed Sheet158_combined.csv: R² = 0.9982, Components = 10
#
#
# Processed Sheet403_combined.csv: R² = 0.9907, Components = 10Processed Sheet414_combined.csv: R² = 0.9990, Components = 10Processed Sheet361_combined.csv: R² = 0.9975, Components = 10
#
# Processed Sheet454_combined.csv: R² = 0.9963, Components = 10Processed Sheet336_combined.csv: R² = 0.9975, Components = 10
#
#
# Processed Sheet259_combined.csv: R² = 0.9987, Components = 10
# Processed Sheet442_combined.csv: R² = 0.9957, Components = 10
# Processed Sheet392_combined.csv: R² = 0.9985, Components = 10
# Processed Sheet343_combined.csv: R² = 0.9913, Components = 10Processed Sheet269_combined.csv: R² = 0.9994, Components = 10Processed Sheet66_combined.csv: R² = 0.9969, Components = 10
#
#
# Processed Sheet346_combined.csv: R² = 0.9941, Components = 10Processed Sheet306_combined.csv: R² = 0.9971, Components = 10
#
# Processed Sheet445_combined.csv: R² = 0.9992, Components = 10Processed Sheet34_combined.csv: R² = 0.9940, Components = 10
#
# Processed Sheet232_combined.csv: R² = 0.9234, Components = 10
#
# Results saved to: fourier_analysis_results.csv
#
# Initial Analysis Summary:
# Files processed: 484
# Average R² Score: 0.9923
# Average Components Used: 10.0
#
# Evaluating Combined Model Performance:
# ----------------------------------------
# File: Sheet201_combined.csv          R² = -6.1896
# File: Sheet124_combined.csv          R² = -2.2628
# File: Sheet480_combined.csv          R² = -2.5614
# File: Sheet404_combined.csv          R² = -0.6009
# File: Sheet262_combined.csv          R² = -2.2072
# File: Sheet295_combined.csv          R² = -2.8201
# File: Sheet74_combined.csv           R² = -3.4434
# File: Sheet423_combined.csv          R² = -0.7925
# File: Sheet312_combined.csv          R² = -6.4197
# File: Sheet125_combined.csv          R² = 0.3798
# File: Sheet412_combined.csv          R² = -2.5106
# File: Sheet132_combined.csv          R² = -1.9373
# File: Sheet431_combined.csv          R² = -0.6409
# File: Sheet466_combined.csv          R² = -2.4729
# File: Sheet373_combined.csv          R² = -4.1038
# File: Sheet91_combined.csv           R² = -0.0242
# File: Sheet460_combined.csv          R² = -1.7014
# File: Sheet23_combined.csv           R² = -5.3674
# File: Sheet321_combined.csv          R² = -0.4714
# File: Sheet153_combined.csv          R² = -0.1894
# File: Sheet209_combined.csv          R² = -3.5236
# File: Sheet304_combined.csv          R² = -6.9999
# File: Sheet148_combined.csv          R² = -4.1720
# File: Sheet225_combined.csv          R² = -6.1939
# File: Sheet160_combined.csv          R² = -1.1683
# File: Sheet133_combined.csv          R² = -0.5271
# File: Sheet311_combined.csv          R² = -0.7216
# File: Sheet483_combined.csv          R² = -0.1204
# File: Sheet349_combined.csv          R² = -4.9217
# File: Sheet95_combined.csv           R² = -12.5022
# File: Sheet29_combined.csv           R² = -0.9096
# File: Sheet296_combined.csv          R² = -3.6030
# File: Sheet84_combined.csv           R² = -3.3875
# File: Sheet231_combined.csv          R² = -2.4922
# File: Sheet302_combined.csv          R² = -4.0877
# File: Sheet397_combined.csv          R² = -0.3391
# File: Sheet419_combined.csv          R² = -0.7496
# File: Sheet434_combined.csv          R² = -2.3619
# File: Sheet78_combined.csv           R² = -6.7342
# File: Sheet227_combined.csv          R² = -0.3541
# File: Sheet173_combined.csv          R² = -4.4634
# File: Sheet2_combined.csv            R² = -10.0072
# File: Sheet230_combined.csv          R² = -9.2166
# File: Sheet45_combined.csv           R² = -0.0915
# File: Sheet217_combined.csv          R² = -0.9096
# File: Sheet129_combined.csv          R² = -3.0309
# File: Sheet228_combined.csv          R² = -3.7523
# File: Sheet421_combined.csv          R² = -0.4007
# File: Sheet285_combined.csv          R² = -0.8011
# File: Sheet367_combined.csv          R² = -0.2792
# File: Sheet437_combined.csv          R² = 0.1215
# File: Sheet291_combined.csv          R² = -0.7622
# File: Sheet438_combined.csv          R² = -1.8584
# File: Sheet449_combined.csv          R² = -0.8947
# File: Sheet41_combined.csv           R² = -1.1623
# File: Sheet446_combined.csv          R² = -2.6629
# File: Sheet439_combined.csv          R² = -1.4777
# File: Sheet40_combined.csv           R² = -3.9221
# File: Sheet118_combined.csv          R² = -3.3590
# File: Sheet301_combined.csv          R² = -0.0653
# File: Sheet44_combined.csv           R² = -2.3019
# File: Sheet320_combined.csv          R² = -3.1666
# File: Sheet61_combined.csv           R² = -0.9363
# File: Sheet251_combined.csv          R² = 0.1485
# File: Sheet465_combined.csv          R² = 0.1736
# File: Sheet432_combined.csv          R² = -1.4466
# File: Sheet110_combined.csv          R² = -1.7991
# File: Sheet453_combined.csv          R² = -0.8511
# File: Sheet388_combined.csv          R² = -1.7626
# File: Sheet378_combined.csv          R² = -1.1728
# File: Sheet253_combined.csv          R² = -1.0460
# File: Sheet332_combined.csv          R² = -1.3263
# File: Sheet5_combined.csv            R² = -6.4675
# File: Sheet171_combined.csv          R² = -0.2500
# File: Sheet425_combined.csv          R² = -0.6395
# File: Sheet236_combined.csv          R² = -2.7597
# File: Sheet339_combined.csv          R² = -0.2534
# File: Sheet116_combined.csv          R² = -6.5630
# File: Sheet13_combined.csv           R² = -2.5816
# File: Sheet145_combined.csv          R² = -0.6826
# File: Sheet360_combined.csv          R² = -5.3770
# File: Sheet342_combined.csv          R² = -2.6509
# File: Sheet233_combined.csv          R² = -1.9550
# File: Sheet119_combined.csv          R² = 0.0542
# File: Sheet333_combined.csv          R² = -0.2859
# File: Sheet92_combined.csv           R² = -7.3737
# File: Sheet131_combined.csv          R² = -0.2351
# File: Sheet181_combined.csv          R² = -0.6191
# File: Sheet130_combined.csv          R² = -3.6774
# File: Sheet210_combined.csv          R² = -5.1406
# File: Sheet347_combined.csv          R² = -6.5229
# File: Sheet126_combined.csv          R² = -12.9858
# File: Sheet175_combined.csv          R² = -1.0076
# File: Sheet135_combined.csv          R² = 0.4890
# File: Sheet65_combined.csv           R² = -4.8836
# File: Sheet353_combined.csv          R² = -2.9219
# File: Sheet472_combined.csv          R² = -3.1854
# File: Sheet234_combined.csv          R² = -4.2576
# File: Sheet334_combined.csv          R² = -3.6352
# File: Sheet268_combined.csv          R² = -2.5512
# File: Sheet459_combined.csv          R² = -2.4538
# File: Sheet330_combined.csv          R² = -2.0193
# File: Sheet177_combined.csv          R² = -1.4680
# File: Sheet485_combined.csv          R² = -0.6383
# File: Sheet436_combined.csv          R² = -3.1701
# File: Sheet208_combined.csv          R² = -7.4232
# File: Sheet15_combined.csv           R² = -8.6415
# File: Sheet391_combined.csv          R² = -2.5851
# File: Sheet139_combined.csv          R² = -0.7786
# File: Sheet344_combined.csv          R² = -3.6199
# File: Sheet72_combined.csv           R² = -4.5170
# File: Sheet469_combined.csv          R² = -4.4059
# File: Sheet244_combined.csv          R² = -6.9712
# File: Sheet478_combined.csv          R² = -2.0667
# File: Sheet37_combined.csv           R² = -3.4039
# File: Sheet413_combined.csv          R² = -0.2285
# File: Sheet369_combined.csv          R² = -2.0357
# File: Sheet394_combined.csv          R² = -1.1539
# File: Sheet407_combined.csv          R² = -0.1027
# File: Sheet357_combined.csv          R² = -0.6881
# File: Sheet164_combined.csv          R² = -2.3544
# File: Sheet48_combined.csv           R² = -6.4284
# File: Sheet50_combined.csv           R² = -2.3858
# File: Sheet105_combined.csv          R² = -1.0160
# File: Sheet470_combined.csv          R² = -2.3409
# File: Sheet224_combined.csv          R² = -5.2496
# File: Sheet415_combined.csv          R² = -0.2104
# File: Sheet451_combined.csv          R² = -0.5335
# File: Sheet219_combined.csv          R² = -3.0507
# File: Sheet161_combined.csv          R² = -0.3035
# File: Sheet142_combined.csv          R² = -3.2885
# File: Sheet338_combined.csv          R² = -4.4799
# File: Sheet214_combined.csv          R² = -2.5751
# File: Sheet294_combined.csv          R² = -4.0142
# File: Sheet36_combined.csv           R² = -7.8828
# File: Sheet156_combined.csv          R² = -5.4476
# File: Sheet16_combined.csv           R² = -3.8815
# File: Sheet477_combined.csv          R² = -0.9932
# File: Sheet39_combined.csv           R² = -4.0143
# File: Sheet286_combined.csv          R² = -4.3586
# File: Sheet243_combined.csv          R² = -5.1480
# File: Sheet479_combined.csv          R² = -0.9038
# File: Sheet267_combined.csv          R² = -0.0497
# File: Sheet73_combined.csv           R² = -0.4929
# File: Sheet35_combined.csv           R² = -1.7166
# File: Sheet355_combined.csv          R² = -0.7739
# File: Sheet55_combined.csv           R² = 0.3515
# File: Sheet303_combined.csv          R² = -2.1208
# File: Sheet315_combined.csv          R² = -5.6376
# File: Sheet75_combined.csv           R² = -0.7214
# File: Sheet191_combined.csv          R² = 0.5467
# File: Sheet63_combined.csv           R² = 0.0365
# File: Sheet350_combined.csv          R² = -4.4702
# File: Sheet213_combined.csv          R² = -0.2351
# File: Sheet190_combined.csv          R² = -1.6299
# File: Sheet255_combined.csv          R² = 0.3720
# File: Sheet374_combined.csv          R² = -5.3171
# File: Sheet348_combined.csv          R² = -2.2088
# File: Sheet106_combined.csv          R² = -2.8153
# File: Sheet28_combined.csv           R² = -4.3153
# File: Sheet467_combined.csv          R² = -0.6142
# File: Sheet399_combined.csv          R² = -0.7754
# File: Sheet420_combined.csv          R² = -2.4520
# File: Sheet211_combined.csv          R² = -0.9308
# File: Sheet109_combined.csv          R² = -2.5256
# File: Sheet239_combined.csv          R² = -4.0223
# File: Sheet283_combined.csv          R² = -1.0775
# File: Sheet123_combined.csv          R² = -1.0306
# File: Sheet386_combined.csv          R² = -3.5554
# File: Sheet272_combined.csv          R² = -5.8054
# File: Sheet261_combined.csv          R² = -2.6996
# File: Sheet266_combined.csv          R² = -2.9951
# File: Sheet450_combined.csv          R² = -1.8168
# File: Sheet166_combined.csv          R² = -3.6296
# File: Sheet263_combined.csv          R² = -0.5927
# File: Sheet194_combined.csv          R² = -1.2908
# File: Sheet42_combined.csv           R² = -2.8798
# File: Sheet337_combined.csv          R² = -0.0909
# File: Sheet90_combined.csv           R² = -0.3381
# File: Sheet127_combined.csv          R² = -9.8401
# File: Sheet3_combined.csv            R² = -4.4587
# File: Sheet98_combined.csv           R² = -1.8638
# File: Sheet363_combined.csv          R² = 0.1206
# File: Sheet383_combined.csv          R² = -0.5051
# File: Sheet345_combined.csv          R² = -0.3782
# File: Sheet140_combined.csv          R² = -0.7513
# File: Sheet426_combined.csv          R² = -3.9707
# File: Sheet85_combined.csv           R² = -1.2640
# File: Sheet365_combined.csv          R² = -1.0425
# File: Sheet277_combined.csv          R² = -0.7359
# File: Sheet122_combined.csv          R² = -4.6507
# File: Sheet396_combined.csv          R² = -2.6108
# File: Sheet196_combined.csv          R² = -2.0338
# File: Sheet33_combined.csv           R² = -2.1055
# File: Sheet368_combined.csv          R² = -2.3479
# File: Sheet319_combined.csv          R² = -1.1048
# File: Sheet162_combined.csv          R² = -3.7581
# File: Sheet387_combined.csv          R² = -1.7582
# File: Sheet245_combined.csv          R² = -3.9639
# File: Sheet100_combined.csv          R² = -4.1652
# File: Sheet114_combined.csv          R² = -9.2387
# File: Sheet121_combined.csv          R² = 0.4545
# File: Sheet17_combined.csv           R² = -0.3804
# File: Sheet150_combined.csv          R² = -2.9325
# File: Sheet307_combined.csv          R² = -0.0101
# File: Sheet463_combined.csv          R² = -0.8555
# File: Sheet464_combined.csv          R² = -2.1691
# File: Sheet275_combined.csv          R² = -0.6635
# File: Sheet222_combined.csv          R² = -1.9226
# File: Sheet168_combined.csv          R² = -0.9544
# File: Sheet461_combined.csv          R² = -1.2655
# File: Sheet408_combined.csv          R² = -2.6214
# File: Sheet326_combined.csv          R² = -4.2441
# File: Sheet71_combined.csv           R² = -4.4587
# File: Sheet11_combined.csv           R² = 0.6256
# File: Sheet206_combined.csv          R² = -2.0570
# File: Sheet113_combined.csv          R² = -1.6940
# File: Sheet99_combined.csv           R² = -0.3529
# File: Sheet455_combined.csv          R² = -0.9942
# File: Sheet154_combined.csv          R² = -4.6796
# File: Sheet247_combined.csv          R² = -6.4675
# File: Sheet482_combined.csv          R² = -1.6320
# File: Sheet187_combined.csv          R² = -2.7201
# File: Sheet220_combined.csv          R² = -2.6163
# File: Sheet305_combined.csv          R² = -3.9193
# File: Sheet351_combined.csv          R² = -0.2431
# File: Sheet185_combined.csv          R² = 0.2945
# File: Sheet136_combined.csv          R² = -3.3420
# File: Sheet87_combined.csv           R² = 0.4475
# File: Sheet401_combined.csv          R² = -0.4414
# File: Sheet377_combined.csv          R² = -0.4777
# File: Sheet27_combined.csv           R² = 0.0309
# File: Sheet241_combined.csv          R² = -2.0541
# File: Sheet448_combined.csv          R² = -2.1225
# File: Sheet193_combined.csv          R² = -1.7348
# File: Sheet250_combined.csv          R² = -3.9375
# File: Sheet258_combined.csv          R² = -1.8182
# File: Sheet14_combined.csv           R² = -8.5908
# File: Sheet428_combined.csv          R² = -2.1351
# File: Sheet32_combined.csv           R² = -4.3990
# File: Sheet149_combined.csv          R² = -1.4702
# File: Sheet309_combined.csv          R² = -2.0551
# File: Sheet288_combined.csv          R² = -1.1683
# File: Sheet192_combined.csv          R² = -1.2472
# File: Sheet199_combined.csv          R² = -0.5505
# File: Sheet51_combined.csv           R² = 0.0365
# File: Sheet93_combined.csv           R² = -2.5216
# File: Sheet380_combined.csv          R² = -1.8431
# File: Sheet143_combined.csv          R² = -0.3883
# File: Sheet115_combined.csv          R² = -1.2285
# File: Sheet155_combined.csv          R² = -1.3810
# File: Sheet179_combined.csv          R² = 0.2184
# File: Sheet457_combined.csv          R² = -7.5331
# File: Sheet165_combined.csv          R² = -0.4702
# File: Sheet79_combined.csv           R² = -5.2180
# File: Sheet484_combined.csv          R² = -2.1273
# File: Sheet329_combined.csv          R² = -1.1679
# File: Sheet46_combined.csv           R² = -4.2578
# File: Sheet331_combined.csv          R² = -0.6916
# File: Sheet144_combined.csv          R² = -3.3177
# File: Sheet473_combined.csv          R² = -1.1037
# File: Sheet159_combined.csv          R² = -0.1099
# File: Sheet371_combined.csv          R² = 0.2319
# File: Sheet409_combined.csv          R² = -0.7300
# File: Sheet441_combined.csv          R² = -1.5362
# File: Sheet359_combined.csv          R² = -1.9723
# File: Sheet456_combined.csv          R² = -11.8681
# File: Sheet218_combined.csv          R² = -5.5996
# File: Sheet249_combined.csv          R² = -1.9568
# File: Sheet64_combined.csv           R² = -3.9707
# File: Sheet358_combined.csv          R² = -4.3487
# File: Sheet197_combined.csv          R² = -0.7754
# File: Sheet376_combined.csv          R² = -2.9868
# File: Sheet94_combined.csv           R² = -10.1184
# File: Sheet443_combined.csv          R² = -0.8455
# File: Sheet151_combined.csv          R² = -0.3197
# File: Sheet364_combined.csv          R² = -1.1906
# File: Sheet366_combined.csv          R² = -2.9506
# File: Sheet429_combined.csv          R² = -0.7587
# File: Sheet146_combined.csv          R² = -7.4401
# File: Sheet141_combined.csv          R² = 0.0443
# File: Sheet384_combined.csv          R² = -2.7075
# File: Sheet49_combined.csv           R² = -0.9363
# File: Sheet299_combined.csv          R² = -0.4570
# File: Sheet435_combined.csv          R² = -0.1584
# File: Sheet289_combined.csv          R² = -0.3035
# File: Sheet276_combined.csv          R² = -1.2319
# File: Sheet184_combined.csv          R² = -2.2354
# File: Sheet427_combined.csv          R² = -4.8836
# File: Sheet21_combined.csv           R² = -0.3704
# File: Sheet252_combined.csv          R² = -3.4768
# File: Sheet317_combined.csv          R² = -2.0615
# File: Sheet382_combined.csv          R² = -1.9700
# File: Sheet475_combined.csv          R² = -3.6065
# File: Sheet284_combined.csv          R² = -2.7098
# File: Sheet7_combined.csv            R² = -0.4672
# File: Sheet265_combined.csv          R² = -1.4041
# File: Sheet352_combined.csv          R² = -6.2781
# File: Sheet418_combined.csv          R² = -2.1651
# File: Sheet57_combined.csv           R² = -0.0915
# File: Sheet379_combined.csv          R² = -3.8529
# File: Sheet88_combined.csv           R² = -11.4017
# File: Sheet137_combined.csv          R² = -2.6704
# File: Sheet215_combined.csv          R² = -0.4531
# File: Sheet298_combined.csv          R² = -4.4414
# File: Sheet81_combined.csv           R² = -1.2375
# File: Sheet256_combined.csv          R² = -1.9824
# File: Sheet204_combined.csv          R² = -3.3025
# File: Sheet400_combined.csv          R² = -1.8839
# File: Sheet216_combined.csv          R² = -4.3153
# File: Sheet26_combined.csv           R² = -2.1200
# File: Sheet405_combined.csv          R² = -1.7336
# File: Sheet481_combined.csv          R² = -0.3039
# File: Sheet19_combined.csv           R² = -0.4274
# File: Sheet25_combined.csv           R² = -1.5564
# File: Sheet221_combined.csv          R² = -1.2049
# File: Sheet189_combined.csv          R² = -1.7932
# File: Sheet104_combined.csv          R² = -0.0975
# File: Sheet176_combined.csv          R² = -2.5670
# File: Sheet264_combined.csv          R² = -6.6308
# File: Sheet257_combined.csv          R² = -0.3004
# File: Sheet54_combined.csv           R² = -0.9699
# File: Sheet128_combined.csv          R² = -10.8319
# File: Sheet117_combined.csv          R² = -4.7621
# File: Sheet38_combined.csv           R² = -4.5542
# File: Sheet424_combined.csv          R² = -1.7753
# File: Sheet20_combined.csv           R² = -2.8003
# File: Sheet96_combined.csv           R² = -4.4694
# File: Sheet476_combined.csv          R² = -1.8040
# File: Sheet157_combined.csv          R² = -1.7848
# File: Sheet183_combined.csv          R² = -0.0594
# File: Sheet393_combined.csv          R² = -1.6893
# File: Sheet68_combined.csv           R² = -1.8493
# File: Sheet458_combined.csv          R² = -5.7261
# File: Sheet212_combined.csv          R² = -3.6774
# File: Sheet395_combined.csv          R² = 0.0097
# File: Sheet280_combined.csv          R² = -3.0592
# File: Sheet235_combined.csv          R² = -1.0698
# File: Sheet82_combined.csv           R² = -4.5164
# File: Sheet422_combined.csv          R² = -1.8367
# File: Sheet170_combined.csv          R² = -5.9223
# File: Sheet471_combined.csv          R² = -1.6404
# File: Sheet274_combined.csv          R² = -3.0838
# File: Sheet226_combined.csv          R² = -4.6255
# File: Sheet248_combined.csv          R² = -7.4171
# File: Sheet278_combined.csv          R² = -10.7178
# File: Sheet102_combined.csv          R² = -2.0161
# File: Sheet8_combined.csv            R² = -2.5032
# File: Sheet77_combined.csv           R² = 0.5452
# File: Sheet202_combined.csv          R² = -3.6294
# File: Sheet31_combined.csv           R² = -5.5481
# File: Sheet138_combined.csv          R² = -7.5739
# File: Sheet198_combined.csv          R² = -3.7635
# File: Sheet238_combined.csv          R² = -1.8458
# File: Sheet163_combined.csv          R² = 0.2788
# File: Sheet370_combined.csv          R² = -3.7045
# File: Sheet86_combined.csv           R² = -2.5032
# File: Sheet462_combined.csv          R² = -2.1661
# File: Sheet70_combined.csv           R² = -10.0072
# File: Sheet4_combined.csv            R² = -6.7671
# File: Sheet308_combined.csv          R² = -1.7693
# File: Sheet410_combined.csv          R² = -5.0231
# File: Sheet327_combined.csv          R² = -5.5755
# File: Sheet273_combined.csv          R² = -2.1163
# File: Sheet287_combined.csv          R² = -1.6055
# File: Sheet324_combined.csv          R² = -2.9597
# File: Sheet282_combined.csv          R² = -2.3146
# File: Sheet340_combined.csv          R² = -4.4694
# File: Sheet200_combined.csv          R² = -9.8567
# File: Sheet254_combined.csv          R² = -3.2553
# File: Sheet180_combined.csv          R² = -1.4806
# File: Sheet293_combined.csv          R² = 0.0412
# File: Sheet108_combined.csv          R² = -7.3249
# File: Sheet147_combined.csv          R² = -3.3510
# File: Sheet9_combined.csv            R² = 0.4475
# File: Sheet52_combined.csv           R² = -3.9707
# File: Sheet107_combined.csv          R² = -0.2156
# File: Sheet325_combined.csv          R² = -3.3251
# File: Sheet316_combined.csv          R² = -3.8362
# File: Sheet356_combined.csv          R² = -2.8002
# File: Sheet60_combined.csv           R² = -6.4284
# File: Sheet398_combined.csv          R² = -2.0338
# File: Sheet12_combined.csv           R² = -2.9492
# File: Sheet18_combined.csv           R² = -4.1573
# File: Sheet406_combined.csv          R² = -2.1467
# File: Sheet385_combined.csv          R² = -0.3619
# File: Sheet186_combined.csv          R² = -6.0462
# File: Sheet103_combined.csv          R² = 0.0067
# File: Sheet111_combined.csv          R² = 0.3131
# File: Sheet474_combined.csv          R² = -6.0520
# File: Sheet246_combined.csv          R² = -6.7671
# File: Sheet172_combined.csv          R² = -1.8698
# File: Sheet30_combined.csv           R² = -3.1277
# File: Sheet323_combined.csv          R² = -0.6069
# File: Sheet134_combined.csv          R² = -2.1948
# File: Sheet174_combined.csv          R² = -3.2699
# File: Sheet452_combined.csv          R² = -2.3746
# File: Sheet354_combined.csv          R² = -2.9375
# File: Sheet468_combined.csv          R² = -4.1986
# File: Sheet322_combined.csv          R² = -2.3491
# File: Sheet67_combined.csv           R² = 0.3515
# File: Sheet375_combined.csv          R² = -2.2540
# File: Sheet89_combined.csv           R² = -1.9735
# File: Sheet178_combined.csv          R² = -1.2301
# File: Sheet223_combined.csv          R² = 0.1464
# File: Sheet59_combined.csv           R² = -1.4057
# File: Sheet372_combined.csv          R² = -9.1349
# File: Sheet290_combined.csv          R² = -2.2376
# File: Sheet300_combined.csv          R² = -3.6352
# File: Sheet389_combined.csv          R² = -0.1246
# File: Sheet120_combined.csv          R² = -2.0274
# File: Sheet433_combined.csv          R² = -0.1051
# File: Sheet152_combined.csv          R² = -1.7359
# File: Sheet112_combined.csv          R² = -4.8015
# File: Sheet101_combined.csv          R² = -1.0128
# File: Sheet281_combined.csv          R² = -0.4995
# File: Sheet22_combined.csv           R² = -10.1045
# File: Sheet416_combined.csv          R² = -2.5670
# File: Sheet195_combined.csv          R² = -0.2632
# File: Sheet411_combined.csv          R² = -1.0241
# File: Sheet335_combined.csv          R² = -0.0653
# File: Sheet80_combined.csv           R² = -5.8577
# File: Sheet314_combined.csv          R² = -8.8806
# File: Sheet430_combined.csv          R² = -3.0442
# File: Sheet381_combined.csv          R² = -0.7806
# File: Sheet292_combined.csv          R² = -2.0536
# File: Sheet318_combined.csv          R² = -3.4567
# File: Sheet240_combined.csv          R² = -7.6083
# File: Sheet237_combined.csv          R² = 0.3803
# File: Sheet53_combined.csv           R² = -4.8836
# File: Sheet341_combined.csv          R² = -3.3424
# File: Sheet169_combined.csv          R² = -0.9521
# File: Sheet417_combined.csv          R² = 0.2996
# File: Sheet270_combined.csv          R² = -3.9006
# File: Sheet6_combined.csv            R² = -3.9416
# File: Sheet297_combined.csv          R² = -1.0150
# File: Sheet440_combined.csv          R² = -3.5717
# File: Sheet10_combined.csv           R² = -2.4417
# File: Sheet83_combined.csv           R² = 0.0907
# File: Sheet313_combined.csv          R² = -0.8380
# File: Sheet260_combined.csv          R² = -3.8780
# File: Sheet76_combined.csv           R² = -2.0022
# File: Sheet205_combined.csv          R² = -1.5519
# File: Sheet271_combined.csv          R² = -1.5860
# File: Sheet328_combined.csv          R² = -4.7128
# File: Sheet207_combined.csv          R² = -0.1549
# File: Sheet362_combined.csv          R² = -2.4142
# File: Sheet97_combined.csv           R² = -3.3424
# File: Sheet24_combined.csv           R² = -4.5804
# File: Sheet43_combined.csv           R² = -0.1571
# File: Sheet229_combined.csv          R² = -1.5157
# File: Sheet242_combined.csv          R² = -6.1294
# File: Sheet444_combined.csv          R² = -4.2741
# File: Sheet402_combined.csv          R² = -7.0487
# File: Sheet203_combined.csv          R² = -1.8667
# File: Sheet390_combined.csv          R² = -3.7016
# File: Sheet182_combined.csv          R² = -1.2877
# File: Sheet167_combined.csv          R² = -0.6758
# File: Sheet188_combined.csv          R² = -2.6812
# File: Sheet47_combined.csv           R² = -1.4057
# File: Sheet62_combined.csv           R² = -2.3858
# File: Sheet310_combined.csv          R² = -2.2032
# File: Sheet69_combined.csv           R² = -1.6893
# File: Sheet447_combined.csv          R² = -1.5939
# File: Sheet158_combined.csv          R² = -1.8178
# File: Sheet279_combined.csv          R² = -4.7785
# File: Sheet58_combined.csv           R² = -4.2578
# File: Sheet336_combined.csv          R² = -5.3235
# File: Sheet56_combined.csv           R² = -2.3019
# File: Sheet361_combined.csv          R² = -5.0198
# File: Sheet403_combined.csv          R² = -0.6576
# File: Sheet414_combined.csv          R² = -1.5045
# File: Sheet454_combined.csv          R² = -1.8875
# File: Sheet442_combined.csv          R² = -2.3230
# File: Sheet259_combined.csv          R² = -0.0755
# File: Sheet269_combined.csv          R² = -0.0159
# File: Sheet392_combined.csv          R² = -1.8493
# File: Sheet66_combined.csv           R² = -0.9699
# File: Sheet343_combined.csv          R² = -0.2174
# File: Sheet346_combined.csv          R² = -7.6706
# File: Sheet306_combined.csv          R² = -4.2759
# File: Sheet445_combined.csv          R² = -1.1299
# File: Sheet34_combined.csv           R² = -6.2694
# File: Sheet232_combined.csv          R² = -2.3007
#
# Combined Model Performance Summary:
# Average R² Score: -2.6493 ± 2.4335
# Min R² Score: -12.9858
# Max R² Score: 0.6256
#
# Combined model performance metrics saved to: combined_model_performance.csv
# Detailed results saved to: combined_model_detailed_results.csv
