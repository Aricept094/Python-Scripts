# %%
import os
from bs4 import BeautifulSoup
from docx import Document

def concatenate_html_plaintext_to_docx(html_dir, output_docx_file):
    """
    Concatenates the *plaintext content* of .html files in a directory into a single .docx file.
    Extracts visible text and ignores HTML tags to ensure clean text in DOCX.

    Args:
        html_dir (str): Path to the directory containing .html files.
        output_docx_file (str): Path to save the concatenated .docx file.
    """

    docx_document = Document()  # Create a new DOCX document

    html_files = sorted([f for f in os.listdir(html_dir) if f.endswith('.html')]) # Get sorted list of HTML files

    for html_file in html_files:
        html_filepath = os.path.join(html_dir, html_file)
        print(f"Processing: {html_file}")

        try:
            with open(html_filepath, 'r', encoding='utf-8') as f:
                html_content = f.read()

            soup = BeautifulSoup(html_content, 'html.parser')

            # **Extract plaintext: Get all text, remove tags, scripts, and styles**
            plaintext_content = soup.get_text(separator='\n', strip=True) # Get all text, separated by newlines, and strip whitespace

            # Add the plaintext content as a paragraph
            docx_document.add_paragraph(plaintext_content)

            docx_document.add_page_break() # Add a page break between files

        except Exception as e:
            print(f"Error processing {html_file}: {e}")

    docx_document.save(output_docx_file)
    print(f"\nConcatenated DOCX file created (plaintext content): {output_docx_file}")
    
if __name__ == "__main__":
    html_directory = "/home/aricept094/pipet/rayon_docs_content"  # Replace with the directory where your HTML files are saved
    docx_output_file = "/home/aricept094/pipet/combined_rayon_docs.docx" # Name for the output .docx file

    concatenate_html_raw_to_docx(html_directory, docx_output_file)
# Out:
# Processing: all.html
# Processing: array.rs.html
# Processing: binary_heap.rs.html
# Processing: blocks.rs.html
# Processing: btree_map.rs.html
# Processing: btree_set.rs.html
# Processing: chain.rs.html
# Processing: chunk_by.rs.html
# Processing: chunks.rs.html
# Processing: cloned.rs.html
# Processing: copied.rs.html
# Processing: empty.rs.html
# Processing: enum.Either.html
# Processing: enum.Yield.html
# Processing: enumerate.rs.html
# Processing: extend.rs.html
# Processing: filter.rs.html
# Processing: filter_map.rs.html
# Processing: flat_map.rs.html
# Processing: flat_map_iter.rs.html
# Processing: flatten.rs.html
# Processing: flatten_iter.rs.html
# Processing: fn.bridge.html
# Processing: fn.bridge_producer_consumer.html
# Processing: fn.bridge_unindexed.html
# Processing: fn.broadcast.html
# Processing: fn.current_num_threads.html
# Processing: fn.current_thread_index.html
# Processing: fn.empty.html
# Processing: fn.in_place_scope.html
# Processing: fn.in_place_scope_fifo.html
# Processing: fn.join.html
# Processing: fn.join_context.html
# Processing: fn.max_num_threads.html
# Processing: fn.once.html
# Processing: fn.repeat.html
# Processing: fn.repeatn.html
# Processing: fn.scope.html
# Processing: fn.scope_fifo.html
# Processing: fn.spawn.html
# Processing: fn.spawn_broadcast.html
# Processing: fn.spawn_fifo.html
# Processing: fn.split.html
# Processing: fn.walk_tree.html
# Processing: fn.walk_tree_postfix.html
# Processing: fn.walk_tree_prefix.html
# Processing: fn.yield_local.html
# Processing: fn.yield_now.html
# Processing: fold.rs.html
# Processing: fold_chunks.rs.html
# Processing: fold_chunks_with.rs.html
# Processing: from_par_iter.rs.html
# Processing: hash_map.rs.html
# Processing: hash_set.rs.html
# Processing: help.html
# Processing: index.html
# Processing: inspect.rs.html
# Processing: interleave.rs.html
# Processing: interleave_shortest.rs.html
# Processing: intersperse.rs.html
# Processing: len.rs.html
# Processing: lib.rs.html
# Processing: linked_list.rs.html
# Processing: map.rs.html
# Processing: map_with.rs.html
# Processing: mod.rs.html
# Processing: multizip.rs.html
# Processing: once.rs.html
# Processing: option.rs.html
# Processing: panic_fuse.rs.html
# Processing: par_bridge.rs.html
# Processing: par_either.rs.html
# Processing: positions.rs.html
# Processing: prelude.rs.html
# Processing: range.rs.html
# Processing: range_inclusive.rs.html
# Processing: rchunks.rs.html
# Processing: repeat.rs.html
# Processing: result.rs.html
# Processing: rev.rs.html
# Processing: settings.html
# Processing: skip.rs.html
# Processing: skip_any.rs.html
# Processing: skip_any_while.rs.html
# Processing: splitter.rs.html
# Processing: step_by.rs.html
# Processing: str.rs.html
# Processing: string.rs.html
# Processing: struct.BroadcastContext.html
# Processing: struct.Bytes.html
# Processing: struct.Chain.html
# Processing: struct.CharIndices.html
# Processing: struct.Chars.html
# Processing: struct.ChunkBy.html
# Processing: struct.ChunkByMut.html
# Processing: struct.Chunks.html
# Processing: struct.ChunksExact.html
# Processing: struct.ChunksExactMut.html
# Processing: struct.ChunksMut.html
# Processing: struct.Cloned.html
# Processing: struct.Copied.html
# Processing: struct.Drain.html
# Processing: struct.Empty.html
# Processing: struct.EncodeUtf16.html
# Processing: struct.Enumerate.html
# Processing: struct.ExponentialBlocks.html
# Processing: struct.Filter.html
# Processing: struct.FilterMap.html
# Processing: struct.FlatMap.html
# Processing: struct.FlatMapIter.html
# Processing: struct.Flatten.html
# Processing: struct.FlattenIter.html
# Processing: struct.FnContext.html
# Processing: struct.Fold.html
# Processing: struct.FoldChunks.html
# Processing: struct.FoldChunksWith.html
# Processing: struct.FoldWith.html
# Processing: struct.Inspect.html
# Processing: struct.Interleave.html
# Processing: struct.InterleaveShortest.html
# Processing: struct.Intersperse.html
# Processing: struct.IntoIter.html
# Processing: struct.Iter.html
# Processing: struct.IterBridge.html
# Processing: struct.IterMut.html
# Processing: struct.Lines.html
# Processing: struct.Map.html
# Processing: struct.MapInit.html
# Processing: struct.MapWith.html
# Processing: struct.MatchIndices.html
# Processing: struct.Matches.html
# Processing: struct.MaxLen.html
# Processing: struct.MinLen.html
# Processing: struct.MultiZip.html
# Processing: struct.Once.html
# Processing: struct.PanicFuse.html
# Processing: struct.Positions.html
# Processing: struct.RChunks.html
# Processing: struct.RChunksExact.html
# Processing: struct.RChunksExactMut.html
# Processing: struct.RChunksMut.html
# Processing: struct.Repeat.html
# Processing: struct.RepeatN.html
# Processing: struct.Rev.html
# Processing: struct.Scope.html
# Processing: struct.ScopeFifo.html
# Processing: struct.Skip.html
# Processing: struct.SkipAny.html
# Processing: struct.SkipAnyWhile.html
# Processing: struct.Split.html
# Processing: struct.SplitAsciiWhitespace.html
# Processing: struct.SplitInclusive.html
# Processing: struct.SplitInclusiveMut.html
# Processing: struct.SplitMut.html
# Processing: struct.SplitTerminator.html
# Processing: struct.SplitWhitespace.html
# Processing: struct.StepBy.html
# Processing: struct.Take.html
# Processing: struct.TakeAny.html
# Processing: struct.TakeAnyWhile.html
# Processing: struct.ThreadBuilder.html
# Processing: struct.ThreadPool.html
# Processing: struct.ThreadPoolBuildError.html
# Processing: struct.ThreadPoolBuilder.html
# Processing: struct.TryFold.html
# Processing: struct.TryFoldWith.html
# Processing: struct.UniformBlocks.html
# Processing: struct.Update.html
# Processing: struct.WalkTree.html
# Processing: struct.WalkTreePostfix.html
# Processing: struct.WalkTreePrefix.html
# Processing: struct.WhileSome.html
# Processing: struct.Windows.html
# Processing: struct.Zip.html
# Processing: struct.ZipEq.html
# Processing: take.rs.html
# Processing: take_any.rs.html
# Processing: take_any_while.rs.html
# Processing: trait.Consumer.html
# Processing: trait.Folder.html
# Processing: trait.FromParallelIterator.html
# Processing: trait.IndexedParallelIterator.html
# Processing: trait.IntoParallelIterator.html
# Processing: trait.IntoParallelRefIterator.html
# Processing: trait.IntoParallelRefMutIterator.html
# Processing: trait.ParallelBridge.html
# Processing: trait.ParallelDrainFull.html
# Processing: trait.ParallelDrainRange.html
# Processing: trait.ParallelExtend.html
# Processing: trait.ParallelIterator.html
# Processing: trait.ParallelSlice.html
# Processing: trait.ParallelSliceMut.html
# Processing: trait.ParallelString.html
# Processing: trait.Producer.html
# Processing: trait.ProducerCallback.html
# Processing: trait.Reducer.html
# Processing: trait.UnindexedConsumer.html
# Processing: trait.UnindexedProducer.html
# Processing: try_fold.rs.html
# Processing: unzip.rs.html
# Processing: update.rs.html
# Processing: vec.rs.html
# Processing: vec_deque.rs.html
# Processing: walk_tree.rs.html
# Processing: while_some.rs.html
# Processing: zip.rs.html
# Processing: zip_eq.rs.html
#
# Concatenated DOCX file created (URL-encoded raw HTML): /home/aricept094/pipet/combined_rayon_docs.docx
